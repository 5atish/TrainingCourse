# %% [markdown]
# #### Installation and Basic Setup

# %%
from huggingface_hub import InferenceClient

client = InferenceClient(base_url="http://localhost:8080/v1")

response = client.chat_completion(
    messages=[{"role": "user", "content": "Hello, how are you?"}],
    max_tokens=50,
)

print(response.choices[0].message.content)
# Out:
# I'm just a language model, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to help you with any questions or topics you'd like to discuss. How about you? How's your day going?

# %%
from huggingface_hub import InferenceClient

# Initialize client pointing to TGI endpoint
client = InferenceClient(
    model="http://localhost:8080",  # URL to the TGI server
)

# %%
from openai import OpenAI

client = OpenAI(base_url="http://localhost:8080/v1", api_key="not-needed")

# %%
# Text generation
response = client.completions.create(
    model="local-model",
    prompt="Tell me a story",
    max_tokens=100,
    temperature=0.7,
    top_p=0.95,
)

print(response.choices[0].text)
# Out:
#  about a small, struggling business owner who finds inspiration and motivation from an unlikely source.
# ---
#
# **The Art of the Unseen**
#
# Lena, the owner of a quaint, yet struggling bookstore, had been fighting an uphill battle to keep her business afloat. With the rise of e-books and online retailers, the traditional bookstore was becoming a relic of the past. Lena's store, "Page & Co.", had been a fixture in the community for over a decade, but sales had been dwindling

# %%
from huggingface_hub import InferenceClient

# Initialize client pointing to TGI endpoint
client = InferenceClient(
    model="http://localhost:8080",  # URL to the TGI server
)
# For chat format
response = client.chat_completion(
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Tell me a story"},
    ],
    max_tokens=100,
    temperature=0.7,
    top_p=0.95,
)
print(response.choices[0].message.content)
# Out:
# Once upon a time, in a small village nestled in the rolling hills of Tuscany, there lived a young girl named Luna. She was a curious and adventurous soul, with eyes that shone like the stars on a clear night and hair that flowed like the golden wheat that grew in the fields around her home.
#
# Luna lived with her wise and loving grandmother, who was known throughout the village for her extraordinary gift: the ability to communicate with animals. It was said that her grandmother could talk

# %%
from openai import OpenAI

# Initialize client pointing to TGI endpoint
client = OpenAI(
    base_url="http://localhost:8080/v1",  # Make sure to include /v1
    api_key="not-needed",  # TGI doesn't require an API key by default
)

# Chat completion
response = client.chat.completions.create(
    model="HuggingFaceTB/SmolLM2-360M-Instruct",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Tell me a story"},
    ],
    max_tokens=100,
    temperature=0.7,
    top_p=0.95,
)
print(response.choices[0].message.content)
# Out:
# Once upon a time, in a small village nestled in the rolling hills of the countryside, there lived a young girl named Luna. Luna was a curious and adventurous child, with a heart full of wonder and a mind full of questions. She loved to explore the world around her, and was always getting into mischief.
#
# One day, while wandering through the village, Luna stumbled upon a small, mysterious shop that she had never noticed before. The sign above the door read "Curios and Wonders,"

# %%
from huggingface_hub import InferenceClient

# Initialize client pointing to llama.cpp server
client = InferenceClient(
    model="http://localhost:8080/v1",  # URL to the llama.cpp server
    token="sk-no-key-required",  # llama.cpp server requires this placeholder
)

# %%
# Chat format — this is the one that works with llama.cpp
response = client.chat_completion(
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Tell me a story"},
    ],
    max_tokens=100,
    temperature=0.7,
    top_p=0.95,
)
print(response.choices[0].message.content)
# Out:
# Once upon a time, in a small village nestled in the rolling hills of Tuscany, there was a young girl named Luna. Luna was a curious and adventurous child, with a heart full of wonder and a mind full of questions.
#
# One day, while exploring the village, Luna stumbled upon a small, mysterious shop tucked away on a quiet street. The sign above the door read "Curios and Wonders," and the windows were filled with an assortment of strange and fascinating objects.
#
# Luna

# %%
# For chat format
response = client.chat_completion(
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Tell me a story"},
    ],
    max_tokens=100,
    temperature=0.7,
    top_p=0.95,
)
print(response.choices[0].message.content)
# Out:
# Once upon a time, in a small village nestled between two great mountains, there lived a young girl named Luna. Luna was a curious and adventurous soul, with eyes that sparkled like the stars on a clear night and hair as bright as the golden sun.
#
# Luna lived with her wise and loving grandmother, who taught her the ancient secrets of the forest and the magic that lay within. Her grandmother, known as the "Weaver," was a master of the mystical arts, and her tales of

# %%
from openai import OpenAI

# Initialize client pointing to llama.cpp server
client = OpenAI(
    base_url="http://localhost:8080/v1",
    api_key="sk-no-key-required",  # llama.cpp server requires this placeholder
)

# Chat completion
response = client.chat.completions.create(
    model="smollm2-1.7b-instruct",  # Model identifier can be anything as server only loads one model
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Tell me a story"},
    ],
    max_tokens=100,
    temperature=0.7,
    top_p=0.95,
)
print(response.choices[0].message.content)
# Out:
# Once upon a time, in a small village nestled in the rolling hills of a far-off land, there lived a young girl named Luna. Luna was a curious and adventurous child, with a heart full of wonder and a mind full of questions. She loved to explore the world around her, and was always getting into mischief.
#
# One day, while wandering through the village, Luna stumbled upon a small, mysterious shop tucked away on a quiet street. The sign above the door read "Curios and W

# %%
from huggingface_hub import InferenceClient

# Initialize client pointing to vLLM endpoint
client = InferenceClient(
    model="http://localhost:8080/v1",  # URL to the vLLM server
)

# Text generation
response = client.chat_completion(
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Tell me a story"},
    ],
    max_tokens=100,
    temperature=0.7,
    top_p=0.95,
)
print(response.choices[0].message.content)
# Out:
# Once upon a time, in a small village nestled between two great mountains, there lived a young girl named Luna. She was a curious and adventurous child, with eyes that shone like the stars on a clear night and hair as bright as the golden sun.
#
# Luna lived with her wise and kind grandmother, who taught her the secrets of the forest and the language of the animals. She spent her days exploring the woods, collecting herbs and berries, and listening to the tales of the forest spirits.

# %%
# For chat format
response = client.chat_completion(
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Tell me a story"},
    ],
    max_tokens=100,
    temperature=0.7,
    top_p=0.95,
)
print(response.choices[0].message.content)
# Out:
# Once upon a time, in a small village nestled between two great mountains, there lived a young girl named Luna. She was a curious and adventurous child, with eyes that shone like the stars on a clear night and hair as bright as the sun.
#
# Luna lived with her wise and kind grandmother, who taught her the secrets of the forest and the magic of the earth. She showed Luna how to listen to the trees, how to talk to the animals, and how to heal the wounded plants

# %%
from huggingface_hub import InferenceClient

client = InferenceClient(model="http://localhost:8080")

# Advanced parameters example
response = client.chat_completion(
    messages=[
        {"role": "system", "content": "You are a creative storyteller."},
        {"role": "user", "content": "Write a creative story"},
    ],
    temperature=0.8,
    max_tokens=200,
    top_p=0.95,
)
print(response.choices[0].message.content)
# Out:
# The Whispering Library of Dreams
#
# In a world where dreams were currency, the city of Somnium was the richest place on earth. Its streets were lined with shops that sold the most precious of commodities: slumber. People would trade their deepest desires, their darkest fears, and their most vibrant imagination for a night's sleep. And in the heart of Somnium, there stood a mystical library like no other – the Whispering Library of Dreams.
#
# The library was said to be run by a mysterious librarian named Luna, who could weave the most fantastical tales and conjure the most vivid of dreams. Her shelves were lined with books that shimmered like moonlight, their pages whispering secrets to those who dared to listen.
#
# One night, a young traveler named Aria stumbled upon the Whispering Library of Dreams. She had heard whispers of its existence, but never thought she'd find herself standing before its doors. As she pushed open the heavy wooden doors, a soft breeze carried the

# %%
# Raw text generation
response = client.chat_completion(
    
    messages=[
        {"role": "system", "content": "You are a creative storyteller."},
        {"role": "user", "content": "Write a creative story about space exploration"},
    ],
    temperature=0.8,
    max_tokens=200,
    top_p=0.95,
)
print(response.choices[0].message.content)
# Out:
# In the year 2154, humanity had finally reached the stars, but it wasn't the sleek, silver spacecraft that had captivated the imagination of the world's greatest minds. It was the ancient, mystical vessel known as the "Aurora's Hope."
#
# This enigmatic ship, rumored to have been constructed by a long-lost civilization of spacefaring beings, was said to possess the power to traverse the vast expanse of interstellar space without the need for conventional propulsion systems. Instead, it relied on a complex network of quantum entanglements and celestial resonances that allowed it to tap into the very fabric of space-time itself.
#
# Captain Lyra Blackwood, a brilliant and fearless astrophysicist, had spent her entire life searching for the Aurora's Hope. Her obsession with the ship had driven her to make countless sacrifices, including the loss of her parents in a catastrophic accident that had left her with a rare condition known as "gravitational resonance syndrome."
#
# Despite the risks

# %%
from openai import OpenAI

client = OpenAI(base_url="http://localhost:8080/v1", api_key="not-needed")

# %%
# Advanced parameters example
response = client.chat.completions.create(
    model="HuggingFaceTB/SmolLM2-360M-Instruct",
    messages=[
        {"role": "system", "content": "You are a creative storyteller."},
        {"role": "user", "content": "Write a creative story"},
    ],
    temperature=0.8,  # Higher for more creativity
)
print(response.choices[0].message.content)
# Out:
# **The Whispering Library of Dreams**
#
# In the heart of the mystical forest, hidden behind a veil of shimmering mist, lay the Whispering Library of Dreams. This enchanting repository of knowledge was said to hold the secrets of the subconscious, where the whispers of the past and present converged to shape the future.
#
# Lena, a curious and adventurous soul, stumbled upon the library while wandering through the forest. As she pushed open the creaky door, a warm golden light spilled out, inviting her to enter. The air inside was alive with the whispers of forgotten tales, each one a thread in the tapestry of human experience.
#
# The librarian, a wispy figure with eyes like starlight, greeted Lena with a gentle smile. "Welcome, seeker of dreams. I shall guide you through the shelves, where the whispers of the past await."
#
# As they walked among the shelves, Lena noticed that each book had a soft, ethereal glow. The titles were etched in a language she couldn't understand, yet the words seemed to reverberate with the whispers of the past.
#
# The librarian led her to a section filled with books bound in a material that looked like liquid moonlight. "These are the dreams of the forgotten," the librarian said. "The ones who have lost their way, their passions, and their purpose."
#
# Lena's fingers itched to touch the books, and as she did, the whispers grew louder. She heard the dreams of a young artist, struggling to find her voice in a world of conformity. A musician, searching for the perfect melody to express his soul. A writer, seeking to capture the essence of love.
#
# As she delved deeper into the library, Lena encountered books with titles that shimmered like stardust: "The Dance of the Firefly," "The Song of the River," and "The Lullaby of the Nightingale." Each one whispered secrets of the human heart, revealing the hidden patterns of desire, fear, and love.
#
# The librarian guided her to a shelf filled with books that pulsed with a fiery energy. "These are the dreams of the bold," the librarian said. "The ones who have dared to challenge the status quo, to defy the conventions of the world."
#
# As Lena touched these books, the whispers became a crescendo of excitement and possibility. She heard the dreams of a pioneer, blazing a trail through the wilderness. A rebel, fighting against the tyranny of the establishment. A visionary, shaping the future with her imagination.
#
# As the night wore on, Lena found herself standing at the edge of a great, crystal lake. The librarian smiled, knowing that she had reached the heart of the library. "Here lies the Well of Dreams," the librarian said. "Drink from its waters, and you shall unlock the secrets of your own heart."
#
# Lena leaned forward, and as her lips touched the crystal surface, the whispers ceased. The library fell silent, except for the soft lapping of the water against the shore. In the stillness, she heard the whispers of her own heart, speaking in a language she had never known before.
#
# The secrets of her own dreams were revealed to her, and with them, a new path unfolded before her. Lena smiled, knowing that she had discovered a part of herself she never knew existed. As she left the Whispering Library of Dreams, the librarian's words echoed in her mind: "The whispers of the past are the keys to the future."
#
# From that day on, Lena carried the whispers of the library with her, using them to guide her on her own journey of self-discovery. And whenever she needed inspiration, she would return to the Whispering Library of Dreams, where the secrets of the heart awaited her, whispering softly in the darkness.

# %%
from huggingface_hub import InferenceClient

client = InferenceClient(model="http://localhost:8080/v1", token="sk-no-key-required")

# %%
# Advanced parameters example
response = client.chat_completion(
    messages=[
        {"role": "system", "content": "You are a creative storyteller."},
        {"role": "user", "content": "Write a creative story"},
    ],
    temperature=0.8,
    max_tokens=200,
    top_p=0.95,
)
print(response.choices[0].message.content)
# Out:
# In the depths of a mystical forest, where the ancient trees whispered secrets to the wind, and the moonlight filtering through the leaves created an ethereal glow, there existed a village of dreamers. The villagers were known for their extraordinary talents, for they possessed the ability to weave reality with their imagination.
#
# Aria, a young apprentice weaver, was renowned for her extraordinary skill in crafting illusions. Her threads shimmered with an otherworldly essence, imbuing the fabric with a life of its own. People would come from far and wide to commission her creations, each one more breathtaking than the last.
#
# One fateful evening, as the villagers gathered around the Great Oak, their elder storyteller, Eira, revealed a mysterious prophecy. "A great imbalance has been detected in the fabric of reality," she warned. "A rogue thread has been woven, threatening to unravel the very essence of our world."
#
# Aria, feeling an inexplicable connection to the prophecy, knew she had to embark

# %%
# Advanced parameters example
response = client.chat_completion(
    messages=[
        {"role": "system", "content": "You are a creative storyteller."},
        {"role": "user", "content":  "Write a creative story about space exploration"},
    ],
    temperature=0.8,
    max_tokens=200,
    top_p=0.95,
)
print(response.choices[0].message.content)
# Out:
# **The Star Weaver**
#
# In the year 2256, humanity had finally cracked the code to interstellar travel. The spacecraft, named _Aurora_, was a marvel of engineering, with a hull made of a new, lightweight material that could withstand the harsh conditions of space. Its crew of six was handpicked by the brilliant scientist, Dr. Sophia Patel, who had spent her entire life studying the mysteries of the cosmos.
#
# The mission was to explore the distant planet of Xylophia-IV, a world shrouded in legend and myth. According to ancient texts, Xylophia-IV was home to a civilization that had mastered the art of manipulating the fabric of space and time itself.
#
# As the _Aurora_ entered the orbit of Xylophia-IV, the crew was awestruck by the planet's breathtaking beauty. The sky was a deep shade of indigo, and the stars twinkled like diamonds against the blackness. But it was

# %%
# # For direct text generation
# response = client.text_generation(
#     "Write a creative story about space exploration",
#     max_new_tokens=200,
#     temperature=0.8,
#     top_p=0.95,
#     repetition_penalty=1.1,
#     details=True,
# )
# print(response.generated_text)

# %%
from openai import OpenAI

# Initialize client pointing to llama.cpp server
client = OpenAI(
    base_url="http://localhost:8080/v1",
    api_key="sk-no-key-required",  # llama.cpp server requires this placeholder
)

# %%
# Chat completion
response = client.chat.completions.create(
    model="smollm2-1.7b-instruct",  # Model identifier can be anything as server only loads one model
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Tell me a story"},
    ],
    max_tokens=100,
    temperature=0.7,
    top_p=0.95,
)
print(response.choices[0].message.content)
# Out:
# Once upon a time, in a small village nestled in the rolling hills of Provence, France, there lived a young girl named Sophie. Sophie was a curious and adventurous child, with a heart full of wonder and a mind full of questions. She loved to explore the world around her, and spent most of her days wandering through the fields and forests, discovering hidden streams and secret meadows.
#
# One day, while out on a walk, Sophie stumbled upon a small, mysterious shop tucked away in a

# %%
from huggingface_hub import InferenceClient

# Initialize client pointing to vLLM endpoint
client = InferenceClient(
    model="http://localhost:8080/v1",  # URL to the vLLM server
)

# Text generation
response = client.chat.completions.create(
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Tell me a story"},
    ],    
    max_tokens=100,
    temperature=0.7,
    top_p=0.95,
)
print(response.choices[0].message.content)
# Out:
# Once upon a time, in a small village nestled in the rolling hills of Tuscany, there was a young girl named Luna. Luna was a curious and adventurous soul, with a heart full of wonder and a mind full of questions. She lived with her wise and loving grandmother, Nonna Rosa, in a cozy little cottage surrounded by vineyards and olive groves.
#
# Nonna Rosa was a kind and gentle soul, with a deep understanding of the natural world and the magic that lay just beneath

# %%
# For chat format
response = client.chat.completions.create(
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Tell me a story"},
    ],
    max_tokens=100,
    temperature=0.7,
    top_p=0.95,
)
print(response.choices[0].message.content)
# Out:
# Once upon a time, in a small village nestled in the rolling hills of Provence, France, there lived a young girl named Sophie. Sophie was a curious and imaginative child, with a wild mane of curly brown hair and bright green eyes that sparkled like emeralds in the sunlight.
#
# Sophie lived with her grandmother, Madame Dupont, in a charming stone cottage surrounded by a lush garden filled with roses, lavender, and sunflowers. The village was famous for its beautiful pottery, and

# %%
from openai import OpenAI

# Initialize client pointing to vLLM endpoint
client = OpenAI(
    base_url="http://localhost:8080/v1",
    api_key="not-needed",  # vLLM doesn't require an API key by default
)

# Chat completion
response = client.chat.completions.create(
    model="HuggingFaceTB/SmolLM2-360M-Instruct",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Tell me a story"},
    ],
    max_tokens=100,
    temperature=0.7,
    top_p=0.95,
)
print(response.choices[0].message.content)
# Out:
# Once upon a time, in a small village nestled in the rolling hills of Tuscany, there lived a young girl named Luna. Luna was a curious and adventurous child, with a heart full of wonder and a mind full of questions. She loved to explore the world around her, and was always eager to learn new things.
#
# One day, while wandering through the village, Luna stumbled upon a small, mysterious shop tucked away on a quiet street. The sign above the door read "Curios and

# %%
from huggingface_hub import InferenceClient

client = InferenceClient(model="http://localhost:8080/v1")

# Advanced parameters example
response = client.chat.completions.create(
    messages=[
        {"role": "system", "content": "You are a creative storyteller."},
        {"role": "user", "content": "Write a creative story"},
    ],
    temperature=0.8,
    max_tokens=200,
    top_p=0.95,
)
print(response.choices[0].message.content)
# Out:
# In the sleepy town of Luminaria, where the moon dipped into the horizon and painted the sky with hues of sapphire and amethyst, a mystical bookstore stood nestled between two ancient oak trees. The sign above the door creaked in the gentle breeze, bearing the words "Moonlit Pages" in letters that shimmered like stardust.
#
# Ava, a young bibliophile with eyes as bright as the night sky, stumbled upon the bookstore one fateful evening. As she pushed open the door, a soft bell above it rang out, and the proprietor, an enigmatic woman named Lyra, looked up from behind the counter with an knowing smile.
#
# "Welcome, Ava," Lyra said, her voice as melodic as a nightingale's song. "I've been expecting you. You see, this bookstore is no ordinary establishment. We're a repository of lost tales, forgotten knowledge, and whispers from the cosmos itself."
#
# As Ava wandered the aisles, her fingers

# %%
# Raw text generation

response = client.chat_completion(
    messages=[
        {"role": "user", "content": "Write a creative story about space exploration"}
    ],
    max_tokens=200,
    temperature=0.8,
    top_p=0.95,
)

print(response.choices[0].message.content)
# Out:
# **The Quantum Prophecy**
#
# In the year 2178, humanity had finally achieved the impossible – sending a self-sustaining spacecraft, the Aurora, to the farthest reaches of the galaxy. The mission was led by the brilliant and enigmatic Captain Jaxon, a man with a vision for the future of space exploration.
#
# As the Aurora pierced through the cosmos, it encountered strange occurrences that defied explanation. Equipment malfunctioned, and strange energy readings appeared on the ship's sensors. It was as if the universe itself was trying to communicate with the crew.
#
# One night, while navigating through a swirling nebula, Captain Jaxon received a cryptic message from an unknown source. The message was encoded in an ancient language, but the ship's AI, EVE, managed to decipher the meaning.
#
# The message spoke of a hidden planet, hidden within the nebula, where the secrets of the universe lay waiting. The message was clear: the planet was guarded by an ancient civilization, and only those

# %%
from openai import OpenAI

client = OpenAI(base_url="http://localhost:8080/v1", api_key="not-needed")

# Advanced parameters example
response = client.chat.completions.create(
    model="HuggingFaceTB/SmolLM2-360M-Instruct",
    messages=[
        {"role": "system", "content": "You are a creative storyteller."},
        {"role": "user", "content": "Write a creative story"},
    ],
    temperature=0.8,  # Higher for more creativity
)
print(response.choices[0].message.content)
# Out:
# In the heart of a mystical forest, there existed a tiny village called Luminaria. The villagers of Luminaria were known for their extraordinary gift – the ability to weave the most breathtaking tapestries that seemed to come alive.
#
# Aurora, a young and talented weaver, was the most skilled among them. Her fingers danced with an ethereal touch, as she wove threads of silver, gold, and crystal into magnificent creations. Her tapestries told stories of ancient myths, whispered secrets, and hidden truths.
#
# One fateful evening, a stranger arrived in Luminaria. His name was Lyra, and he carried a mysterious box adorned with intricate symbols. The box seemed to radiate an otherworldly energy, and the villagers sensed that Lyra was not like any other traveler they had ever met.
#
# Aurora, intrigued by the stranger's presence, offered him shelter in her small cottage. As they sipped tea, Lyra revealed that he was a collector of forgotten memories. He possessed a magical loom that could weave the most vivid and poignant recollections into tangible tapestries.
#
# The villagers were skeptical, but Aurora saw the potential in Lyra's loom. She asked him to weave a tapestry of Luminaria's collective memories. Lyra agreed, and with the magical loom, he began to weave a stunning tapestry.
#
# As the threads danced across the loom, the tapestry came alive. Images of Luminaria's history unfolded: the birth of the forest, the ancient rituals, and the secrets hidden within the trees. The villagers watched in awe as their memories were transformed into a breathtaking work of art.
#
# However, as the tapestry grew, it began to reveal a darker aspect of Luminaria's past. A long-forgotten tragedy, hidden beneath the forest's surface, began to surface. The villagers were shocked to discover that their village was built upon a site of ancient sorrow.
#
# Aurora, Lyra, and the villagers realized that the tapestry was not just a simple weaving, but a key to unlocking the secrets of their own history. They decided to work together to unravel the mysteries hidden within the tapestry.
#
# With each passing night, the tapestry grew more vibrant, revealing the truth about Luminaria's past. The villagers learned that their village was built upon a site of ancient power, where a long-lost civilization had worshipped the forest spirits. The tragedy that had occurred was a result of a forbidden ritual that had disturbed the balance of nature.
#
# As the truth began to surface, the villagers came together to heal the wounds of their collective past. They performed a ritual of forgiveness and restoration, using the magical loom to weave a new tapestry – one of hope, renewal, and unity.
#
# The new tapestry shone brighter than any before, its threads infused with the essence of the forest. Aurora, Lyra, and the villagers knew that their village would never be the same, for they had discovered the true power of weaving memories into the fabric of reality.
#
# And so, Luminaria continued to thrive, its tapestries a testament to the magic that lay just beneath the surface of the mundane world. For in the heart of the mystical forest, memories were woven into reality, and the fabric of the world was forever changed.

# %%
from huggingface_hub import InferenceClient

client = InferenceClient(model="http://localhost:8080/v1", token="sk-no-key-required")

# Advanced parameters example
response = client.chat.completions.create(
    messages=[
        {"role": "system", "content": "You are a creative storyteller."},
        {"role": "user", "content": "Write a creative story"},
    ],
    temperature=0.8,
    max_tokens=200,
    top_p=0.95,
)
print(response.choices[0].message.content)
# Out:
# The Mysterious Library of Lost Dreams
#
# In the heart of the city, hidden behind a veil of fog and forgotten memories, lay a library like no other. The shelves stretched high into the air, lined with books that glowed with an ethereal light. These were no ordinary tomes, for each one contained a single, precious dream that had been lost to the sands of time.
#
# Aria, a young and curious soul, stumbled upon the library by chance. She had been wandering through the streets, searching for a refuge from the world's noise and distractions. As she pushed open the creaky door, a warm, golden light enveloped her, and she felt an inexplicable sense of belonging.
#
# The librarian, an enigmatic figure with eyes that shone like stars, greeted her with a knowing smile. "Welcome, Aria," he said, his voice as gentle as a summer breeze. "I have been expecting you. You have a thirst for the forgotten, a hunger

# %%
# For direct text generation
response = client.chat_completion(
    messages=[
        {"role": "user", "content": "Write a creative story about space exploration"}
    ],
    max_tokens=200,
    temperature=0.8,
    top_p=0.95,
)
print(response.choices[0].message.content)
# Out:
# **The Aurora Odyssey**
#
# In the year 2178, humanity had finally reached the stars. The United Earth Space Agency (UESA) had launched the most ambitious mission in history: the Aurora Odyssey. The spacecraft, named after the breathtaking natural light display of the aurora borealis, was designed to explore the mysteries of the cosmos.
#
# Commander Sarah Patel, a seasoned astronaut with a Ph.D. in astrophysics, stood at the helm of the Aurora, her eyes fixed on the vast expanse of space before her. The crew of six had been handpicked from the best of the best, each with their own unique expertise and passion for exploration.
#
# As the Aurora broke free of Earth's gravitational pull, the crew settled into their routine, conducting daily checks and maintenance tasks. But Sarah knew that the real adventure was only just beginning. Their first destination was the planet Kepler-62f, a stunning celestial body orbiting a nearby star.
#
# The journey was grueling, with long periods

# %%
from openai import OpenAI

client = OpenAI(base_url="http://localhost:8080/v1", api_key="sk-no-key-required")

# Advanced parameters example
response = client.chat.completions.create(
    model="smollm2-1.7b-instruct",
    messages=[
        {"role": "system", "content": "You are a creative storyteller."},
        {"role": "user", "content": "Write a creative story"},
    ],
    temperature=0.8,  # Higher for more creativity
    top_p=0.95,  # Nucleus sampling probability
    frequency_penalty=0.5,  # Reduce repetition of frequent tokens
    presence_penalty=0.5,  # Reduce repetition by penalizing tokens already present
    max_tokens=200,  # Maximum generation length
)
print(response.choices[0].message.content)
# Out:
# In the sleepy town of Luminaria, where the sun dipped into the horizon and painted the sky with hues of crimson and gold, there existed a mysterious shop known only as "Moonwhisper's Curios." The store was tucked away on a narrow street, its windows aglow with an ethereal light that seemed to beckon passersby to enter.
#
# No one knew much about the proprietor, Moonwhisper, except that she was an enigmatic figure with hair as black as the night sky and eyes that shone like stars. Her presence was both captivating and unnerving, like a siren luring sailors to their doom.
#
# Rumors swirled about Moonwhisper's abilities: some said she could communicate with the spirits of the dead, while others claimed she could weave magic into fabrics that would grant the wearer incredible powers. But one thing was certain – those who dared to enter Moonwhisper's Curios would never be the same again.
#
# One fateful evening,

# %%
# Using llama-cpp-python package for direct model access
from llama_cpp import Llama
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[79], line 2
#       1 # Using llama-cpp-python package for direct model access
# ----> 2 from llama_cpp import Llama
#
# ModuleNotFoundError: No module named 'llama_cpp'

# %%
# Load the model
llm = Llama(
    model_path="smollm2-1.7b-instruct.Q4_K_M.gguf",
    n_ctx=4096,  # Context window size
    n_threads=8,  # CPU threads
    n_gpu_layers=0,  # GPU layers (0 = CPU only)
)

# Format prompt according to the model's expected format
prompt = """<|im_start|>system
You are a creative storyteller.
<|im_end|>
<|im_start|>user
Write a creative story
<|im_end|>
<|im_start|>assistant
"""

# Generate response with precise parameter control
output = llm(
    prompt,
    max_tokens=200,
    temperature=0.8,
    top_p=0.95,
    frequency_penalty=0.5,
    presence_penalty=0.5,
    stop=["<|im_end|>"],
)

print(output["choices"][0]["text"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[77], line 2
#       1 # Using llama-cpp-python package for direct model access
# ----> 2 from llama_cpp import Llama
#       3
#       4 # Load the model
#       5 llm = Llama(
#
# ModuleNotFoundError: No module named 'llama_cpp'

# %%
from huggingface_hub import InferenceClient

client = InferenceClient(model="http://localhost:8080/v1")

# Advanced parameters example
response = client.chat_completion(
    messages=[
        {"role": "system", "content": "You are a creative storyteller."},
        {"role": "user", "content": "Write a creative story"},
    ],
    temperature=0.8,
    max_tokens=200,
    top_p=0.95,
)
print(response.choices[0].message.content)
# Out:
# In the heart of a mystical forest, where ancient trees whispered secrets to the wind, and fireflies danced like tiny lanterns, there existed a hidden village called Luminaria. It was a place where magic dwelled in every corner, and the air was sweet with the scent of enchanted blooms.
#
# In the midst of this enchanted land, there lived a young apprentice named Aria. She was a master weaver of tales, with hands that could shape the very fabric of reality. Aria's gift was rare and coveted, for it allowed her to weave narratives that brought people together, binding their hearts with an invisible thread of shared wonder.
#
# One fateful evening, as the stars began to twinkle in the sky like diamonds scattered across the velvet expanse, Aria received a mysterious invitation. The parchment was made of iridescent silk, and its words shimmered like moonlight on a summer's night:
#
# "Gather at the Old Oak Tree, where shadows dance and moonbeams play

# %%
# For direct text generation
response = client.chat_completion(
    # "Write a creative story about space exploration",
    messages=[
        {"role": "user", "content": "Write a creative story about space exploration"}
    ],
    max_tokens=200,
    temperature=0.8,
    top_p=0.95,
)
print(response.choices[0].message.content)
# Out:
# The stars shone brightly in the night sky as the spaceship Aurora pierced through the cosmos, leaving a trail of glittering stardust in its wake. On board, Captain Jaxon gazed out at the endless expanse of space, his heart filled with a sense of wonder and discovery.
#
# The Aurora was on a mission to explore the mysterious planet of Xylophia-IV, a world shrouded in legend and myth. For centuries, astronomers had searched for signs of life on this distant world, but none had ever returned.
#
# As the ship approached the planet, Captain Jaxon felt a thrill of excitement coursing through his veins. He had spent years studying the ancient texts and data that hinted at Xylophia-IV's incredible secrets. The planet was said to be home to a species of beings known as the Luminari, who possessed technology and knowledge beyond anything humanity had ever dreamed of.
#
# The Aurora landed softly on the planet's surface, sending up a plume

# %%
from openai import OpenAI

client = OpenAI(base_url="http://localhost:8080/v1", api_key="not-needed")

# Advanced parameters example
response = client.chat.completions.create(
    model="HuggingFaceTB/SmolLM2-360M-Instruct",
    messages=[
        {"role": "system", "content": "You are a creative storyteller."},
        {"role": "user", "content": "Write a creative story"},
    ],
    temperature=0.8,
    top_p=0.95,
    max_tokens=200,
)
print(response.choices[0].message.content)
# Out:
# In the heart of the mystical forest of Aethereia, where moonbeams danced with the whispers of ancient trees, there existed a tiny village called Luminaria. It was a place where dreams and reality intertwined, where the fabric of time was woven with threads of magic.
#
# In the center of the village, a young girl named Luna dwelled. Her eyes shone like the night sky, and her hair was as silver as the stars that twinkled above. Luna was no ordinary child; she possessed a gift – the ability to hear the whispers of the forest.
#
# One evening, as the sun dipped below the horizon, Luna decided to explore the woods. The air was alive with the soft rustling of leaves and the gentle chirping of crickets. She wandered deeper into the forest, her footsteps quiet on the moss-covered path. The trees seemed to lean in, as if sharing a secret, and the wind whispered tales of old in her ear.
#
# As she wandered, Luna stumbled

# %%
from vllm import LLM
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 from vllm import LLM
#
# File C:\PythonVM\env2\Lib\site-packages\vllm\__init__.py:70, in __getattr__(name)
#      68 if name in MODULE_ATTRS:
#      69     module_name, attr_name = MODULE_ATTRS[name].split(":")
# ---> 70     module = import_module(module_name, __package__)
#      71     return getattr(module, attr_name)
#      72 else:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3824.0_x64__qbz5n2kfra8p0\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File C:\PythonVM\env2\Lib\site-packages\vllm\entrypoints\llm.py:35
#      30 from vllm.config.quantization import QuantizationConfigArgs
#      31 from vllm.distributed.weight_transfer.base import (
#      32     WeightTransferInitRequest,
#      33     WeightTransferUpdateRequest,
#      34 )
# ---> 35 from vllm.engine.arg_utils import EngineArgs
#      36 from vllm.entrypoints.chat_utils import (
#      37     ChatCompletionMessageParam,
#      38     ChatTemplateContentFormatOption,
#      39     load_chat_template,
#      40 )
#      41 from vllm.entrypoints.generate.beam_search.offline import BeamSearchOfflineMixin
#
# File C:\PythonVM\env2\Lib\site-packages\vllm\engine\arg_utils.py:122
#     120 from vllm.utils.torch_utils import resolve_kv_cache_dtype_string
#     121 from vllm.v1.attention.backends.registry import AttentionBackendEnum
# --> 122 from vllm.v1.sample.logits_processor import LogitsProcessor
#     123 from vllm.version import __version__ as VLLM_VERSION
#     125 if TYPE_CHECKING:
#
# File C:\PythonVM\env2\Lib\site-packages\vllm\v1\sample\logits_processor\__init__.py:16
#      14 from vllm.logger import init_logger
#      15 from vllm.logits_process import LogitsProcessor as RequestLogitsProcessor
# ---> 16 from vllm.sampling_params import SamplingParams
#      17 from vllm.utils.torch_utils import guard_cuda_initialization
#      18 from vllm.v1.sample.logits_processor.builtin import (
#      19     LogitBiasLogitsProcessor,
#      20     MinPLogitsProcessor,
#      21     MinTokensLogitsProcessor,
#      22     process_dict_updates,
#      23 )
#
# File C:\PythonVM\env2\Lib\site-packages\vllm\sampling_params.py:23
#      21 from vllm.tokenizers import TokenizerLike
#      22 from vllm.utils.mistral import is_mistral_tokenizer
# ---> 23 from vllm.v1.serial_utils import PydanticMsgspecMixin
#      25 logger = init_logger(__name__)
#      27 _SAMPLING_EPS = 1e-5
#
# File C:\PythonVM\env2\Lib\site-packages\vllm\v1\serial_utils.py:37
#      25 from vllm.multimodal.inputs import (
#      26     BaseMultiModalField,
#      27     MultiModalBatchedField,
#    (...)     34     NestedTensors,
#      35 )
#      36 from vllm.utils.torch_utils import PIN_MEMORY
# ---> 37 from vllm.v1.utils import tensor_data
#      39 logger = init_logger(__name__)
#      41 CUSTOM_TYPE_PICKLE = 1
#
# File C:\PythonVM\env2\Lib\site-packages\vllm\v1\utils.py:26
#      16 from typing import (
#      17     TYPE_CHECKING,
#      18     Any,
#    (...)     22     overload,
#      23 )
#      25 import torch
# ---> 26 import uvloop
#      27 from torch.autograd.profiler import record_function
#      29 import vllm.envs as envs
#
# ModuleNotFoundError: No module named 'uvloop'

# %%
from vllm import LLM, SamplingParams

# Initialize the model with advanced parameters
llm = LLM(
    model="HuggingFaceTB/SmolLM2-360M-Instruct",
    gpu_memory_utilization=0.85,
    max_num_batched_tokens=8192,
    max_num_seqs=256,
    block_size=16,
)
# Out:
# INFO 08-22 23:42:55 [importing.py:88] Triton not installed or not compatible; certain GPU-related functions will not be available.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 from vllm import LLM, SamplingParams
#       2
#       3 # Initialize the model with advanced parameters
#       4 llm = LLM(
#
# File C:\PythonVM\env2\Lib\site-packages\vllm\__init__.py:70, in __getattr__(name)
#      68 if name in MODULE_ATTRS:
#      69     module_name, attr_name = MODULE_ATTRS[name].split(":")
# ---> 70     module = import_module(module_name, __package__)
#      71     return getattr(module, attr_name)
#      72 else:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3824.0_x64__qbz5n2kfra8p0\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File C:\PythonVM\env2\Lib\site-packages\vllm\entrypoints\llm.py:35
#      30 from vllm.config.quantization import QuantizationConfigArgs
#      31 from vllm.distributed.weight_transfer.base import (
#      32     WeightTransferInitRequest,
#      33     WeightTransferUpdateRequest,
#      34 )
# ---> 35 from vllm.engine.arg_utils import EngineArgs
#      36 from vllm.entrypoints.chat_utils import (
#      37     ChatCompletionMessageParam,
#      38     ChatTemplateContentFormatOption,
#      39     load_chat_template,
#      40 )
#      41 from vllm.entrypoints.generate.beam_search.offline import BeamSearchOfflineMixin
#
# File C:\PythonVM\env2\Lib\site-packages\vllm\engine\arg_utils.py:122
#     120 from vllm.utils.torch_utils import resolve_kv_cache_dtype_string
#     121 from vllm.v1.attention.backends.registry import AttentionBackendEnum
# --> 122 from vllm.v1.sample.logits_processor import LogitsProcessor
#     123 from vllm.version import __version__ as VLLM_VERSION
#     125 if TYPE_CHECKING:
#
# File C:\PythonVM\env2\Lib\site-packages\vllm\v1\sample\logits_processor\__init__.py:16
#      14 from vllm.logger import init_logger
#      15 from vllm.logits_process import LogitsProcessor as RequestLogitsProcessor
# ---> 16 from vllm.sampling_params import SamplingParams
#      17 from vllm.utils.torch_utils import guard_cuda_initialization
#      18 from vllm.v1.sample.logits_processor.builtin import (
#      19     LogitBiasLogitsProcessor,
#      20     MinPLogitsProcessor,
#      21     MinTokensLogitsProcessor,
#      22     process_dict_updates,
#      23 )
#
# File C:\PythonVM\env2\Lib\site-packages\vllm\sampling_params.py:23
#      21 from vllm.tokenizers import TokenizerLike
#      22 from vllm.utils.mistral import is_mistral_tokenizer
# ---> 23 from vllm.v1.serial_utils import PydanticMsgspecMixin
#      25 logger = init_logger(__name__)
#      27 _SAMPLING_EPS = 1e-5
#
# File C:\PythonVM\env2\Lib\site-packages\vllm\v1\serial_utils.py:37
#      25 from vllm.multimodal.inputs import (
#      26     BaseMultiModalField,
#      27     MultiModalBatchedField,
#    (...)     34     NestedTensors,
#      35 )
#      36 from vllm.utils.torch_utils import PIN_MEMORY
# ---> 37 from vllm.v1.utils import tensor_data
#      39 logger = init_logger(__name__)
#      41 CUSTOM_TYPE_PICKLE = 1
#
# File C:\PythonVM\env2\Lib\site-packages\vllm\v1\utils.py:26
#      16 from typing import (
#      17     TYPE_CHECKING,
#      18     Any,
#    (...)     22     overload,
#      23 )
#      25 import torch
# ---> 26 import uvloop
#      27 from torch.autograd.profiler import record_function
#      29 import vllm.envs as envs
#
# ModuleNotFoundError: No module named 'uvloop'

# %%
# Configure sampling parameters
sampling_params = SamplingParams(
    temperature=0.8,  # Higher for more creativity
    top_p=0.95,  # Consider top 95% probability mass
    max_tokens=100,  # Maximum length
    presence_penalty=1.1,  # Reduce repetition
    frequency_penalty=1.1,  # Reduce repetition
    stop=["\n\n", "###"],  # Stop sequences
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[86], line 2
#       1 # Configure sampling parameters
# ----> 2 sampling_params = SamplingParams(
#       3     temperature=0.8,  # Higher for more creativity
#       4     top_p=0.95,  # Consider top 95% probability mass
#       5     max_tokens=100,  # Maximum length
#
# NameError: name 'SamplingParams' is not defined

# %%
# Generate text
prompt = "Write a creative story"
outputs = llm.generate(prompt, sampling_params)
print(outputs[0].outputs[0].text)

# For chat-style interactions
chat_prompt = [
    {"role": "system", "content": "You are a creative storyteller."},
    {"role": "user", "content": "Write a creative story"},
]
formatted_prompt = llm.get_chat_template()(chat_prompt)  # Uses model's chat template
outputs = llm.generate(formatted_prompt, sampling_params)
print(outputs[0].outputs[0].text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[87], line 3
#       1 # Generate text
#       2 prompt = "Write a creative story"
# ----> 3 outputs = llm.generate(prompt, sampling_params)
#       4 print(outputs[0].outputs[0].text)
#       5
#       6 # For chat-style interactions
#
# NameError: name 'llm' is not defined

# %%
client.generate(
    "Write a creative story",
    temperature=0.8,  # Higher for more creativity
    top_p=0.95,  # Consider top 95% probability mass
    top_k=50,  # Consider top 50 tokens
    max_new_tokens=100,  # Maximum length
    repetition_penalty=1.1,  # Reduce repetition
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 client.generate(
#       2     "Write a creative story",
#       3     temperature=0.8,  # Higher for more creativity
#       4     top_p=0.95,  # Consider top 95% probability mass
#
# AttributeError: 'OpenAI' object has no attribute 'generate'

# %%
# Via OpenAI API compatibility
response = client.completions.create(
    model="smollm2-1.7b-instruct",  # Model name (can be any string for llama.cpp server)
    prompt="Write a creative story",
    temperature=0.8,  # Higher for more creativity
    top_p=0.95,  # Consider top 95% probability mass
    frequency_penalty=1.1,  # Reduce repetition
    presence_penalty=0.1,  # Reduce repetition
    max_tokens=100,  # Maximum length
)

# Via llama-cpp-python direct access
output = llm(
    "Write a creative story",
    temperature=0.8,
    top_p=0.95,
    top_k=50,
    max_tokens=100,
    repeat_penalty=1.1,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[89], line 13
#       9     max_tokens=100,  # Maximum length
#      10 )
#      11
#      12 # Via llama-cpp-python direct access
# ---> 13 output = llm(
#      14     "Write a creative story",
#      15     temperature=0.8,
#      16     top_p=0.95,
#
# NameError: name 'llm' is not defined

# %%
params = SamplingParams(
    temperature=0.8,  # Higher for more creativity
    top_p=0.95,  # Consider top 95% probability mass
    top_k=50,  # Consider top 50 tokens
    max_tokens=100,  # Maximum length
    presence_penalty=0.1,  # Reduce repetition
)
llm.generate("Write a creative story", sampling_params=params)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 params = SamplingParams(
#       2     temperature=0.8,  # Higher for more creativity
#       3     top_p=0.95,  # Consider top 95% probability mass
#       4     top_k=50,  # Consider top 50 tokens
#
# NameError: name 'SamplingParams' is not defined

# %%
client.generate(
    "Write a varied text",
    repetition_penalty=1.1,  # Penalize repeated tokens
    no_repeat_ngram_size=3,  # Prevent 3-gram repetition
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 client.generate(
#       2     "Write a varied text",
#       3     repetition_penalty=1.1,  # Penalize repeated tokens
#       4     no_repeat_ngram_size=3,  # Prevent 3-gram repetition
#
# AttributeError: 'OpenAI' object has no attribute 'generate'

# %%
# Via OpenAI API
response = client.completions.create(
    model="smollm2-1.7b-instruct",
    prompt="Write a varied text",
    frequency_penalty=1.1,  # Penalize frequent tokens
    presence_penalty=0.8,  # Penalize tokens already present
)

# Via direct library
output = llm(
    "Write a varied text",
    repeat_penalty=1.1,  # Penalize repeated tokens
    frequency_penalty=0.5,  # Additional frequency penalty
    presence_penalty=0.5,  # Additional presence penalty
)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Via OpenAI API
# ----> 2 response = client.completions.create(
#       3     model="smollm2-1.7b-instruct",
#       4     prompt="Write a varied text",
#       5     frequency_penalty=1.1,  # Penalize frequent tokens
#
# File C:\PythonVM\env2\Lib\site-packages\openai\_utils\_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File C:\PythonVM\env2\Lib\site-packages\openai\resources\completions.py:554, in Completions.create(self, model, prompt, best_of, echo, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, seed, stop, stream, stream_options, suffix, temperature, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     525 @required_args(["model", "prompt"], ["model", "prompt", "stream"])
#     526 def create(
#     527     self,
#    (...)    552     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     553 ) -> Completion | Stream[Completion]:
# --> 554     return self._post(
#     555         "/completions",
#     556         body=maybe_transform(
#     557             {
#     558                 "model": model,
#     559                 "prompt": prompt,
#     560                 "best_of": best_of,
#     561                 "echo": echo,
#     562                 "frequency_penalty": frequency_penalty,
#     563                 "logit_bias": logit_bias,
#     564                 "logprobs": logprobs,
#     565                 "max_tokens": max_tokens,
#     566                 "n": n,
#     567                 "presence_penalty": presence_penalty,
#     568                 "seed": seed,
#     569                 "stop": stop,
#     570                 "stream": stream,
#     571                 "stream_options": stream_options,
#     572                 "suffix": suffix,
#     573                 "temperature": temperature,
#     574                 "top_p": top_p,
#     575                 "user": user,
#     576             },
#     577             completion_create_params.CompletionCreateParamsStreaming
#     578             if stream
#     579             else completion_create_params.CompletionCreateParamsNonStreaming,
#     580         ),
#     581         options=make_request_options(
#     582             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     583         ),
#     584         cast_to=Completion,
#     585         stream=stream or False,
#     586         stream_cls=Stream[Completion],
#     587     )
#
# File C:\PythonVM\env2\Lib\site-packages\openai\_base_client.py:1314, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1305     warnings.warn(
#    1306         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1307         "Please pass raw bytes via the `content` parameter instead.",
#    1308         DeprecationWarning,
#    1309         stacklevel=2,
#    1310     )
#    1311 opts = FinalRequestOptions.construct(
#    1312     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1313 )
# -> 1314 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File C:\PythonVM\env2\Lib\site-packages\openai\_base_client.py:1087, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1084             err.response.read()
#    1086         log.debug("Re-raising status error")
# -> 1087         raise self._make_status_error_from_response(err.response) from None
#    1089     break
#    1091 assert response is not None, "could not resolve response (should never happen)"
#
# NotFoundError: Error code: 404

# %%
client.generate(
    "Generate a short paragraph",
    max_new_tokens=100,
    min_new_tokens=10,
    stop_sequences=["\n\n", "###"],
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 client.generate(
#       2     "Generate a short paragraph",
#       3     max_new_tokens=100,
#       4     min_new_tokens=10,
#
# AttributeError: 'OpenAI' object has no attribute 'generate'

# %%
# Via OpenAI API
response = client.completions.create(
    model="smollm2-1.7b-instruct",
    prompt="Generate a short paragraph",
    max_tokens=100,
    stop=["\n\n", "###"],
)

# Via direct library
output = llm("Generate a short paragraph", max_tokens=100, stop=["\n\n", "###"])
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[26], line 2
#       1 # Via OpenAI API
# ----> 2 response = client.completions.create(
#       3     model="smollm2-1.7b-instruct",
#       4     prompt="Generate a short paragraph",
#       5     max_tokens=100,
#
# File C:\PythonVM\env2\Lib\site-packages\openai\_utils\_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File C:\PythonVM\env2\Lib\site-packages\openai\resources\completions.py:554, in Completions.create(self, model, prompt, best_of, echo, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, seed, stop, stream, stream_options, suffix, temperature, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     525 @required_args(["model", "prompt"], ["model", "prompt", "stream"])
#     526 def create(
#     527     self,
#    (...)    552     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     553 ) -> Completion | Stream[Completion]:
# --> 554     return self._post(
#     555         "/completions",
#     556         body=maybe_transform(
#     557             {
#     558                 "model": model,
#     559                 "prompt": prompt,
#     560                 "best_of": best_of,
#     561                 "echo": echo,
#     562                 "frequency_penalty": frequency_penalty,
#     563                 "logit_bias": logit_bias,
#     564                 "logprobs": logprobs,
#     565                 "max_tokens": max_tokens,
#     566                 "n": n,
#     567                 "presence_penalty": presence_penalty,
#     568                 "seed": seed,
#     569                 "stop": stop,
#     570                 "stream": stream,
#     571                 "stream_options": stream_options,
#     572                 "suffix": suffix,
#     573                 "temperature": temperature,
#     574                 "top_p": top_p,
#     575                 "user": user,
#     576             },
#     577             completion_create_params.CompletionCreateParamsStreaming
#     578             if stream
#     579             else completion_create_params.CompletionCreateParamsNonStreaming,
#     580         ),
#     581         options=make_request_options(
#     582             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     583         ),
#     584         cast_to=Completion,
#     585         stream=stream or False,
#     586         stream_cls=Stream[Completion],
#     587     )
#
# File C:\PythonVM\env2\Lib\site-packages\openai\_base_client.py:1314, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1305     warnings.warn(
#    1306         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1307         "Please pass raw bytes via the `content` parameter instead.",
#    1308         DeprecationWarning,
#    1309         stacklevel=2,
#    1310     )
#    1311 opts = FinalRequestOptions.construct(
#    1312     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1313 )
# -> 1314 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File C:\PythonVM\env2\Lib\site-packages\openai\_base_client.py:1087, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1084             err.response.read()
#    1086         log.debug("Re-raising status error")
# -> 1087         raise self._make_status_error_from_response(err.response) from None
#    1089     break
#    1091 assert response is not None, "could not resolve response (should never happen)"
#
# NotFoundError: Error code: 404

# %%
params = SamplingParams(
    max_tokens=100,
    min_tokens=10,
    stop=["###", "\n\n"],
    ignore_eos=False,
    skip_special_tokens=True,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 params = SamplingParams(
#       2     max_tokens=100,
#       3     min_tokens=10,
#       4     stop=["###", "\n\n"],
#
# NameError: name 'SamplingParams' is not defined

# %%
# Docker deployment with memory optimization
docker run --gpus all -p 8080:80 \
    --shm-size 1g \
    ghcr.io/huggingface/text-generation-inference:latest \
    --model-id HuggingFaceTB/SmolLM2-1.7B-Instruct \
    --max-batch-total-tokens 8192 \
    --max-input-length 4096
# Out:
#   Cell In[28], line 3
#     --shm-size 1g \
#                ^
# SyntaxError: invalid decimal literal

# %%
from vllm.engine.arg_utils import AsyncEngineArgs

engine_args = AsyncEngineArgs(
    model="HuggingFaceTB/SmolLM2-1.7B-Instruct",
    gpu_memory_utilization=0.85,
    max_num_batched_tokens=8192,
    block_size=16,
)

llm = LLM(engine_args=engine_args)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 from vllm.engine.arg_utils import AsyncEngineArgs
#       2
#       3 engine_args = AsyncEngineArgs(
#       4     model="HuggingFaceTB/SmolLM2-1.7B-Instruct",
#
# File C:\PythonVM\env2\Lib\site-packages\vllm\engine\arg_utils.py:36
#      33 from typing_extensions import TypeIs
#      35 import vllm.envs as envs
# ---> 36 from vllm.config import (
#      37     AttentionConfig,
#      38     CacheConfig,
#      39     CompilationConfig,
#      40     ConfigType,
#      41     DeviceConfig,
#      42     DiffusionConfig,
#      43     ECTransferConfig,
#      44     EPLBConfig,
#      45     FaultToleranceConfig,
#      46     KernelConfig,
#      47     KVEventsConfig,
#      48     KVTransferConfig,
#      49     LoadConfig,
#      50     LoRAConfig,
#      51     MambaConfig,
#      52     ModelConfig,
#      53     MultiModalConfig,
#      54     ObservabilityConfig,
#      55     OffloadConfig,
#      56     ParallelConfig,
#      57     PoolerConfig,
#      58     PrefetchOffloadConfig,
#      59     ProfilerConfig,
#      60     ReasoningConfig,
#      61     SchedulerConfig,
#      62     SpeculativeConfig,
#      63     StructuredOutputsConfig,
#      64     UVAOffloadConfig,
#      65     VllmConfig,
#      66     WeightTransferConfig,
#      67     get_attr_docs,
#      68 )
#      69 from vllm.config.cache import (
#      70     CacheDType,
#      71     KVOffloadingBackend,
#    (...)     74     PrefixCachingHashAlgo,
#      75 )
#      76 from vllm.config.device import Device
#
# File C:\PythonVM\env2\Lib\site-packages\vllm\config\__init__.py:23
#      21 from vllm.config.lora import LoRAConfig
#      22 from vllm.config.mamba import MambaConfig
# ---> 23 from vllm.config.model import (
#      24     ModelConfig,
#      25     iter_architecture_defaults,
#      26     str_dtype_to_torch_dtype,
#      27     try_match_architecture_defaults,
#      28 )
#      29 from vllm.config.multimodal import MultiModalConfig
#      30 from vllm.config.observability import ObservabilityConfig
#
# File C:\PythonVM\env2\Lib\site-packages\vllm\config\model.py:25
#      17 from vllm.config.multimodal import (
#      18     MMCacheType,
#      19     MMEncoderTPMode,
#    (...)     22     MultiModalConfig,
#      23 )
#      24 from vllm.config.pooler import POOLER_CONFIG_LOG_FIELDS, PoolerConfig
# ---> 25 from vllm.config.quantization import QuantizationConfigArgs
#      26 from vllm.config.scheduler import RunnerType
#      27 from vllm.config.utils import config, getattr_iter
#
# File C:\PythonVM\env2\Lib\site-packages\vllm\config\quantization.py:10
#       7 from pydantic_core import core_schema
#       9 from vllm.config.utils import config
# ---> 10 from vllm.model_executor.layers.quantization.utils.quant_utils import (
#      11     QuantKey,
#      12     kFp8Dynamic128Sym,
#      13     kFp8DynamicTensorSym,
#      14     kFp8DynamicTokenSym,
#      15     kFp8Static128BlockSym,
#      16     kFp8StaticChannelSym,
#      17     kFp8StaticTensorSym,
#      18     kInt8StaticChannelSym,
#      19     kMxfp4Dynamic,
#      20     kMxfp8Dynamic,
#      21     kNvfp4Static,
#      22 )
#      24 # User-facing names addressable from quantization_config.
#      25 QUANT_KEY_NAMES: dict[str, QuantKey] = {
#      26     "fp8_per_tensor_static": kFp8StaticTensorSym,
#      27     "fp8_per_tensor_dynamic": kFp8DynamicTensorSym,
#    (...)     34     "int8_per_channel_static": kInt8StaticChannelSym,
#      35 }
#
# File C:\PythonVM\env2\Lib\site-packages\vllm\model_executor\layers\quantization\__init__.py:7
#       4 from typing import Literal, get_args
#       6 from vllm.logger import init_logger
# ----> 7 from vllm.model_executor.layers.quantization.base_config import QuantizationConfig
#       8 from vllm.platforms import current_platform
#      10 logger = init_logger(__name__)
#
# File C:\PythonVM\env2\Lib\site-packages\vllm\model_executor\layers\quantization\base_config.py:11
#       9 import torch
#      10 from torch import nn
# ---> 11 from transformers import PretrainedConfig
#      13 if TYPE_CHECKING:
#      14     from vllm.model_executor.layers.quantization import QuantizationMethods
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\__init__.py:808
#     805 else:
#     806     _import_structure = {k: set(v) for k, v in _import_structure.items()}
# --> 808     import_structure = define_import_structure(Path(__file__).parent / "models", prefix="models")
#     809     import_structure[frozenset({})].update(_import_structure)
#     811     sys.modules[__name__] = _LazyModule(
#     812         __name__,
#     813         globals()["__file__"],
#    (...)    816         extra_objects={"__version__": __version__},
#     817     )
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\utils\import_utils.py:3310, in define_import_structure(module_path, prefix)
#    3286 @lru_cache
#    3287 def define_import_structure(module_path: str, prefix: str | None = None) -> IMPORT_STRUCTURE_T:
#    3288     """
#    3289     This method takes a module_path as input and creates an import structure digestible by a _LazyModule.
#    3290
#    (...)   3308     If `prefix` is not None, it will add that prefix to all keys in the returned dict.
#    3309     """
# -> 3310     import_structure = create_import_structure_from_path(module_path)
#    3311     spread_dict = spread_import_structure(import_structure)
#    3313     if prefix is None:
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\utils\import_utils.py:3027, in create_import_structure_from_path(module_path)
#    3025     continue
#    3026 if entry.is_dir():
# -> 3027     import_structure[entry.name] = create_import_structure_from_path(entry.path)
#    3028 elif not entry.name.startswith(("convert_", "modular_")):
#    3029     adjacent_modules.append(entry.name)
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\utils\import_utils.py:3043, in create_import_structure_from_path(module_path)
#    3040 if not module_name.endswith(".py"):
#    3041     continue
# -> 3043 with open(os.path.join(module_path, module_name), encoding="utf-8") as f:
#    3044     file_content = f.read()
#    3046 # Remove the .py suffix
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3824.0_x64__qbz5n2kfra8p0\Lib\codecs.py:312, in BufferedIncrementalDecoder.__init__(self, errors)
#     306 class BufferedIncrementalDecoder(IncrementalDecoder):
#     307     """
#     308     This subclass of IncrementalDecoder can be used as the baseclass for an
#     309     incremental decoder if the decoder must be able to handle incomplete
#     310     byte sequences.
#     311     """
# --> 312     def __init__(self, errors='strict'):
#     313         IncrementalDecoder.__init__(self, errors)
#     314         # undecoded input that is kept between calls to decode()
#
# KeyboardInterrupt:
