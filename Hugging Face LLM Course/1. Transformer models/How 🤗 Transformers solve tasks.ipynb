# %%
from transformers import pipeline

transcriber = pipeline(
    task="automatic-speech-recognition", model="openai/whisper-base.en"
)
transcriber("https://huggingface.co/datasets/Narsil/asr_dummy/resolve/main/mlk.flac")
# Output: {'text': ' I have a dream that one day this nation will rise up and live out the true meaning of its creed.'}
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 0.00B [00:00, ?B/s]
# C:\PythonVM\env2\Lib\site-packages\huggingface_hub\file_download.py:138: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\satish.a.waghmare\.cache\huggingface\hub\models--openai--whisper-base.en. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors:   0%|          | 0.00/290M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/245 [00:00<?, ?it/s]
# generation_config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/805 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# normalizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# preprocessor_config.json: 0.00B [00:00, ?B/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\audio_utils.py:33, in ffmpeg_read(bpayload, sampling_rate)
#      32 try:
# ---> 33     with subprocess.Popen(ffmpeg_command, stdin=subprocess.PIPE, stdout=subprocess.PIPE) as ffmpeg_process:
#      34         output_stream = ffmpeg_process.communicate(bpayload)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3824.0_x64__qbz5n2kfra8p0\Lib\subprocess.py:1039, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1036             self.stderr = io.TextIOWrapper(self.stderr,
#    1037                     encoding=encoding, errors=errors)
# -> 1039     self._execute_child(args, executable, preexec_fn, close_fds,
#    1040                         pass_fds, cwd, env,
#    1041                         startupinfo, creationflags, shell,
#    1042                         p2cread, p2cwrite,
#    1043                         c2pread, c2pwrite,
#    1044                         errread, errwrite,
#    1045                         restore_signals,
#    1046                         gid, gids, uid, umask,
#    1047                         start_new_session, process_group)
#    1048 except:
#    1049     # Cleanup if the child failed starting.
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3824.0_x64__qbz5n2kfra8p0\Lib\subprocess.py:1554, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1553 try:
# -> 1554     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1555                              # no special security
#    1556                              None, None,
#    1557                              int(not close_fds),
#    1558                              creationflags,
#    1559                              env,
#    1560                              cwd,
#    1561                              startupinfo)
#    1562 finally:
#    1563     # Child is launched. Close the parent's copy of those pipe
#    1564     # handles that only the child should have open.  You need
#    (...)   1567     # pipe will not close when the child process exits and the
#    1568     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 6
#       2
#       3 transcriber = pipeline(
#       4     task="automatic-speech-recognition", model="openai/whisper-base.en"
#       5 )
# ----> 6 transcriber("https://huggingface.co/datasets/Narsil/asr_dummy/resolve/main/mlk.flac")
#       7 # Output: {'text': ' I have a dream that one day this nation will rise up and live out the true meaning of its creed.'}
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\automatic_speech_recognition.py:247, in AutomaticSpeechRecognitionPipeline.__call__(self, inputs, **kwargs)
#     190 def __call__(self, inputs: np.ndarray | bytes | str | dict, **kwargs: Any) -> list[dict[str, Any]]:
#     191     """
#     192     Transcribe the audio sequence(s) given as inputs to text. See the [`AutomaticSpeechRecognitionPipeline`]
#     193     documentation for more information.
#    (...)    245                 `"".join(chunk["text"] for chunk in output["chunks"])`.
#     246     """
# --> 247     return super().__call__(inputs, **kwargs)
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\base.py:1286, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1282     return self.get_iterator(
#    1283         inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1284     )
#    1285 elif isinstance(self, ChunkPipeline):
# -> 1286     return next(
#    1287         iter(
#    1288             self.get_iterator(
#    1289                 [inputs], num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1290             )
#    1291         )
#    1292     )
#    1293 else:
#    1294     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\pt_utils.py:126, in PipelineIterator.__next__(self)
#     123     return self.loader_batch_item()
#     125 # We're out of items within a batch
# --> 126 item = next(self.iterator)
#     127 processed = self.infer(item, **self.params)
#     128 # We now have a batch of "inferred things".
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\pt_utils.py:271, in PipelinePackIterator.__next__(self)
#     268             return accumulator
#     270 while not is_last:
# --> 271     processed = self.infer(next(self.iterator), **self.params)
#     272     if self.loader_batch_size is not None:
#     273         if isinstance(processed, torch.Tensor):
#
# File C:\PythonVM\env2\Lib\site-packages\torch\utils\data\dataloader.py:725, in _BaseDataLoaderIter.__next__(self)
#     722 if self._sampler_iter is None:
#     723     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     724     self._reset()  # type: ignore[call-arg]
# --> 725 data = self._next_data()
#     726 self._num_yielded += 1
#     727 if (
#     728     self._dataset_kind == _DatasetKind.Iterable
#     729     and self._IterableDataset_len_called is not None
#     730     and self._num_yielded > self._IterableDataset_len_called
#     731 ):
#
# File C:\PythonVM\env2\Lib\site-packages\torch\utils\data\dataloader.py:785, in _SingleProcessDataLoaderIter._next_data(self)
#     783 def _next_data(self):
#     784     index = self._next_index()  # may raise StopIteration
# --> 785     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     786     if self._pin_memory:
#     787         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File C:\PythonVM\env2\Lib\site-packages\torch\utils\data\_utils\fetch.py:35, in _IterableDatasetFetcher.fetch(self, possibly_batched_index)
#      33 for _ in possibly_batched_index:
#      34     try:
# ---> 35         data.append(next(self.dataset_iter))
#      36     except StopIteration:
#      37         self.ended = True
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\pt_utils.py:188, in PipelineChunkIterator.__next__(self)
#     185     self.subiterator = self.infer(next(self.iterator), **self.params)
#     186 try:
#     187     # Try to return next item
# --> 188     processed = next(self.subiterator)
#     189 except StopIteration:
#     190     # When a preprocess iterator ends, we can start looking at the next item
#     191     # ChunkIterator will keep feeding until ALL elements of iterator
#    (...)    194     # Another way to look at it, is we're basically flattening lists of lists
#     195     # into a single list, but with generators
#     196     self.subiterator = self.infer(next(self.iterator), **self.params)
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\automatic_speech_recognition.py:356, in AutomaticSpeechRecognitionPipeline.preprocess(self, inputs, chunk_length_s, stride_length_s)
#     353             inputs = f.read()
#     355 if isinstance(inputs, bytes):
# --> 356     inputs = ffmpeg_read(inputs, self.feature_extractor.sampling_rate)
#     358 stride = None
#     359 extra = {}
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\audio_utils.py:36, in ffmpeg_read(bpayload, sampling_rate)
#      34         output_stream = ffmpeg_process.communicate(bpayload)
#      35 except FileNotFoundError as error:
# ---> 36     raise ValueError("ffmpeg was not found but is required to load audio files from filename") from error
#      37 out_bytes = output_stream[0]
#      38 audio = np.frombuffer(out_bytes, np.float32)
#
# ValueError: ffmpeg was not found but is required to load audio files from filename

# %%
# !pip install codecarbon
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting codecarbon
#   Downloading codecarbon-3.3.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: arrow in C:\PythonVM\env2\Lib\site-packages (from codecarbon) (1.4.0)
# Collecting authlib>=1.2.1 (from codecarbon)
#   Downloading authlib-1.7.2-py2.py3-none-any.whl.metadata (10 kB)
# Collecting joserfc>=1.0.0 (from codecarbon)
#   Downloading joserfc-1.7.4-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: click in C:\PythonVM\env2\Lib\site-packages (from codecarbon) (8.1.8)
# Requirement already satisfied: pandas in C:\PythonVM\env2\Lib\site-packages (from codecarbon) (3.0.2)
# Requirement already satisfied: prometheus_client in C:\PythonVM\env2\Lib\site-packages (from codecarbon) (0.25.0)
# Requirement already satisfied: psutil>=6.0.0 in C:\PythonVM\env2\Lib\site-packages (from codecarbon) (7.2.2)
# Collecting py-cpuinfo (from codecarbon)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in C:\PythonVM\env2\Lib\site-packages (from codecarbon) (2.12.5)
# Collecting nvidia-ml-py (from codecarbon)
#   Downloading nvidia_ml_py-13.610.43-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: rapidfuzz in C:\PythonVM\env2\Lib\site-packages (from codecarbon) (3.14.5)
# Requirement already satisfied: requests in C:\PythonVM\env2\Lib\site-packages (from codecarbon) (2.33.1)
# Collecting questionary (from codecarbon)
#   Downloading questionary-2.1.1-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: rich in C:\PythonVM\env2\Lib\site-packages (from codecarbon) (14.3.4)
# Requirement already satisfied: typer in C:\PythonVM\env2\Lib\site-packages (from codecarbon) (0.23.1)
# Collecting pycountry (from codecarbon)
#   Downloading pycountry-26.2.16-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\PythonVM\env2\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->codecarbon) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\PythonVM\env2\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->codecarbon) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in C:\PythonVM\env2\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->codecarbon) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\PythonVM\env2\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->codecarbon) (0.4.2)
# Requirement already satisfied: cryptography in C:\PythonVM\env2\Lib\site-packages (from authlib>=1.2.1->codecarbon) (46.0.7)
# Requirement already satisfied: cffi>=2.0.0 in C:\PythonVM\env2\Lib\site-packages (from cryptography->authlib>=1.2.1->codecarbon) (2.0.0)
# Requirement already satisfied: pycparser in C:\PythonVM\env2\Lib\site-packages (from cffi>=2.0.0->cryptography->authlib>=1.2.1->codecarbon) (3.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in C:\PythonVM\env2\Lib\site-packages (from arrow->codecarbon) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\PythonVM\env2\Lib\site-packages (from arrow->codecarbon) (2026.1)
# Requirement already satisfied: six>=1.5 in C:\PythonVM\env2\Lib\site-packages (from python-dateutil>=2.7.0->arrow->codecarbon) (1.17.0)
# Requirement already satisfied: colorama in C:\PythonVM\env2\Lib\site-packages (from click->codecarbon) (0.4.6)
# Requirement already satisfied: numpy>=1.26.0 in C:\PythonVM\env2\Lib\site-packages (from pandas->codecarbon) (2.4.4)
# Requirement already satisfied: prompt_toolkit<4.0,>=2.0 in C:\PythonVM\env2\Lib\site-packages (from questionary->codecarbon) (3.0.52)
# Requirement already satisfied: wcwidth in C:\PythonVM\env2\Lib\site-packages (from prompt_toolkit<4.0,>=2.0->questionary->codecarbon) (0.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\PythonVM\env2\Lib\site-packages (from requests->codecarbon) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\PythonVM\env2\Lib\site-packages (from requests->codecarbon) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\PythonVM\env2\Lib\site-packages (from requests->codecarbon) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in C:\PythonVM\env2\Lib\site-packages (from requests->codecarbon) (2026.2.25)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\PythonVM\env2\Lib\site-packages (from rich->codecarbon) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\PythonVM\env2\Lib\site-packages (from rich->codecarbon) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\PythonVM\env2\Lib\site-packages (from markdown-it-py>=2.2.0->rich->codecarbon) (0.1.2)
# Requirement already satisfied: shellingham>=1.3.0 in C:\PythonVM\env2\Lib\site-packages (from typer->codecarbon) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\PythonVM\env2\Lib\site-packages (from typer->codecarbon) (0.0.4)
# Downloading codecarbon-3.3.0-py3-none-any.whl (396 kB)
# Downloading authlib-1.7.2-py2.py3-none-any.whl (259 kB)
# Downloading joserfc-1.7.4-py3-none-any.whl (71 kB)
# Downloading nvidia_ml_py-13.610.43-py3-none-any.whl (53 kB)
# Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Downloading pycountry-26.2.16-py3-none-any.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ------- -------------------------------- 1.6/8.0 MB 8.8 MB/s eta 0:00:01
#    ------------- -------------------------- 2.6/8.0 MB 7.2 MB/s eta 0:00:01
#    -------------------- ------------------- 4.2/8.0 MB 6.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.0/8.0 MB 7.1 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.0 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 7.5 MB/s  0:00:01
# Downloading questionary-2.1.1-py3-none-any.whl (36 kB)
# Installing collected packages: py-cpuinfo, nvidia-ml-py, pycountry, questionary, joserfc, authlib, codecarbon
#
#    ---------------------------------------- 0/7 [py-cpuinfo]
#    ---------------------------------------- 0/7 [py-cpuinfo]
#    ---------------------------------------- 0/7 [py-cpuinfo]
#    ---------------------------------------- 0/7 [py-cpuinfo]
#    ----- ---------------------------------- 1/7 [nvidia-ml-py]
#    ----- ---------------------------------- 1/7 [nvidia-ml-py]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------- ---------------------------- 2/7 [pycountry]
#    ----------------- ---------------------- 3/7 [questionary]
#    ----------------- ---------------------- 3/7 [questionary]
#    ----------------- ---------------------- 3/7 [questionary]
#    ----------------- ---------------------- 3/7 [questionary]
#    ----------------- ---------------------- 3/7 [questionary]
#    ----------------- ---------------------- 3/7 [questionary]
#    ----------------- ---------------------- 3/7 [questionary]
#    ----------------- ---------------------- 3/7 [questionary]
#    ----------------- ---------------------- 3/7 [questionary]
#    ----------------- ---------------------- 3/7 [questionary]
#    ----------------- ---------------------- 3/7 [questionary]
#    ----------------- ---------------------- 3/7 [questionary]
#    ----------------- ---------------------- 3/7 [questionary]
#    ----------------- ---------------------- 3/7 [questionary]
#    ----------------- ---------------------- 3/7 [questionary]
#    ----------------- ---------------------- 3/7 [questionary]
#    ----------------- ---------------------- 3/7 [questionary]
#    ----------------- ---------------------- 3/7 [questionary]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------- ----------------- 4/7 [joserfc]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------- ----------- 5/7 [authlib]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------- ----- 6/7 [codecarbon]
#    ---------------------------------------- 7/7 [codecarbon]
#
# Successfully installed authlib-1.7.2 codecarbon-3.3.0 joserfc-1.7.4 nvidia-ml-py-13.610.43 py-cpuinfo-9.0.0 pycountry-26.2.16 questionary-2.1.1
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /codecarbon/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /codecarbon/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /codecarbon/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /codecarbon/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /codecarbon/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /authlib/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /authlib/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /authlib/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /authlib/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /authlib/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /joserfc/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /joserfc/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /joserfc/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /joserfc/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /joserfc/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /py-cpuinfo/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /py-cpuinfo/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /py-cpuinfo/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /py-cpuinfo/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /py-cpuinfo/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /nvidia-ml-py/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /nvidia-ml-py/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /nvidia-ml-py/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /nvidia-ml-py/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /nvidia-ml-py/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /questionary/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /questionary/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /questionary/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /questionary/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /questionary/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /pycountry/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /pycountry/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /pycountry/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /pycountry/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /pycountry/
#
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install --upgrade pip
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: pip in C:\PythonVM\env2\Lib\site-packages (26.1.1)
# Collecting pip
#   Downloading pip-26.2.1-py3-none-any.whl.metadata (4.6 kB)
# Downloading pip-26.2.1-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------------------- ---------------- 1.0/1.8 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 9.4 MB/s  0:00:00
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /pip/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /pip/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /pip/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /pip/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /pip/
# ERROR: To modify pip, please run the following command:
# C:\PythonVM\env2\Scripts\python.exe -m pip install --upgrade pip

# %%
from codecarbon import EmissionsTracker

# %%
tracker = EmissionsTracker()
# Out:
# [codecarbon WARNING @ 01:00:01] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 01:00:22] Emissions data (if any) will be saved to file C:\PythonVM\LLM\LLM Course\1. Transformer models\emissions.csv

# %%
tracker.start()
# Out:
# [codecarbon INFO @ 01:00:37] [setup] RAM Tracking...
# [codecarbon INFO @ 01:00:37] [setup] CPU Tracking...
# [codecarbon INFO @ 01:00:37] [setup] GPU Tracking...
# [codecarbon INFO @ 01:00:37] No GPU found.
# [codecarbon INFO @ 01:00:38] Tracking CPU via the Windows Energy Meter Interface (RAPL)
# [codecarbon INFO @ 01:00:48] The below tracking methods have been set up:
#                 RAM Tracking Method: RAM power estimation model
#                 CPU Tracking Method: Windows EMI
#                 GPU Tracking Method: Unspecified
#
# [codecarbon INFO @ 01:00:48] >>> Tracker's metadata:
# [codecarbon INFO @ 01:00:48]   Platform system: Windows-11-10.0.26200-SP0
# [codecarbon INFO @ 01:00:48]   Python version: 3.13.14
# [codecarbon INFO @ 01:00:48]   CodeCarbon version: 3.3.0
# [codecarbon INFO @ 01:00:48]   Available RAM : 15.779 GB
# [codecarbon INFO @ 01:00:48]   CPU count: 8 thread(s) in 1 physical CPU(s)
# [codecarbon INFO @ 01:00:48]   CPU model: Intel(R) Core(TM) i5-10310U CPU @ 1.70GHz
# [codecarbon INFO @ 01:00:48]   GPU count: 0
# [codecarbon INFO @ 01:00:48]   GPU model:
# [codecarbon INFO @ 01:00:48] Energy consumed for RAM : 0.000000 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 01:00:48] Delta energy consumed for CPU with windows_emi : 0.000000 kWh, power : 1.7376563212154095 W
# [codecarbon INFO @ 01:00:48] Energy consumed for All CPU : 0.000000 kWh
# [codecarbon INFO @ 01:00:48] 0.000000 kWh of electricity and 0.000000 L of water were used since the beginning.

# %%
tracker.stop()
# Out:
# [codecarbon INFO @ 01:00:55] Energy consumed for RAM : 0.000019 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 01:00:55] Delta energy consumed for CPU with windows_emi : 0.000021 kWh, power : 3.089203445967686 W
# [codecarbon INFO @ 01:00:55] Energy consumed for All CPU : 0.000021 kWh
# [codecarbon INFO @ 01:00:55] 0.000040 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon WARNING @ 01:00:56] Unable to access geographical location through primary API. Will resort to using the backup API - Exception : HTTPSConnectionPool(host='get.geojs.io', port=443): Read timed out. (read timeout=0.5) - url=https://get.geojs.io/v1/ip/geo.json
# 4.883835298304184e-06
