# %%
from transformers import pipeline

# %%
# !pip install torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: torch in C:\PythonVM\env2\Lib\site-packages (2.13.0)
# Requirement already satisfied: filelock in C:\PythonVM\env2\Lib\site-packages (from torch) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\PythonVM\env2\Lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools>=77.0.3 in C:\PythonVM\env2\Lib\site-packages (from torch) (82.0.1)
# Requirement already satisfied: sympy>=1.13.3 in C:\PythonVM\env2\Lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\PythonVM\env2\Lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in C:\PythonVM\env2\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in C:\PythonVM\env2\Lib\site-packages (from torch) (2026.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\PythonVM\env2\Lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\PythonVM\env2\Lib\site-packages (from jinja2->torch) (3.0.3)
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install --upgrade pip
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: pip in C:\PythonVM\env2\Lib\site-packages (26.1.1)
# Collecting pip
#   Downloading pip-26.2.1-py3-none-any.whl.metadata (4.6 kB)
# Downloading pip-26.2.1-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 4.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.3/1.8 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 3.8 MB/s  0:00:00
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /pip/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /pip/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /pip/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /pip/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /pip/
# ERROR: To modify pip, please run the following command:
# C:\PythonVM\env2\Scripts\python.exe -m pip install --upgrade pip

# %%
# import os
# print(os.getcwd())
# Out:
# C:\PythonVM\LLM\LLM Course\1. Transformer models

# %%
# import sys
# print(sys.path[:5])
# Out:
# ['C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.13_3.13.3824.0_x64__qbz5n2kfra8p0\\python313.zip', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.13_3.13.3824.0_x64__qbz5n2kfra8p0\\DLLs', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.13_3.13.3824.0_x64__qbz5n2kfra8p0\\Lib', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.13_3.13.3824.0_x64__qbz5n2kfra8p0', 'C:\\PythonVM\\env2']

# %%
import torch
# print(torch.__version__)

# %%
from transformers import pipeline

generator = pipeline(
    "text-generation",
    model="distilgpt2",
)

generator("In this course, we will teach you how to", max_length=10, num_return_sequences=2)
# Out:
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# [transformers] Passing `generation_config` together with generation-related arguments=({'max_length', 'num_return_sequences'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=10) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer GPT2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# [{'generated_text': 'In this course, we will teach you how to properly manage your data. We will even give you a chance to explore our solutions to all of these issues.\n\n\n\n\n\nAfter the course, you can choose to choose a different approach to managing your data. You can either use a new model or a new model.\nWe will make sure you are aware that a lot of your data is going to be stored in a datacenter in your data center.\nWe will use this knowledge to learn how to manage your data.\nWe will build your data plan using the following techniques:\nWe will create your data plan using the following approach:\nWe will create your data plan using the following method:\nWe will create your data plan using the following approach:\nWe will create your data plan using the following method:\nWe will create your data plan using the following approach:\nWe will create your data plan using the following method:\nThere are many different ways to manage your data, but each method has different advantages. We will use these methods to manage your data, and then create your data plan using the following approach:\nWe will create your data plan using the following method:\nWe will create your data plan using the following method:\nWe will create your data plan using the'},
#  {'generated_text': "In this course, we will teach you how to be a better person.\n\n\n\nThis course will be a three-part class.\nWe will talk about many things you can do to improve your own health.\nYou may not know how to do that, but you know how to do it. We will start off with the basics, and then we'll walk you through how to learn how to do it.\nWe will talk about how to deal with mental problems, and how to help your mental health.\nWe will also talk about how to be a better person.\nIt will take an hour, but it will take about 10 minutes.\nYou will also get about two hours of basic yoga, followed by two sessions.\nYou will also get about two hours of basic yoga, followed by two sessions.\nYou will also get about two hours of basic yoga, followed by two sessions.\nYou will also get about two hours of basic yoga, followed by two sessions.\nYou will also get about two hours of basic yoga, followed by two sessions.\nYou will also get about two hours of basic yoga, followed by two sessions.\nYou will also get about two hours of basic yoga, followed by two sessions.\nYou will also get about two hours of basic yoga, followed"}]

# %%
# dir torch.py

# %%
classifier = pipeline(
    "sentiment-analysis",
    model="distilbert/distilbert-base-uncased-finetuned-sst-2-english"
    # revision="714eb0f"
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 classifier = pipeline(
#       2     "sentiment-analysis",
#       3     model="distilbert/distilbert-base-uncased-finetuned-sst-2-english"
#       4     # revision="714eb0f"
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\__init__.py:1033, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, video_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1031 if isinstance(model, str):
#    1032     model_classes = targeted_task["pt"]
# -> 1033     model = load_model(
#    1034         adapter_path if adapter_path is not None else model,
#    1035         model_classes=model_classes,
#    1036         config=config,
#    1037         task=task,
#    1038         **hub_kwargs,
#    1039         **model_kwargs,
#    1040     )
#    1042 hub_kwargs["_commit_hash"] = model.config._commit_hash
#    1044 if pipeline_class is None:
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\base.py:241, in load_model(model, config, model_classes, task, **model_kwargs)
#     238 kwargs = model_kwargs.copy()
#     240 try:
# --> 241     model = model_class.from_pretrained(model, **kwargs)
#     242     # Stop loading on the first successful load.
#     243     break
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\models\auto\auto_factory.py:402, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     400         if parent_quant is not None:
#     401             config.quantization_config = parent_quant
# --> 402     return model_class.from_pretrained(
#     403         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     404     )
#     405 raise ValueError(
#     406     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     407     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping)}."
#     408 )
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\modeling_utils.py:4248, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, fusion_config, disable_mmap, *model_args, **kwargs)
#    4243     logger.warning_once(
#    4244         "A kernel_config was provided but use_kernels is False; setting use_kernels=True automatically. To suppress this warning, explicitly set use_kernels to True."
#    4245     )
#    4246     use_kernels = True
# -> 4248 checkpoint_files, sharded_metadata = _get_resolved_checkpoint_files(
#    4249     pretrained_model_name_or_path=pretrained_model_name_or_path,
#    4250     variant=variant,
#    4251     gguf_file=gguf_file,
#    4252     use_safetensors=use_safetensors,
#    4253     download_kwargs=download_kwargs_with_commit,
#    4254     user_agent=user_agent,
#    4255     is_remote_code=cls.is_remote_code(),
#    4256     transformers_explicit_filename=getattr(config, "transformers_weights", None),
#    4257     tqdm_class=tqdm_class,
#    4258 )
#    4260 is_quantized = hf_quantizer is not None
#    4262 # Find the correct dtype based on current state
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\modeling_utils.py:677, in _get_resolved_checkpoint_files(pretrained_model_name_or_path, variant, gguf_file, use_safetensors, user_agent, is_remote_code, transformers_explicit_filename, download_kwargs, tqdm_class)
#     665 can_auto_convert = (
#     666     not is_offline_mode()  # for obvious reasons
#     667     # If we are in a CI environment or in a pytest run, we prevent the conversion
#    (...)    670     and subfolder == ""  # converter bot does not work on subfolders
#     671 )
#     673 try:
#     674     # Load from URL or cache if already cached
#     675     # Since we set _raise_exceptions_for_missing_entries=False, we don't get an exception but a None
#     676     # result when internet is up, the repo and revision exist, but the file does not.
# --> 677     resolved_archive_file = cached_file(pretrained_model_name_or_path, filename, **cached_file_kwargs)
#     679     # Try safetensors files first if not already found
#     680     if resolved_archive_file is None and filename == _add_variant(SAFE_WEIGHTS_NAME, variant):
#     681         # Maybe the checkpoint is sharded, we try to grab the index name in this case.
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\utils\hub.py:294, in cached_file(path_or_repo_id, filename, **kwargs)
#     239 def cached_file(
#     240     path_or_repo_id: str | os.PathLike,
#     241     filename: str,
#     242     **kwargs,
#     243 ) -> str | None:
#     244     """
#     245     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     246
#    (...)    292     ```
#     293     """
# --> 294     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     295     file = file[0] if file is not None else file
#     296     return file
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\utils\hub.py:438, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     435 try:
#     436     if len(full_filenames) == 1:
#     437         # This is slightly better for only 1 file
# --> 438         hf_hub_download(
#     439             path_or_repo_id,
#     440             filenames[0],
#     441             subfolder=None if len(subfolder) == 0 else subfolder,
#     442             repo_type=repo_type,
#     443             revision=revision,
#     444             cache_dir=cache_dir,
#     445             user_agent=user_agent,
#     446             force_download=force_download,
#     447             proxies=proxies,
#     448             token=token,
#     449             local_files_only=local_files_only,
#     450             tqdm_class=tqdm_class,
#     451         )
#     452     else:
#     453         snapshot_download(
#     454             path_or_repo_id,
#     455             allow_patterns=full_filenames,
#    (...)    464             tqdm_class=tqdm_class,
#     465         )
#
# File C:\PythonVM\env2\Lib\site-packages\huggingface_hub\utils\_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File C:\PythonVM\env2\Lib\site-packages\huggingface_hub\file_download.py:997, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, etag_timeout, token, local_files_only, headers, endpoint, tqdm_class, dry_run)
#     976     return _hf_hub_download_to_local_dir(
#     977         # Destination
#     978         local_dir=local_dir,
#    (...)    994         dry_run=dry_run,
#     995     )
#     996 else:
# --> 997     return _hf_hub_download_to_cache_dir(
#     998         # Destination
#     999         cache_dir=cache_dir,
#    1000         # File info
#    1001         repo_id=repo_id,
#    1002         filename=filename,
#    1003         repo_type=repo_type,
#    1004         revision=revision,
#    1005         # HTTP info
#    1006         endpoint=endpoint,
#    1007         etag_timeout=etag_timeout,
#    1008         headers=hf_headers,
#    1009         token=token,
#    1010         # Additional options
#    1011         local_files_only=local_files_only,
#    1012         force_download=force_download,
#    1013         tqdm_class=tqdm_class,
#    1014         dry_run=dry_run,
#    1015     )
#
# File C:\PythonVM\env2\Lib\site-packages\huggingface_hub\file_download.py:1215, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, force_download, tqdm_class, dry_run)
#    1211         return pointer_path
#    1213 # Local file doesn't exist or etag isn't a match => retrieve file from remote (or cache)
# -> 1215 with WeakFileLock(lock_path):
#    1216     _download_to_tmp_and_move(
#    1217         incomplete_path=Path(blob_path + ".incomplete"),
#    1218         destination_path=Path(blob_path),
#    (...)   1226         tqdm_class=tqdm_class,
#    1227     )
#    1228     if not os.path.exists(pointer_path):
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3824.0_x64__qbz5n2kfra8p0\Lib\contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     139 del self.args, self.kwds, self.func
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#     143     raise RuntimeError("generator didn't yield") from None
#
# File C:\PythonVM\env2\Lib\site-packages\huggingface_hub\utils\_fixes.py:99, in WeakFileLock(lock_file, timeout)
#      96     raise Timeout(str(lock_file))
#      98 try:
# ---> 99     lock.acquire(timeout=min(log_interval, timeout - elapsed_time) if timeout else log_interval)
#     100 except Timeout:
#     101     logger.info(
#     102         f"Still waiting to acquire lock on {lock_file} (elapsed: {time.time() - start_time:.1f} seconds)"
#     103     )
#
# File C:\PythonVM\env2\Lib\site-packages\filelock\_api.py:517, in BaseFileLock.acquire(self, timeout, poll_interval, poll_intervall, blocking, cancel_check)
#     515         msg = "Lock %s not acquired on %s, waiting %s seconds ..."
#     516         _LOGGER.debug(msg, lock_id, lock_filename, poll_interval)
# --> 517         time.sleep(poll_interval)
#     518 except BaseException:
#     519     self._context.lock_counter = max(0, self._context.lock_counter - 1)
#
# KeyboardInterrupt:

# %%
classifier = pipeline("sentiment-analysis", model="distilbert-base-uncased-finetuned-sst-2-english")
# Out:
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# C:\PythonVM\env2\Lib\site-packages\huggingface_hub\file_download.py:138: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\satish.a.waghmare\.cache\huggingface\hub\models--distilbert-base-uncased-finetuned-sst-2-english. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]

# %%
classifier("I've been waiting for a HuggingFace course my whole life.")
# Out:
# [{'label': 'POSITIVE', 'score': 0.9598049521446228}]

# %%
[{'label': 'POSITIVE', 'score': 0.9598047137260437}]
# Out:
# [{'label': 'POSITIVE', 'score': 0.9598047137260437}]

# %%
classifier(
    ["I've been waiting for a HuggingFace course my whole life.", "I hate this so much!"]
)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9598049521446228},
#  {'label': 'NEGATIVE', 'score': 0.9994558691978455}]

# %%
[{'label': 'POSITIVE', 'score': 0.9598047137260437},
 {'label': 'NEGATIVE', 'score': 0.9994558095932007}]
# Out:
# [{'label': 'POSITIVE', 'score': 0.9598047137260437},
#  {'label': 'NEGATIVE', 'score': 0.9994558095932007}]

# %% [markdown]
# #### Zero-shot classification

# %%
from transformers import pipeline

classifier = pipeline("zero-shot-classification")
classifier(
    "This is a course about the Transformers library",
    candidate_labels=["education", "politics", "business"],
)
# Out:
# [transformers] No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json: 0.00B [00:00, ?B/s]
# C:\PythonVM\env2\Lib\site-packages\huggingface_hub\file_download.py:138: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\satish.a.waghmare\.cache\huggingface\hub\models--facebook--bart-large-mnli. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/515 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# {'sequence': 'This is a course about the Transformers library',
#  'labels': ['education', 'business', 'politics'],
#  'scores': [0.8445991277694702, 0.1119740828871727, 0.04342678189277649]}

# %%
{'sequence': 'This is a course about the Transformers library',
 'labels': ['education', 'business', 'politics'],
 'scores': [0.8445963859558105, 0.111976258456707, 0.043427448719739914]}
# Out:
# {'sequence': 'This is a course about the Transformers library',
#  'labels': ['education', 'business', 'politics'],
#  'scores': [0.8445963859558105, 0.111976258456707, 0.043427448719739914]}

# %% [markdown]
# #### Text generation

# %%
from transformers import pipeline

generator = pipeline("text-generation")
generator("In this course, we will teach you how to")
# Out:
# [transformers] No model was supplied, defaulted to HuggingFaceTB/SmolLM3-3B and revision a07cc9a.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/326 [00:00<?, ?it/s]
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'In this course, we will teach you how to write Python code using Python 3. We will start with basic Python concepts and gradually move on to more complex topics. We will also cover best practices for writing clean, readable, and maintainable code.\nWe will start with the basics of Python, including data types, operators, and control structures. We will then move on to more advanced topics, such as functions, classes, and object-oriented programming. We will also cover file I/O, modules, and exceptions.\nThroughout the course, we will provide hands-on exercises and projects to help you practice and reinforce your learning. We will also provide feedback and guidance to help you improve your coding skills.\nBy the end of the course, you will have a solid understanding of Python and be able to write clean, readable, and maintainable code.\nWho is this course for?\nThis course is for beginners who want to learn Python programming language. It is suitable for students who have no prior experience with Python or programming in general.\nWhat will you learn in this course?\nIn this course, you will learn:\n- Basic Python concepts such as data types, operators, and control structures.\n- More advanced topics such as functions, classes, and object-oriented programming.\n- File I/O, modules, and exceptions.\n- Best practices for writing'}]

# %%
[{'generated_text': 'In this course, we will teach you how to understand and use '
                    'data flow and data interchange when handling user data. We '
                    'will be working with one or more of the most commonly used '
                    'data flows — data flows of various types, as seen by the '
                    'HTTP'}]
# Out:
# [{'generated_text': 'In this course, we will teach you how to understand and use data flow and data interchange when handling user data. We will be working with one or more of the most commonly used data flows — data flows of various types, as seen by the HTTP'}]

# %% [markdown]
# #### Using any model from the Hub in a pipeline

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="HuggingFaceTB/SmolLM2-360M")
generator(
    "In this course, we will teach you how to",
    max_length=30,
    num_return_sequences=2,
)
# Out:
# config.json:   0%|          | 0.00/689 [00:00<?, ?B/s]
# C:\PythonVM\env2\Lib\site-packages\huggingface_hub\file_download.py:138: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\satish.a.waghmare\.cache\huggingface\hub\models--HuggingFaceTB--SmolLM2-360M. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors:   0%|          | 0.00/724M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/831 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# [transformers] Passing `generation_config` together with generation-related arguments=({'max_length', 'num_return_sequences'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer GPT2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# [{'generated_text': 'In this course, we will teach you how to make use of the knowledge you’ve acquired in other classes and in other activities you’ve done, such as research projects, writing, or other activities.\n\nThis course is designed to help you prepare for the examinations. It is not a course in learning. It is a course in learning how to learn. We will provide you with all the information and support necessary to help you learn how to learn.\n\nThis course is not for everyone. It is not for everyone. It is for everyone who wants to learn more about the subject. It is not for everyone. It is for everyone who wants to learn more about the subject.\n\nThis course is not for everyone who wants to learn more about the subject. It is for everyone who wants to learn more about the subject. It is for everyone who wants to learn more about the subject. It is not for everyone. It is for everyone who wants to learn more about the subject.\n\nIt is for everyone who wants to learn more about the subject. It is for everyone who wants to learn more about the subject. It is for everyone who wants to learn more about the subject. It is not for everyone. It is for everyone who wants to learn more about the subject.\n\nIt is'},
#  {'generated_text': 'In this course, we will teach you how to make an introduction for a research paper using a proper format that will help you write a great research paper. We will also teach you how to write an introductory paragraph for a research paper, how to write a conclusion for a research paper, and how to write a research paper outline for a research paper.\n\nThe course will also teach you how to write a research paper outline for an effective research paper. The course will also teach you how to write a research paper in the APA style, how to write a research paper for a science fair, and how to write a research paper for a college level course.\n\nYou will learn the basics of research paper writing, and you will learn how to use the research paper writing process. You will also learn how to write a research paper outline, and you will learn how to write a research paper in the APA style. You will learn how to write a research paper in a science fair, and you will learn how to write a research paper for a college level course.\n\nYou will learn how to write a research paper in the APA style, and you will learn how to write a research paper in a science fair. You will learn how to write a research paper in the APA style, and you will learn to write a'}]

# %%
[{'generated_text': 'In this course, we will teach you how to manipulate the world and '
                    'move your mental and physical capabilities to your advantage.'},
 {'generated_text': 'In this course, we will teach you how to become an expert and '
                    'practice realtime, and with a hands on experience on both real '
                    'time and real'}]
# Out:
# [{'generated_text': 'In this course, we will teach you how to manipulate the world and move your mental and physical capabilities to your advantage.'},
#  {'generated_text': 'In this course, we will teach you how to become an expert and practice realtime, and with a hands on experience on both real time and real'}]

# %% [markdown]
# #### Mask filling

# %%
from transformers import pipeline

unmasker = pipeline("fill-mask")
unmasker("This course will teach you all about <mask> models.", top_k=2)
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilroberta-base and revision fb53ab8.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# C:\PythonVM\env2\Lib\site-packages\huggingface_hub\file_download.py:138: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\satish.a.waghmare\.cache\huggingface\hub\models--distilbert--distilroberta-base. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors:   0%|          | 0.00/331M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/106 [00:00<?, ?it/s]
# [transformers] RobertaForMaskedLM LOAD REPORT from: distilbert/distilroberta-base
# Key                         | Status     |  |
# ----------------------------+------------+--+-
# roberta.pooler.dense.weight | UNEXPECTED |  |
# roberta.pooler.dense.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# [{'score': 0.1961975395679474,
#   'token': 30412,
#   'token_str': ' mathematical',
#   'sequence': 'This course will teach you all about mathematical models.'},
#  {'score': 0.04052716866135597,
#   'token': 38163,
#   'token_str': ' computational',
#   'sequence': 'This course will teach you all about computational models.'}]

# %%
[{'sequence': 'This course will teach you all about mathematical models.',
  'score': 0.19619831442832947,
  'token': 30412,
  'token_str': ' mathematical'},
 {'sequence': 'This course will teach you all about computational models.',
  'score': 0.04052725434303284,
  'token': 38163,
  'token_str': ' computational'}]
# Out:
# [{'sequence': 'This course will teach you all about mathematical models.',
#   'score': 0.19619831442832947,
#   'token': 30412,
#   'token_str': ' mathematical'},
#  {'sequence': 'This course will teach you all about computational models.',
#   'score': 0.04052725434303284,
#   'token': 38163,
#   'token_str': ' computational'}]

# %% [markdown]
# #### Named entity recognition

# %%
from transformers import pipeline

ner = pipeline("ner", grouped_entities=True)
ner("My name is Sylvain and I work at Hugging Face in Brooklyn.")
# Out:
# [transformers] No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/998 [00:00<?, ?B/s]
# C:\PythonVM\env2\Lib\site-packages\huggingface_hub\file_download.py:138: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\satish.a.waghmare\.cache\huggingface\hub\models--dbmdz--bert-large-cased-finetuned-conll03-english. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# [transformers] BertForTokenClassification LOAD REPORT from: dbmdz/bert-large-cased-finetuned-conll03-english
# Key                      | Status     |  |
# -------------------------+------------+--+-
# bert.pooler.dense.bias   | UNEXPECTED |  |
# bert.pooler.dense.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/60.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 from transformers import pipeline
#       2
# ----> 3 ner = pipeline("ner", grouped_entities=True)
#       4 ner("My name is Sylvain and I work at Hugging Face in Brooklyn.")
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\__init__.py:1124, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, video_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1121 if processor is not None:
#    1122     kwargs["processor"] = processor
# -> 1124 return pipeline_class(model=model, task=task, **kwargs)
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\token_classification.py:137, in TokenClassificationPipeline.__init__(self, args_parser, **kwargs)
#     136 def __init__(self, args_parser=TokenClassificationArgumentHandler(), **kwargs):
# --> 137     super().__init__(**kwargs)
#     139     self.check_model_type(MODEL_FOR_TOKEN_CLASSIFICATION_MAPPING_NAMES)
#     141     self._basic_tokenizer = BasicTokenizer(do_lower_case=False)
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\base.py:934, in Pipeline.__init__(self, model, tokenizer, feature_extractor, image_processor, video_processor, processor, task, device, binary_output, **kwargs)
#     932 self._batch_size = kwargs.pop("batch_size", None)
#     933 self._num_workers = kwargs.pop("num_workers", None)
# --> 934 self._preprocess_params, self._forward_params, self._postprocess_params = self._sanitize_parameters(**kwargs)
#     936 # In processor only mode, we can get the modality processors from the processor
#     937 if self.processor is not None and all(
#     938     [self.tokenizer is None, self.feature_extractor is None, self.image_processor is None]
#     939 ):
#
# TypeError: TokenClassificationPipeline._sanitize_parameters() got an unexpected keyword argument 'grouped_entities'

# %%
[{'entity_group': 'PER', 'score': 0.99816, 'word': 'Sylvain', 'start': 11, 'end': 18}, 
 {'entity_group': 'ORG', 'score': 0.97960, 'word': 'Hugging Face', 'start': 33, 'end': 45}, 
 {'entity_group': 'LOC', 'score': 0.99321, 'word': 'Brooklyn', 'start': 49, 'end': 57}
]
# Out:
# [{'entity_group': 'PER',
#   'score': 0.99816,
#   'word': 'Sylvain',
#   'start': 11,
#   'end': 18},
#  {'entity_group': 'ORG',
#   'score': 0.9796,
#   'word': 'Hugging Face',
#   'start': 33,
#   'end': 45},
#  {'entity_group': 'LOC',
#   'score': 0.99321,
#   'word': 'Brooklyn',
#   'start': 49,
#   'end': 57}]

# %% [markdown]
# #### Question answering

# %%
from transformers import pipeline

question_answerer = pipeline("question-answering")
question_answerer(
    question="Where do I work?",
    context="My name is Sylvain and I work at Hugging Face in Brooklyn",
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 3
#       1 from transformers import pipeline
#       2
# ----> 3 question_answerer = pipeline("question-answering")
#       4 question_answerer(
#       5     question="Where do I work?",
#       6     context="My name is Sylvain and I work at Hugging Face in Brooklyn",
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\__init__.py:974, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, video_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     967         pipeline_class = get_class_from_dynamic_module(
#     968             class_ref,
#     969             model,
#     970             code_revision=code_revision,
#     971             **hub_kwargs,
#     972         )
#     973 else:
# --> 974     normalized_task, targeted_task, task_options = check_task(task)
#     975     if pipeline_class is None:
#     976         pipeline_class = targeted_task["impl"]
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\__init__.py:359, in check_task(task)
#     323 def check_task(task: str) -> tuple[str, dict, Any]:
#     324     """
#     325     Checks an incoming task string, to validate it's correct and return the default Pipeline and Model classes, and
#     326     default models if they exist.
#    (...)    357
#     358     """
# --> 359     return PIPELINE_REGISTRY.check_task(task)
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\base.py:1359, in PipelineRegistry.check_task(self, task)
#    1356     targeted_task = self.supported_tasks[task]
#    1357     return task, targeted_task, None
# -> 1359 raise KeyError(f"Unknown task {task}, available tasks are {self.get_supported_tasks()}")
#
# KeyError: "Unknown task question-answering, available tasks are ['any-to-any', 'audio-classification', 'automatic-speech-recognition', 'depth-estimation', 'document-question-answering', 'feature-extraction', 'fill-mask', 'image-classification', 'image-feature-extraction', 'image-segmentation', 'image-text-to-text', 'keypoint-matching', 'mask-generation', 'ner', 'object-detection', 'sentiment-analysis', 'table-question-answering', 'text-classification', 'text-generation', 'text-to-audio', 'text-to-speech', 'token-classification', 'video-classification', 'zero-shot-audio-classification', 'zero-shot-classification', 'zero-shot-image-classification', 'zero-shot-object-detection']"

# %%
{'score': 0.6385916471481323, 'start': 33, 'end': 45, 'answer': 'Hugging Face'}
# Out:
# {'score': 0.6385916471481323, 'start': 33, 'end': 45, 'answer': 'Hugging Face'}

# %% [markdown]
# #### Summarization

# %%
from transformers import pipeline

summarizer = pipeline("summarization")
summarizer(
    """
    America has changed dramatically during recent years. Not only has the number of 
    graduates in traditional engineering disciplines such as mechanical, civil, 
    electrical, chemical, and aeronautical engineering declined, but in most of 
    the premier American universities engineering curricula now concentrate on 
    and encourage largely the study of engineering science. As a result, there 
    are declining offerings in engineering subjects dealing with infrastructure, 
    the environment, and related issues, and greater concentration on high 
    technology subjects, largely supporting increasingly complex scientific 
    developments. While the latter is important, it should not be at the expense 
    of more traditional engineering.

    Rapidly developing economies such as China and India, as well as other 
    industrial countries in Europe and Asia, continue to encourage and advance 
    the teaching of engineering. Both China and India, respectively, graduate 
    six and eight times as many traditional engineers as does the United States. 
    Other industrial countries at minimum maintain their output, while America 
    suffers an increasingly serious decline in the number of engineering graduates 
    and a lack of well-educated engineers.
"""
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 3
#       1 from transformers import pipeline
#       2
# ----> 3 summarizer = pipeline("summarization")
#       4 summarizer(
#       5     """
#       6     America has changed dramatically during recent years. Not only has the number of
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\__init__.py:974, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, video_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     967         pipeline_class = get_class_from_dynamic_module(
#     968             class_ref,
#     969             model,
#     970             code_revision=code_revision,
#     971             **hub_kwargs,
#     972         )
#     973 else:
# --> 974     normalized_task, targeted_task, task_options = check_task(task)
#     975     if pipeline_class is None:
#     976         pipeline_class = targeted_task["impl"]
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\__init__.py:359, in check_task(task)
#     323 def check_task(task: str) -> tuple[str, dict, Any]:
#     324     """
#     325     Checks an incoming task string, to validate it's correct and return the default Pipeline and Model classes, and
#     326     default models if they exist.
#    (...)    357
#     358     """
# --> 359     return PIPELINE_REGISTRY.check_task(task)
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\base.py:1359, in PipelineRegistry.check_task(self, task)
#    1356     targeted_task = self.supported_tasks[task]
#    1357     return task, targeted_task, None
# -> 1359 raise KeyError(f"Unknown task {task}, available tasks are {self.get_supported_tasks()}")
#
# KeyError: "Unknown task summarization, available tasks are ['any-to-any', 'audio-classification', 'automatic-speech-recognition', 'depth-estimation', 'document-question-answering', 'feature-extraction', 'fill-mask', 'image-classification', 'image-feature-extraction', 'image-segmentation', 'image-text-to-text', 'keypoint-matching', 'mask-generation', 'ner', 'object-detection', 'sentiment-analysis', 'table-question-answering', 'text-classification', 'text-generation', 'text-to-audio', 'text-to-speech', 'token-classification', 'video-classification', 'zero-shot-audio-classification', 'zero-shot-classification', 'zero-shot-image-classification', 'zero-shot-object-detection']"

# %%
[{'summary_text': ' America has changed dramatically during recent years . The '
                  'number of engineering graduates in the U.S. has declined in '
                  'traditional engineering disciplines such as mechanical, civil '
                  ', electrical, chemical, and aeronautical engineering . Rapidly '
                  'developing economies such as China and India, as well as other '
                  'industrial countries in Europe and Asia, continue to encourage '
                  'and advance engineering .'}]
# Out:
# [{'summary_text': ' America has changed dramatically during recent years . The number of engineering graduates in the U.S. has declined in traditional engineering disciplines such as mechanical, civil , electrical, chemical, and aeronautical engineering . Rapidly developing economies such as China and India, as well as other industrial countries in Europe and Asia, continue to encourage and advance engineering .'}]

# %% [markdown]
# #### Translation

# %%
from transformers import pipeline

translator = pipeline("translation", model="Helsinki-NLP/opus-mt-fr-en")
translator("Ce cours est produit par Hugging Face.")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# C:\PythonVM\env2\Lib\site-packages\huggingface_hub\file_download.py:138: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\satish.a.waghmare\.cache\huggingface\hub\models--Helsinki-NLP--opus-mt-fr-en. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 3
#       1 from transformers import pipeline
#       2
# ----> 3 translator = pipeline("translation", model="Helsinki-NLP/opus-mt-fr-en")
#       4 translator("Ce cours est produit par Hugging Face.")
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\__init__.py:974, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, video_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     967         pipeline_class = get_class_from_dynamic_module(
#     968             class_ref,
#     969             model,
#     970             code_revision=code_revision,
#     971             **hub_kwargs,
#     972         )
#     973 else:
# --> 974     normalized_task, targeted_task, task_options = check_task(task)
#     975     if pipeline_class is None:
#     976         pipeline_class = targeted_task["impl"]
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\__init__.py:359, in check_task(task)
#     323 def check_task(task: str) -> tuple[str, dict, Any]:
#     324     """
#     325     Checks an incoming task string, to validate it's correct and return the default Pipeline and Model classes, and
#     326     default models if they exist.
#    (...)    357
#     358     """
# --> 359     return PIPELINE_REGISTRY.check_task(task)
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\base.py:1359, in PipelineRegistry.check_task(self, task)
#    1356     targeted_task = self.supported_tasks[task]
#    1357     return task, targeted_task, None
# -> 1359 raise KeyError(f"Unknown task {task}, available tasks are {self.get_supported_tasks()}")
#
# KeyError: "Unknown task translation, available tasks are ['any-to-any', 'audio-classification', 'automatic-speech-recognition', 'depth-estimation', 'document-question-answering', 'feature-extraction', 'fill-mask', 'image-classification', 'image-feature-extraction', 'image-segmentation', 'image-text-to-text', 'keypoint-matching', 'mask-generation', 'ner', 'object-detection', 'sentiment-analysis', 'table-question-answering', 'text-classification', 'text-generation', 'text-to-audio', 'text-to-speech', 'token-classification', 'video-classification', 'zero-shot-audio-classification', 'zero-shot-classification', 'zero-shot-image-classification', 'zero-shot-object-detection']"

# %%
[{'translation_text': 'This course is produced by Hugging Face.'}]
# Out:
# [{'translation_text': 'This course is produced by Hugging Face.'}]

# %% [markdown]
# #### Image classification

# %%
from transformers import pipeline

image_classifier = pipeline(
    task="image-classification", model="google/vit-base-patch16-224"
)
result = image_classifier(
    "https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/pipeline-cat-chonk.jpeg"
)
print(result)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# C:\PythonVM\env2\Lib\site-packages\huggingface_hub\file_download.py:138: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\satish.a.waghmare\.cache\huggingface\hub\models--google--vit-base-patch16-224. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/200 [00:00<?, ?it/s]
# preprocessor_config.json:   0%|          | 0.00/160 [00:00<?, ?B/s]
# [transformers] `ViTImageProcessor` requires torchvision (not installed); falling back to `ViTImageProcessorPil` for backward compatibility. Install torchvision to use the default backend, or import `ViTImageProcessorPil` directly to silence this warning.
# [{'label': 'lynx, catamount', 'score': 0.4334997236728668}, {'label': 'cougar, puma, catamount, mountain lion, painter, panther, Felis concolor', 'score': 0.03479622304439545}, {'label': 'snow leopard, ounce, Panthera uncia', 'score': 0.03240194171667099}, {'label': 'Egyptian cat', 'score': 0.02394479513168335}, {'label': 'tiger cat', 'score': 0.02288925088942051}]

# %%
[{'label': 'lynx, catamount', 'score': 0.43350091576576233},
 {'label': 'cougar, puma, catamount, mountain lion, painter, panther, Felis concolor',
  'score': 0.034796204417943954},
 {'label': 'snow leopard, ounce, Panthera uncia',
  'score': 0.03240183740854263},
 {'label': 'Egyptian cat', 'score': 0.02394474856555462},
 {'label': 'tiger cat', 'score': 0.02288915030658245}]
# Out:
# [{'label': 'lynx, catamount', 'score': 0.43350091576576233},
#  {'label': 'cougar, puma, catamount, mountain lion, painter, panther, Felis concolor',
#   'score': 0.034796204417943954},
#  {'label': 'snow leopard, ounce, Panthera uncia',
#   'score': 0.03240183740854263},
#  {'label': 'Egyptian cat', 'score': 0.02394474856555462},
#  {'label': 'tiger cat', 'score': 0.02288915030658245}]

# %% [markdown]
# #### Automatic speech recognition

# %%
from transformers import pipeline

transcriber = pipeline(
    task="automatic-speech-recognition", model="openai/whisper-large-v3"
)
result = transcriber(
    "https://huggingface.co/datasets/Narsil/asr_dummy/resolve/main/mlk.flac"
)
print(result)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# C:\PythonVM\env2\Lib\site-packages\huggingface_hub\file_download.py:138: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\satish.a.waghmare\.cache\huggingface\hub\models--openai--whisper-large-v3. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/1259 [00:00<?, ?it/s]
# generation_config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# normalizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/340 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\audio_utils.py:33, in ffmpeg_read(bpayload, sampling_rate)
#      32 try:
# ---> 33     with subprocess.Popen(ffmpeg_command, stdin=subprocess.PIPE, stdout=subprocess.PIPE) as ffmpeg_process:
#      34         output_stream = ffmpeg_process.communicate(bpayload)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3824.0_x64__qbz5n2kfra8p0\Lib\subprocess.py:1039, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1036             self.stderr = io.TextIOWrapper(self.stderr,
#    1037                     encoding=encoding, errors=errors)
# -> 1039     self._execute_child(args, executable, preexec_fn, close_fds,
#    1040                         pass_fds, cwd, env,
#    1041                         startupinfo, creationflags, shell,
#    1042                         p2cread, p2cwrite,
#    1043                         c2pread, c2pwrite,
#    1044                         errread, errwrite,
#    1045                         restore_signals,
#    1046                         gid, gids, uid, umask,
#    1047                         start_new_session, process_group)
#    1048 except:
#    1049     # Cleanup if the child failed starting.
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3824.0_x64__qbz5n2kfra8p0\Lib\subprocess.py:1554, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1553 try:
# -> 1554     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1555                              # no special security
#    1556                              None, None,
#    1557                              int(not close_fds),
#    1558                              creationflags,
#    1559                              env,
#    1560                              cwd,
#    1561                              startupinfo)
#    1562 finally:
#    1563     # Child is launched. Close the parent's copy of those pipe
#    1564     # handles that only the child should have open.  You need
#    (...)   1567     # pipe will not close when the child process exits and the
#    1568     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 6
#       2
#       3 transcriber = pipeline(
#       4     task="automatic-speech-recognition", model="openai/whisper-large-v3"
#       5 )
# ----> 6 result = transcriber(
#       7     "https://huggingface.co/datasets/Narsil/asr_dummy/resolve/main/mlk.flac"
#       8 )
#       9 print(result)
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\automatic_speech_recognition.py:247, in AutomaticSpeechRecognitionPipeline.__call__(self, inputs, **kwargs)
#     190 def __call__(self, inputs: np.ndarray | bytes | str | dict, **kwargs: Any) -> list[dict[str, Any]]:
#     191     """
#     192     Transcribe the audio sequence(s) given as inputs to text. See the [`AutomaticSpeechRecognitionPipeline`]
#     193     documentation for more information.
#    (...)    245                 `"".join(chunk["text"] for chunk in output["chunks"])`.
#     246     """
# --> 247     return super().__call__(inputs, **kwargs)
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\base.py:1286, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1282     return self.get_iterator(
#    1283         inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1284     )
#    1285 elif isinstance(self, ChunkPipeline):
# -> 1286     return next(
#    1287         iter(
#    1288             self.get_iterator(
#    1289                 [inputs], num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1290             )
#    1291         )
#    1292     )
#    1293 else:
#    1294     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\pt_utils.py:126, in PipelineIterator.__next__(self)
#     123     return self.loader_batch_item()
#     125 # We're out of items within a batch
# --> 126 item = next(self.iterator)
#     127 processed = self.infer(item, **self.params)
#     128 # We now have a batch of "inferred things".
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\pt_utils.py:271, in PipelinePackIterator.__next__(self)
#     268             return accumulator
#     270 while not is_last:
# --> 271     processed = self.infer(next(self.iterator), **self.params)
#     272     if self.loader_batch_size is not None:
#     273         if isinstance(processed, torch.Tensor):
#
# File C:\PythonVM\env2\Lib\site-packages\torch\utils\data\dataloader.py:725, in _BaseDataLoaderIter.__next__(self)
#     722 if self._sampler_iter is None:
#     723     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     724     self._reset()  # type: ignore[call-arg]
# --> 725 data = self._next_data()
#     726 self._num_yielded += 1
#     727 if (
#     728     self._dataset_kind == _DatasetKind.Iterable
#     729     and self._IterableDataset_len_called is not None
#     730     and self._num_yielded > self._IterableDataset_len_called
#     731 ):
#
# File C:\PythonVM\env2\Lib\site-packages\torch\utils\data\dataloader.py:785, in _SingleProcessDataLoaderIter._next_data(self)
#     783 def _next_data(self):
#     784     index = self._next_index()  # may raise StopIteration
# --> 785     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     786     if self._pin_memory:
#     787         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File C:\PythonVM\env2\Lib\site-packages\torch\utils\data\_utils\fetch.py:35, in _IterableDatasetFetcher.fetch(self, possibly_batched_index)
#      33 for _ in possibly_batched_index:
#      34     try:
# ---> 35         data.append(next(self.dataset_iter))
#      36     except StopIteration:
#      37         self.ended = True
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\pt_utils.py:188, in PipelineChunkIterator.__next__(self)
#     185     self.subiterator = self.infer(next(self.iterator), **self.params)
#     186 try:
#     187     # Try to return next item
# --> 188     processed = next(self.subiterator)
#     189 except StopIteration:
#     190     # When a preprocess iterator ends, we can start looking at the next item
#     191     # ChunkIterator will keep feeding until ALL elements of iterator
#    (...)    194     # Another way to look at it, is we're basically flattening lists of lists
#     195     # into a single list, but with generators
#     196     self.subiterator = self.infer(next(self.iterator), **self.params)
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\automatic_speech_recognition.py:356, in AutomaticSpeechRecognitionPipeline.preprocess(self, inputs, chunk_length_s, stride_length_s)
#     353             inputs = f.read()
#     355 if isinstance(inputs, bytes):
# --> 356     inputs = ffmpeg_read(inputs, self.feature_extractor.sampling_rate)
#     358 stride = None
#     359 extra = {}
#
# File C:\PythonVM\env2\Lib\site-packages\transformers\pipelines\audio_utils.py:36, in ffmpeg_read(bpayload, sampling_rate)
#      34         output_stream = ffmpeg_process.communicate(bpayload)
#      35 except FileNotFoundError as error:
# ---> 36     raise ValueError("ffmpeg was not found but is required to load audio files from filename") from error
#      37 out_bytes = output_stream[0]
#      38 audio = np.frombuffer(out_bytes, np.float32)
#
# ValueError: ffmpeg was not found but is required to load audio files from filename

# %%
{'text': ' I have a dream that one day this nation will rise up and live out the true meaning of its creed.'}
# Out:
# {'text': ' I have a dream that one day this nation will rise up and live out the true meaning of its creed.'}
