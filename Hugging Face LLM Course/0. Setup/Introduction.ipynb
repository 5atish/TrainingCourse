# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: transformers in C:\PythonVM\env2\Lib\site-packages (5.15.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in C:\PythonVM\env2\Lib\site-packages (from transformers) (1.13.0)
# Requirement already satisfied: numpy>=1.17 in C:\PythonVM\env2\Lib\site-packages (from transformers) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in C:\PythonVM\env2\Lib\site-packages (from transformers) (26.1)
# Requirement already satisfied: pyyaml>=5.1 in C:\PythonVM\env2\Lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in C:\PythonVM\env2\Lib\site-packages (from transformers) (2026.1.15)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in C:\PythonVM\env2\Lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in C:\PythonVM\env2\Lib\site-packages (from transformers) (0.23.1)
# Requirement already satisfied: safetensors>=0.8.0 in C:\PythonVM\env2\Lib\site-packages (from transformers) (0.8.0)
# Requirement already satisfied: tqdm>=4.60 in C:\PythonVM\env2\Lib\site-packages (from transformers) (4.67.3)
# Requirement already satisfied: filelock>=3.10.0 in C:\PythonVM\env2\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\PythonVM\env2\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2026.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in C:\PythonVM\env2\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\PythonVM\env2\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in C:\PythonVM\env2\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in C:\PythonVM\env2\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.13.0)
# Requirement already satisfied: certifi in C:\PythonVM\env2\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in C:\PythonVM\env2\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in C:\PythonVM\env2\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\PythonVM\env2\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: colorama in C:\PythonVM\env2\Lib\site-packages (from tqdm>=4.60->transformers) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in C:\PythonVM\env2\Lib\site-packages (from typer->transformers) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in C:\PythonVM\env2\Lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in C:\PythonVM\env2\Lib\site-packages (from typer->transformers) (14.3.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\PythonVM\env2\Lib\site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\PythonVM\env2\Lib\site-packages (from rich>=10.11.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\PythonVM\env2\Lib\site-packages (from rich>=10.11.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\PythonVM\env2\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->transformers) (0.1.2)
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import transformers
# Out:
# [transformers] PyTorch was not found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %%
# !pip install transformers[sentencepiece]
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: transformers[sentencepiece] in C:\PythonVM\env2\Lib\site-packages (5.15.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in C:\PythonVM\env2\Lib\site-packages (from transformers[sentencepiece]) (1.13.0)
# Requirement already satisfied: numpy>=1.17 in C:\PythonVM\env2\Lib\site-packages (from transformers[sentencepiece]) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in C:\PythonVM\env2\Lib\site-packages (from transformers[sentencepiece]) (26.1)
# Requirement already satisfied: pyyaml>=5.1 in C:\PythonVM\env2\Lib\site-packages (from transformers[sentencepiece]) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in C:\PythonVM\env2\Lib\site-packages (from transformers[sentencepiece]) (2026.1.15)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in C:\PythonVM\env2\Lib\site-packages (from transformers[sentencepiece]) (0.22.2)
# Requirement already satisfied: typer in C:\PythonVM\env2\Lib\site-packages (from transformers[sentencepiece]) (0.23.1)
# Requirement already satisfied: safetensors>=0.8.0 in C:\PythonVM\env2\Lib\site-packages (from transformers[sentencepiece]) (0.8.0)
# Requirement already satisfied: tqdm>=4.60 in C:\PythonVM\env2\Lib\site-packages (from transformers[sentencepiece]) (4.67.3)
# Collecting sentencepiece!=0.1.92,>=0.1.91 (from transformers[sentencepiece])
#   Downloading sentencepiece-0.2.2-cp313-cp313-win_amd64.whl.metadata (34 kB)
# Requirement already satisfied: protobuf in C:\PythonVM\env2\Lib\site-packages (from transformers[sentencepiece]) (5.29.6)
# Requirement already satisfied: filelock>=3.10.0 in C:\PythonVM\env2\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[sentencepiece]) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\PythonVM\env2\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[sentencepiece]) (2026.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in C:\PythonVM\env2\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[sentencepiece]) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\PythonVM\env2\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[sentencepiece]) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in C:\PythonVM\env2\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[sentencepiece]) (4.15.0)
# Requirement already satisfied: anyio in C:\PythonVM\env2\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[sentencepiece]) (4.13.0)
# Requirement already satisfied: certifi in C:\PythonVM\env2\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[sentencepiece]) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in C:\PythonVM\env2\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[sentencepiece]) (1.0.9)
# Requirement already satisfied: idna in C:\PythonVM\env2\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[sentencepiece]) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\PythonVM\env2\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[sentencepiece]) (0.16.0)
# Requirement already satisfied: colorama in C:\PythonVM\env2\Lib\site-packages (from tqdm>=4.60->transformers[sentencepiece]) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in C:\PythonVM\env2\Lib\site-packages (from typer->transformers[sentencepiece]) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in C:\PythonVM\env2\Lib\site-packages (from typer->transformers[sentencepiece]) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in C:\PythonVM\env2\Lib\site-packages (from typer->transformers[sentencepiece]) (14.3.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\PythonVM\env2\Lib\site-packages (from typer->transformers[sentencepiece]) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\PythonVM\env2\Lib\site-packages (from rich>=10.11.0->typer->transformers[sentencepiece]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\PythonVM\env2\Lib\site-packages (from rich>=10.11.0->typer->transformers[sentencepiece]) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\PythonVM\env2\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->transformers[sentencepiece]) (0.1.2)
# Downloading sentencepiece-0.2.2-cp313-cp313-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ------------------------- -------------- 0.8/1.2 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 5.5 MB/s  0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.2.2
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /sentencepiece/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /sentencepiece/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /sentencepiece/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /sentencepiece/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.ngc.nvidia.com', port=443): Failed to resolve 'pypi.ngc.nvidia.com' ([Errno 11001] getaddrinfo failed)")': /sentencepiece/
#
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install "transformers[sentencepiece]"
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: transformers[sentencepiece] in C:\PythonVM\env2\Lib\site-packages (5.15.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in C:\PythonVM\env2\Lib\site-packages (from transformers[sentencepiece]) (1.13.0)
# Requirement already satisfied: numpy>=1.17 in C:\PythonVM\env2\Lib\site-packages (from transformers[sentencepiece]) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in C:\PythonVM\env2\Lib\site-packages (from transformers[sentencepiece]) (26.1)
# Requirement already satisfied: pyyaml>=5.1 in C:\PythonVM\env2\Lib\site-packages (from transformers[sentencepiece]) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in C:\PythonVM\env2\Lib\site-packages (from transformers[sentencepiece]) (2026.1.15)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in C:\PythonVM\env2\Lib\site-packages (from transformers[sentencepiece]) (0.22.2)
# Requirement already satisfied: typer in C:\PythonVM\env2\Lib\site-packages (from transformers[sentencepiece]) (0.23.1)
# Requirement already satisfied: safetensors>=0.8.0 in C:\PythonVM\env2\Lib\site-packages (from transformers[sentencepiece]) (0.8.0)
# Requirement already satisfied: tqdm>=4.60 in C:\PythonVM\env2\Lib\site-packages (from transformers[sentencepiece]) (4.67.3)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in C:\PythonVM\env2\Lib\site-packages (from transformers[sentencepiece]) (0.2.2)
# Requirement already satisfied: protobuf in C:\PythonVM\env2\Lib\site-packages (from transformers[sentencepiece]) (5.29.6)
# Requirement already satisfied: filelock>=3.10.0 in C:\PythonVM\env2\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[sentencepiece]) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\PythonVM\env2\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[sentencepiece]) (2026.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in C:\PythonVM\env2\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[sentencepiece]) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\PythonVM\env2\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[sentencepiece]) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in C:\PythonVM\env2\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[sentencepiece]) (4.15.0)
# Requirement already satisfied: anyio in C:\PythonVM\env2\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[sentencepiece]) (4.13.0)
# Requirement already satisfied: certifi in C:\PythonVM\env2\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[sentencepiece]) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in C:\PythonVM\env2\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[sentencepiece]) (1.0.9)
# Requirement already satisfied: idna in C:\PythonVM\env2\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[sentencepiece]) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\PythonVM\env2\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[sentencepiece]) (0.16.0)
# Requirement already satisfied: colorama in C:\PythonVM\env2\Lib\site-packages (from tqdm>=4.60->transformers[sentencepiece]) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in C:\PythonVM\env2\Lib\site-packages (from typer->transformers[sentencepiece]) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in C:\PythonVM\env2\Lib\site-packages (from typer->transformers[sentencepiece]) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in C:\PythonVM\env2\Lib\site-packages (from typer->transformers[sentencepiece]) (14.3.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\PythonVM\env2\Lib\site-packages (from typer->transformers[sentencepiece]) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\PythonVM\env2\Lib\site-packages (from rich>=10.11.0->typer->transformers[sentencepiece]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\PythonVM\env2\Lib\site-packages (from rich>=10.11.0->typer->transformers[sentencepiece]) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\PythonVM\env2\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->transformers[sentencepiece]) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
