# %% [markdown]
# # L1: Automated Project: Planning, Estimation, and Allocation

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

import os
import yaml
from crewai import Agent, Task, Crew

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Set OpenAI Model

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)

# %% [markdown]
# ## Crew's Inputs

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# ### Comprehensive Breakdown of Website Project Tasks
#
# #### Project Overview:
# Create a responsive website for a small business that effectively promotes the company, its services, and engages with customers.
#
# ### Task Breakdown:
#
# 1. **Create a Responsive Design**
#    - **Description**: Develop a design template that adapts seamlessly to both desktop and mobile devices.
#    - **Scope**: Focus on fluid grids, flexible images, and media queries.
#    - **Assigned To**: Bob Smith (Designer)
#    - **Timelines**: 2 Weeks (Start: Week 1, End: Week 2)
#    - **Dependencies**: Finalization of wireframes.
#    - **Deliverable**: Responsive design mockups for review.
#
# 2. **Implement User Interface**
#    - **Description**: Design a modern and visually appealing UI that aligns with the brand.
#    - **Scope**: Include color schemes, typography, and element UI components.
#    - **Assigned To**: Bob Smith (Designer)
#    - **Timelines**: 1 Week (Start: Week 3, End: Week 3)
#    - **Dependencies**: Completion of responsive design.
#    - **Deliverable**: UI component library.
#
# 3. **Develop Navigation System**
#    - **Description**: Create an intuitive menu structure that facilitates easy access to all pages.
#    - **Scope**: Include dropdowns for subcategories if necessary.
#    - **Assigned To**: Jane Doe (Software Engineer)
#    - **Timelines**: 1 Week (Start: Week 4, End: Week 4)
#    - **Dependencies**: Completed UI components.
#    - **Deliverable**: Navigation system fully functional in the prototype.
#
# 4. **Create “About Us” Page**
#    - **Description**: Design and implement a page detailing the company’s history, mission, and values.
#    - **Scope**: Include imagery and text provided by the client.
#    - **Assigned To**: Jane Doe (Software Engineer)
#    - **Timelines**: 1 Week (Start: Week 5, End: Week 5)
#    - **Dependencies**: Completion of UI design and navigation structure.
#    - **Deliverable**: Live "About Us" page.
#
# 5. **Design “Services” Page**
#    - **Description**: Create a page showcasing the business's offerings with descriptions.
#    - **Scope**: Highlight each service with images and detailed descriptions.
#    - **Assigned To**: Jane Doe (Software Engineer)
#    - **Timelines**: 1 Week (Start: Week 6, End: Week 6)
#    - **Dependencies**: Completion of the “About Us” page.
#    - **Deliverable**: Functional “Services” page.
#
# 6. **Create “Contact Us” Page**
#    - **Description**: Develop a contact page with a submission form and integrated map for location.
#    - **Scope**: Ensure form collects necessary information (Name, Email, Message) and includes a Google Map widget.
#    - **Assigned To**: Jane Doe (Software Engineer)
#    - **Timelines**: 1 Week (Start: Week 7, End: Week 7)
#    - **Dependencies**: Completion of services page.
#    - **Deliverable**: Functional "Contact Us" page.
#
# 7. **Implement Blog Section**
#    - **Description**: Create a section for industry news and company updates.
#    - **Scope**: Include posts, categories, and search functionality.
#    - **Assigned To**: Jane Doe (Software Engineer)
#    - **Timelines**: 2 Weeks (Start: Week 8, End: Week 9)
#    - **Dependencies**: Completion of primary pages (About Us, Services, Contact Us).
#    - **Deliverable**: Live blog section.
#
# 8. **Optimize for Fast Loading Times and SEO**
#    - **Description**: Ensure website is optimized for speed and search engines.
#    - **Scope**: Minimize HTML/CSS, use compressed images, and implement SEO strategies (keywords, meta tags).
#    - **Assigned To**: Jane Doe (Software Engineer)
#    - **Timelines**: 1 Week (Start: Week 10, End: Week 10)
#    - **Dependencies**: All pages must be fully functional.
#    - **Deliverable**: Performance report showing speed and SEO readiness.
#
# 9. **Integrate Social Media Links**
#    - **Description**: Add social media icons linking to the business’s profiles.
#    - **Scope**: Ensure visibility across the site, typically in the header or footer.
#    - **Assigned To**: Jane Doe (Software Engineer)
#    - **Timelines**: 1 Week (Start: Week 10, End: Week 10)
#    - **Dependencies**: All pages must be fully functional.
#    - **Deliverable**: Social media integration complete.
#
# 10. **Include Testimonials Section**
#     - **Description**: Design and implement a section for customer testimonials to build trust.
#     - **Scope**: Collect quotes from satisfied customers or highlight reviews.
#     - **Assigned To**: Jane Doe (Software Engineer)
#     - **Timelines**: 1 Week (Start: Week 11, End: Week 11)
#     - **Dependencies**: Completion of primary pages.
#     - **Deliverable**: Live testimonials section.
#
# 11. **Quality Assurance and Final Testing**
#     - **Description**: Conduct thorough QA testing to ensure all functionalities work as intended.
#     - **Scope**: Conduct cross-browser testing, mobile responsiveness checks, and bug reporting.
#     - **Assigned To**: Alice Johnson & Tom Brown (QA Engineers)
#     - **Timelines**: 1 Week (Start: Week 12, End: Week 12)
#     - **Dependencies**: Completion of development tasks.
#     - **Deliverable**: QA report with bug fixes and final website.
#
# ### Gantt Chart/Timeline Visualization:
#
# | Task                                     | Responsible Team Member | Week 1 | Week 2 | Week 3 | Week 4 | Week 5 | Week 6 | Week 7 | Week 8 | Week 9 | Week 10 | Week 11 | Week 12 |
# |------------------------------------------|-------------------------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|---------|---------|
# | Create a Responsive Design               | Bob Smith               |   X    |   X    |        |        |        |        |        |        |        |         |         |         |
# | Implement User Interface                 | Bob Smith               |        |        |   X    |        |        |        |        |        |        |         |         |         |
# | Develop Navigation System                | Jane Doe                |        |        |        |   X    |        |        |        |        |        |         |         |         |
# | Create “About Us” Page                  | Jane Doe                |        |        |        |        |   X    |        |        |        |        |         |         |         |
# | Design “Services” Page                  | Jane Doe                |        |        |        |        |        |   X    |        |        |        |         |         |         |
# | Create “Contact Us” Page                | Jane Doe                |        |        |        |        |        |        |   X    |        |        |         |         |         |
# | Implement Blog Section                   | Jane Doe                |        |        |        |        |        |        |        |   X    |   X    |         |         |         |
# | Optimize for Fast Loading Times & SEO    | Jane Doe                |        |        |        |        |        |        |        |        |        |    X    |         |         |
# | Integrate Social Media Links             | Jane Doe                |        |        |        |        |        |        |        |        |        |    X    |         |         |
# | Include Testimonials Section              | Jane Doe                |        |        |        |        |        |        |        |        |        |         |    X    |         |
# | Quality Assurance and Final Testing      | Alice Johnson & Tom Brown|        |        |        |        |        |        |        |        |        |         |         |    X    |
#
# ### Conclusion
# This structured plan ensures a clear focus on tasks with defined scopes, achievable timelines, and appropriate team allocations. Each task aligns with project goals while meticulously addressing all requirements for the successful launch of the comprehensive website for the small business. The progress will be regularly reviewed to maintain timelines and deliverables on track.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# ### Website Project Estimation Report
#
# ---
#
# #### Task Evaluations and Estimations
#
# 1. **Create a Responsive Design**
#    - **Assigned To**: Bob Smith (Designer)
#    - **Estimated Time**: 2 Weeks
#    - **Resources Needed**:
#      - 1 Designer
#      - Design tools (e.g. Adobe XD, Figma)
#      - Collaboration platform (e.g. Slack, Trello)
#    - **Effort Estimation**: 80 hours
#    - **Risks**: Potential delays in wireframe finalization affecting the design timeline.
#
# ---
#
# 2. **Implement User Interface**
#    - **Assigned To**: Bob Smith (Designer)
#    - **Estimated Time**: 1 Week
#    - **Resources Needed**:
#      - 1 Designer
#      - UI design tools
#    - **Effort Estimation**: 40 hours
#    - **Risks**: Risk of misalignment with branding could require redesign.
#
# ---
#
# 3. **Develop Navigation System**
#    - **Assigned To**: Jane Doe (Software Engineer)
#    - **Estimated Time**: 1 Week
#    - **Resources Needed**:
#      - 1 Software Engineer
#      - Development environment
#    - **Effort Estimation**: 40 hours
#    - **Risks**: Complexity of dropdown menus could lead to usability issues.
#
# ---
#
# 4. **Create “About Us” Page**
#    - **Assigned To**: Jane Doe (Software Engineer)
#    - **Estimated Time**: 1 Week
#    - **Resources Needed**:
#      - 1 Software Engineer
#      - Content from client
#    - **Effort Estimation**: 40 hours
#    - **Risks**: Client delays in providing content can hinder progress.
#
# ---
#
# 5. **Design “Services” Page**
#    - **Assigned To**: Jane Doe (Software Engineer)
#    - **Estimated Time**: 1 Week
#    - **Resources Needed**:
#      - 1 Software Engineer
#      - Images and service descriptions
#    - **Effort Estimation**: 40 hours
#    - **Risks**: Changes in service descriptions may require redesign.
#
# ---
#
# 6. **Create “Contact Us” Page**
#    - **Assigned To**: Jane Doe (Software Engineer)
#    - **Estimated Time**: 1 Week
#    - **Resources Needed**:
#      - 1 Software Engineer
#      - Google Maps API access
#    - **Effort Estimation**: 40 hours
#    - **Risks**: Configuration issues with Google Maps integration may arise.
#
# ---
#
# 7. **Implement Blog Section**
#    - **Assigned To**: Jane Doe (Software Engineer)
#    - **Estimated Time**: 2 Weeks
#    - **Resources Needed**:
#      - 1 Software Engineer
#      - Content management system
#    - **Effort Estimation**: 80 hours
#    - **Risks**: Potential complexity in categorization and search function might affect schedule.
#
# ---
#
# 8. **Optimize for Fast Loading Times and SEO**
#    - **Assigned To**: Jane Doe (Software Engineer)
#    - **Estimated Time**: 1 Week
#    - **Resources Needed**:
#      - 1 Software Engineer
#      - Performance testing tools
#    - **Effort Estimation**: 40 hours
#    - **Risks**: Unforeseen performance issues could lead to additional time requirements.
#
# ---
#
# 9. **Integrate Social Media Links**
#    - **Assigned To**: Jane Doe (Software Engineer)
#    - **Estimated Time**: 1 Week
#    - **Resources Needed**:
#      - 1 Software Engineer
#    - **Effort Estimation**: 40 hours
#    - **Risks**: Changes in brand strategy may necessitate different integrations.
#
# ---
#
# 10. **Include Testimonials Section**
#     - **Assigned To**: Jane Doe (Software Engineer)
#     - **Estimated Time**: 1 Week
#     - **Resources Needed**:
#       - 1 Software Engineer
#       - Testimonial content from the client
#     - **Effort Estimation**: 40 hours
#     - **Risks**: Delay in obtaining testimonials may stall the task.
#
# ---
#
# 11. **Quality Assurance and Final Testing**
#     - **Assigned To**: Alice Johnson & Tom Brown (QA Engineers)
#     - **Estimated Time**: 1 Week
#     - **Resources Needed**:
#       - 2 QA Engineers
#       - Testing tools and devices for cross-browser compatibility
#     - **Effort Estimation**: 80 hours
#     - **Risks**: Last-minute bugs could lead to extended QA timelines.
#
# ---
#
# ### Summary of Time and Resources
#
# - **Total Estimated Time**: 12 Weeks
# - **Total Estimated Effort**: 560 hours
# - **Team Composition**:
#   - 1 Designer (Bob Smith)
#   - 1 Software Engineer (Jane Doe)
#   - 2 QA Engineers (Alice Johnson, Tom Brown)
#
# ### Summary of Risks and Uncertainties
# - **Dependency Risks**: Each task has dependencies that can create a cascading delay if preceding tasks are not completed on time.
# - **Content Risks**: The project timeline heavily relies on client engagement for content delivery, which can be unpredictable.
# - **Technical Risks**: Complex integrations such as Google Maps, Blog, and organizational structures could face unforeseen challenges.
#
# This comprehensive estimation report takes into account historical data and known complexities to predict an achievable timeline and resource allocation. Regular progress reviews will be necessary to maintain alignment with project goals and adapt to any arising challenges.
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# ### Resource Allocation Chart for Website Project
#
# | **Task**                              | **Assigned To**        | **Start Date** | **End Date**   | **Effort (hours)** |
# |---------------------------------------|------------------------|----------------|----------------|---------------------|
# | Create a Responsive Design            | Bob Smith              | Week 1         | Week 2         | 80                  |
# | Implement User Interface              | Bob Smith              | Week 3         | Week 3         | 40                  |
# | Develop Navigation System             | Jane Doe               | Week 1         | Week 1         | 40                  |
# | Create “About Us” Page               | Jane Doe               | Week 2         | Week 2         | 40                  |
# | Design “Services” Page                | Jane Doe               | Week 3         | Week 3         | 40                  |
# | Create “Contact Us” Page             | Jane Doe               | Week 3         | Week 3         | 40                  |
# | Implement Blog Section                | Jane Doe               | Week 4         | Week 5         | 80                  |
# | Optimize for Fast Loading Times and SEO | Jane Doe               | Week 6         | Week 6         | 40                  |
# | Integrate Social Media Links          | Jane Doe               | Week 6         | Week 6         | 40                  |
# | Include Testimonials Section          | Jane Doe               | Week 6         | Week 6         | 40                  |
# | Quality Assurance and Final Testing   | Alice Johnson & Tom Brown | Week 7         | Week 7         | 80                  |
#
# ### Summary and Rationale Behind Allocations
#
# 1. **Creating a Responsive Design**: Bob Smith has the design expertise required for this task, which is vital for the foundation of the entire website. It is allocated 2 weeks to ensure quality and address potential delays in wireframe finalization.
#
# 2. **Implementing User Interface**: Bob remains on board for this task, allowing for continuity in design implementation right after the responsive design phase. It is a shorter task (1 week), following immediately after the responsive design to maintain momentum.
#
# 3. **Develop Navigation System**: Jane Doe is suitable due to her software engineering background. Given that this task is pivotal for user experience, it’s spread over 1 week to ensure proper development and testing.
#
# 4. **Creating "About Us" Page**: Still allocating Jane here as it is a straightforward development task assuming content availability from the client. Estimated at 1 week supports focus completion and mitigates risks from potential content delays.
#
# 5. **Designing "Services" Page**: Although Jane is primarily a software engineer, these tasks can fit within her skill set as they require integrating both engineering and design thinking. Allocated within the same week for speed and efficiency.
#
# 6. **Creating "Contact Us" Page**: Again, Jane’s skills allow her to adapt to this. It follows a similar logic to the "About Us" page, also leading to a quicker turnaround.
#
# 7. **Implementing Blog Section**: Involving more complex development and integration with content management systems, I have assigned it a 2-week duration for Jane to accommodate unexpected complexities.
#
# 8. **Optimizing for Fast Loading Times and SEO**: Given Jane is already tasked with multiple pages, this can be effectively managed in week 6 to ensure all previous work contributes to an optimized outcome.
#
# 9. **Integrating Social Media Links**: This is a straightforward task, easily handled by Jane, allowing her to implement concise, clear integrations in week 6.
#
# 10. **Including Testimonials Section**: Another simple task that Jane can successfully manage, contingent upon client input remaining on schedule.
#
# 11. **Quality Assurance and Final Testing**: This crucial phase is assigned to both Alice Johnson and Tom Brown. Combining their efforts will ensure thorough testing across different devices and browsers. The timeline allocates 1 week to address any unforeseen bugs that emerge during the testing phase.
#
# ### Conclusion
# This allocation plan ensures that each team member is utilized according to their strengths while also preventing workload overload on any individual. By forecasting timelines and tasks collaboratively spread out over the estimated duration, we enhance the project's chances for success and adaptiveness to unforeseen developments. Regular reviews will be planned to maintain progress and address any content dependencies early.

# %% [markdown]
# ## Usage Metrics and Costs

# %% [markdown]
# Let’s see how much it would cost each time if this crew runs at scale.

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0031
#    total_tokens  prompt_tokens  completion_tokens  successful_requests
# 0         20637          12684               7953                    9

# %% [markdown]
# ## Result

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Create a Responsive Design',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Implement User Interface',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Develop Navigation System',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Create “About Us” Page',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Design “Services” Page',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Create “Contact Us” Page',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Implement Blog Section',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Optimize for Fast Loading Times and SEO',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Integrate Social Media Links',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Include Testimonials Section',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Quality Assurance and Final Testing',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Alice Johnson', 'Tom Brown']}],
#  'milestones': [{'milestone_name': 'Phase 1 - Design and Initial Implementation',
#    'tasks': ['Create a Responsive Design',
#     'Implement User Interface',
#     'Develop Navigation System']},
#   {'milestone_name': 'Phase 2 - Content Development',
#    'tasks': ['Create “About Us” Page',
#     'Design “Services” Page',
#     'Create “Contact Us” Page']},
#   {'milestone_name': 'Phase 3 - Feature Implementation and Optimization',
#    'tasks': ['Implement Blog Section',
#     'Optimize for Fast Loading Times and SEO',
#     'Integrate Social Media Links',
#     'Include Testimonials Section']},
#   {'milestone_name': 'Phase 4 - Final Testing and Launch',
#    'tasks': ['Quality Assurance and Final Testing']}]}

# %% [markdown]
# ## Inspect further

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_4f777 th {
#   font-size: 120%;
# }
# #T_4f777  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_4f777" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f777_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_4f777_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_4f777_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f777_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4f777_row0_col0" class="data row0 col0" >Create a Responsive Design</td>
#       <td id="T_4f777_row0_col1" class="data row0 col1" >80.000000</td>
#       <td id="T_4f777_row0_col2" class="data row0 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_4f777_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4f777_row1_col0" class="data row1 col0" >Implement User Interface</td>
#       <td id="T_4f777_row1_col1" class="data row1 col1" >40.000000</td>
#       <td id="T_4f777_row1_col2" class="data row1 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_4f777_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4f777_row2_col0" class="data row2 col0" >Develop Navigation System</td>
#       <td id="T_4f777_row2_col1" class="data row2 col1" >40.000000</td>
#       <td id="T_4f777_row2_col2" class="data row2 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_4f777_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4f777_row3_col0" class="data row3 col0" >Create “About Us” Page</td>
#       <td id="T_4f777_row3_col1" class="data row3 col1" >40.000000</td>
#       <td id="T_4f777_row3_col2" class="data row3 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_4f777_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4f777_row4_col0" class="data row4 col0" >Design “Services” Page</td>
#       <td id="T_4f777_row4_col1" class="data row4 col1" >40.000000</td>
#       <td id="T_4f777_row4_col2" class="data row4 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_4f777_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4f777_row5_col0" class="data row5 col0" >Create “Contact Us” Page</td>
#       <td id="T_4f777_row5_col1" class="data row5 col1" >40.000000</td>
#       <td id="T_4f777_row5_col2" class="data row5 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_4f777_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4f777_row6_col0" class="data row6 col0" >Implement Blog Section</td>
#       <td id="T_4f777_row6_col1" class="data row6 col1" >80.000000</td>
#       <td id="T_4f777_row6_col2" class="data row6 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_4f777_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4f777_row7_col0" class="data row7 col0" >Optimize for Fast Loading Times and SEO</td>
#       <td id="T_4f777_row7_col1" class="data row7 col1" >40.000000</td>
#       <td id="T_4f777_row7_col2" class="data row7 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_4f777_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4f777_row8_col0" class="data row8 col0" >Integrate Social Media Links</td>
#       <td id="T_4f777_row8_col1" class="data row8 col1" >40.000000</td>
#       <td id="T_4f777_row8_col2" class="data row8 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_4f777_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4f777_row9_col0" class="data row9 col0" >Include Testimonials Section</td>
#       <td id="T_4f777_row9_col1" class="data row9 col1" >40.000000</td>
#       <td id="T_4f777_row9_col2" class="data row9 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_4f777_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4f777_row10_col0" class="data row10 col0" >Quality Assurance and Final Testing</td>
#       <td id="T_4f777_row10_col1" class="data row10 col1" >80.000000</td>
#       <td id="T_4f777_row10_col2" class="data row10 col2" >['Alice Johnson', 'Tom Brown']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Inspecting Milestones

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_02ddc th {
#   font-size: 120%;
# }
# #T_02ddc  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_02ddc" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_02ddc_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_02ddc_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02ddc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_02ddc_row0_col0" class="data row0 col0" >Phase 1 - Design and Initial Implementation</td>
#       <td id="T_02ddc_row0_col1" class="data row0 col1" >['Create a Responsive Design', 'Implement User Interface', 'Develop Navigation System']</td>
#     </tr>
#     <tr>
#       <th id="T_02ddc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_02ddc_row1_col0" class="data row1 col0" >Phase 2 - Content Development</td>
#       <td id="T_02ddc_row1_col1" class="data row1 col1" >['Create “About Us” Page', 'Design “Services” Page', 'Create “Contact Us” Page']</td>
#     </tr>
#     <tr>
#       <th id="T_02ddc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_02ddc_row2_col0" class="data row2 col0" >Phase 3 - Feature Implementation and Optimization</td>
#       <td id="T_02ddc_row2_col1" class="data row2 col1" >['Implement Blog Section', 'Optimize for Fast Loading Times and SEO', 'Integrate Social Media Links', 'Include Testimonials Section']</td>
#     </tr>
#     <tr>
#       <th id="T_02ddc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_02ddc_row3_col0" class="data row3 col0" >Phase 4 - Final Testing and Launch</td>
#       <td id="T_02ddc_row3_col1" class="data row3 col1" >['Quality Assurance and Final Testing']</td>
#     </tr>
#   </tbody>
# </table>
