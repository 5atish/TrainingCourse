# %% [markdown]
# # L6: Building Your Crew for Production

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Creating a new project

# %%
! crewai create crew new_project --provider openai
# Out:
# Creating folder new_project...
#   - Created new_project/.gitignore
#   - Created new_project/pyproject.toml
#   - Created new_project/README.md
#   - Created new_project/src/new_project/__init__.py
#   - Created new_project/src/new_project/main.py
#   - Created new_project/src/new_project/crew.py
#   - Created new_project/src/new_project/tools/custom_tool.py
#   - Created new_project/src/new_project/tools/__init__.py
#   - Created new_project/src/new_project/config/agents.yaml
#   - Created new_project/src/new_project/config/tasks.yaml
# Crew new_project created successfully!

# %% [markdown]
# ## Setting up the Environment

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note</code>:</b> The following line might take a few minutes to finish.</p>

# %%
! cd new_project && crewai install
# Out:
# Using CPython 3.11.9 interpreter at: /usr/local/bin/python
# Creating virtual environment at: .venv
# Resolved 155 packages in 1.27s
# Building new-project @ file:///home/jovyan/work/L13/new_project
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# networkx   ------------------------------     0 B/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# openai     ------------------------------     0 B/1.11 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# pyyaml     ------------------------------     0 B/787.73 KiB
# openai     ------------------------------     0 B/1.11 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# openai     ------------------------------     0 B/1.11 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# pydantic   ------------------------------     0 B/460.92 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# openai     ------------------------------     0 B/1.11 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# httptools  ------------------------------     0 B/445.92 KiB
# pydantic   ------------------------------     0 B/460.92 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# openai     ------------------------------     0 B/1.11 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# watchfiles ------------------------------     0 B/445.39 KiB
# httptools  ------------------------------     0 B/445.92 KiB
# pydantic   ------------------------------     0 B/460.92 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# openai     ------------------------------     0 B/1.11 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# watchfiles ------------------------------     0 B/445.39 KiB
# httptools  ------------------------------     0 B/445.92 KiB
# pydantic   ------------------------------     0 B/460.92 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# openai     ------------------------------     0 B/1.11 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# protobuf   ------------------------------     0 B/315.86 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# watchfiles ------------------------------     0 B/445.39 KiB
# httptools  ------------------------------     0 B/445.92 KiB
# pydantic   ------------------------------     0 B/460.92 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# openai     ------------------------------     0 B/1.11 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# rich       ------------------------------     0 B/303.20 KiB
# protobuf   ------------------------------     0 B/315.86 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# watchfiles ------------------------------     0 B/445.39 KiB
# httptools  ------------------------------     0 B/445.92 KiB
# pydantic   ------------------------------     0 B/460.92 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# openai     ------------------------------     0 B/1.11 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# googleapis-common-protos ------------------------------     0 B/293.69 KiB
# rich       ------------------------------     0 B/303.20 KiB
# protobuf   ------------------------------     0 B/315.86 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# watchfiles ------------------------------     0 B/445.39 KiB
# httptools  ------------------------------     0 B/445.92 KiB
# pydantic   ------------------------------     0 B/460.92 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# openai     ------------------------------     0 B/1.11 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# bcrypt     ------------------------------     0 B/271.72 KiB
# googleapis-common-protos ------------------------------     0 B/293.69 KiB
# rich       ------------------------------     0 B/303.20 KiB
# protobuf   ------------------------------     0 B/315.86 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# watchfiles ------------------------------     0 B/445.39 KiB
# httptools  ------------------------------     0 B/445.92 KiB
# pydantic   ------------------------------     0 B/460.92 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# openai     ------------------------------     0 B/1.11 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# python-docx ------------------------------     0 B/247.06 KiB
# bcrypt     ------------------------------     0 B/271.72 KiB
# googleapis-common-protos ------------------------------     0 B/293.69 KiB
# rich       ------------------------------     0 B/303.20 KiB
# protobuf   ------------------------------     0 B/315.86 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# watchfiles ------------------------------     0 B/445.39 KiB
# httptools  ------------------------------     0 B/445.92 KiB
# pydantic   ------------------------------     0 B/460.92 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# openai     ------------------------------     0 B/1.11 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# openpyxl   ------------------------------     0 B/245.03 KiB
# python-docx ------------------------------     0 B/247.06 KiB
# bcrypt     ------------------------------     0 B/271.72 KiB
# googleapis-common-protos ------------------------------     0 B/293.69 KiB
# rich       ------------------------------     0 B/303.20 KiB
# protobuf   ------------------------------     0 B/315.86 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# watchfiles ------------------------------     0 B/445.39 KiB
# httptools  ------------------------------     0 B/445.92 KiB
# pydantic   ------------------------------     0 B/460.92 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# openai     ------------------------------     0 B/1.11 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# multidict  ------------------------------ 62.84 KiB/240.52 KiB
# openpyxl   ------------------------------ 14.80 KiB/245.03 KiB
# python-docx ------------------------------ 30.81 KiB/247.06 KiB
# bcrypt     ------------------------------ 62.81 KiB/271.72 KiB
# googleapis-common-protos ------------------------------ 30.79 KiB/293.69 KiB
# rich       ------------------------------ 39.63 KiB/303.20 KiB
# lance-namespace-urllib3-client ------------------------------ 30.72 KiB/307.40 KiB
# protobuf   ------------------------------ 62.81 KiB/315.86 KiB
# pypdf      ------------------------------ 30.85 KiB/328.43 KiB
# jiter      ------------------------------ 56.44 KiB/354.18 KiB
# rpds-py    ------------------------------ 14.84 KiB/381.67 KiB
# prompt-toolkit ------------------------------ 30.80 KiB/382.26 KiB
# watchfiles ------------------------------ 14.84 KiB/445.39 KiB
# httptools  ------------------------------ 62.74 KiB/445.92 KiB
# pydantic   ------------------------------ 30.81 KiB/460.92 KiB
# crewai     ------------------------------ 30.78 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 16.00 KiB/473.85 KiB
# mpmath     ------------------------------ 36.78 KiB/523.63 KiB
# huggingface-hub ------------------------------ 30.81 KiB/632.58 KiB
# crewai-tools ------------------------------ 14.84 KiB/723.68 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# multidict  ------------------------------ 206.00 KiB/240.52 KiB
# openpyxl   ------------------------------ 30.80 KiB/245.03 KiB
# python-docx ------------------------------ 30.81 KiB/247.06 KiB
# bcrypt     ------------------------------ 203.95 KiB/271.72 KiB
# googleapis-common-protos ------------------------------ 45.30 KiB/293.69 KiB
# rich       ------------------------------ 39.63 KiB/303.20 KiB
# lance-namespace-urllib3-client ------------------------------ 62.72 KiB/307.40 KiB
# protobuf   ------------------------------ 171.85 KiB/315.86 KiB
# pypdf      ------------------------------ 110.85 KiB/328.43 KiB
# jiter      ------------------------------ 190.81 KiB/354.18 KiB
# rpds-py    ------------------------------ 204.85 KiB/381.67 KiB
# prompt-toolkit ------------------------------ 46.80 KiB/382.26 KiB
# watchfiles ------------------------------ 205.85 KiB/445.39 KiB
# httptools  ------------------------------ 205.35 KiB/445.92 KiB
# pydantic   ------------------------------ 62.71 KiB/460.92 KiB
# crewai     ------------------------------ 62.78 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 32.00 KiB/473.85 KiB
# mpmath     ------------------------------ 141.07 KiB/523.63 KiB
# huggingface-hub ------------------------------ 62.70 KiB/632.58 KiB
# crewai-tools ------------------------------ 14.84 KiB/723.68 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# multidict  ------------------------------ 240.52 KiB/240.52 KiB
# openpyxl   ------------------------------ 30.80 KiB/245.03 KiB
# python-docx ------------------------------ 46.81 KiB/247.06 KiB
# bcrypt     ------------------------------ 255.95 KiB/271.72 KiB
# googleapis-common-protos ------------------------------ 61.30 KiB/293.69 KiB
# rich       ------------------------------ 71.52 KiB/303.20 KiB
# lance-namespace-urllib3-client ------------------------------ 110.82 KiB/307.40 KiB
# protobuf   ------------------------------ 203.85 KiB/315.86 KiB
# pypdf      ------------------------------ 246.81 KiB/328.43 KiB
# jiter      ------------------------------ 248.21 KiB/354.18 KiB
# rpds-py    ------------------------------ 268.96 KiB/381.67 KiB
# prompt-toolkit ------------------------------ 77.51 KiB/382.26 KiB
# watchfiles ------------------------------ 285.85 KiB/445.39 KiB
# httptools  ------------------------------ 285.35 KiB/445.92 KiB
# pydantic   ------------------------------ 156.25 KiB/460.92 KiB
# crewai     ------------------------------ 78.78 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 253.92 KiB/473.85 KiB
# mpmath     ------------------------------ 226.64 KiB/523.63 KiB
# huggingface-hub ------------------------------ 238.04 KiB/632.58 KiB
# crewai-tools ------------------------------ 41.15 KiB/723.68 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# openpyxl   ------------------------------ 46.80 KiB/245.03 KiB
# python-docx ------------------------------ 62.81 KiB/247.06 KiB
# bcrypt     ------------------------------ 271.72 KiB/271.72 KiB
# googleapis-common-protos ------------------------------ 61.30 KiB/293.69 KiB
# rich       ------------------------------ 78.23 KiB/303.20 KiB
# lance-namespace-urllib3-client ------------------------------ 110.82 KiB/307.40 KiB
# protobuf   ------------------------------ 225.05 KiB/315.86 KiB
# pypdf      ------------------------------ 246.81 KiB/328.43 KiB
# jiter      ------------------------------ 264.21 KiB/354.18 KiB
# rpds-py    ------------------------------ 284.96 KiB/381.67 KiB
# prompt-toolkit ------------------------------ 93.41 KiB/382.26 KiB
# watchfiles ------------------------------ 310.37 KiB/445.39 KiB
# httptools  ------------------------------ 301.35 KiB/445.92 KiB
# pydantic   ------------------------------ 172.25 KiB/460.92 KiB
# crewai     ------------------------------ 78.78 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 269.92 KiB/473.85 KiB
# mpmath     ------------------------------ 242.64 KiB/523.63 KiB
# huggingface-hub ------------------------------ 254.04 KiB/632.58 KiB
# crewai-tools ------------------------------ 41.15 KiB/723.68 KiB
# pyvis      ------------------------------ 249.93 KiB/738.32 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# tomli      ------------------------------     0 B/238.11 KiB
# openpyxl   ------------------------------ 46.80 KiB/245.03 KiB
# python-docx ------------------------------ 76.70 KiB/247.06 KiB
# googleapis-common-protos ------------------------------ 78.41 KiB/293.69 KiB
# rich       ------------------------------ 94.12 KiB/303.20 KiB
# lance-namespace-urllib3-client ------------------------------ 126.82 KiB/307.40 KiB
# protobuf   ------------------------------ 255.85 KiB/315.86 KiB
# pypdf      ------------------------------ 262.81 KiB/328.43 KiB
# jiter      ------------------------------ 286.81 KiB/354.18 KiB
# rpds-py    ------------------------------ 316.96 KiB/381.67 KiB
# prompt-toolkit ------------------------------ 93.41 KiB/382.26 KiB
# watchfiles ------------------------------ 317.85 KiB/445.39 KiB
# httptools  ------------------------------ 348.84 KiB/445.92 KiB
# pydantic   ------------------------------ 188.25 KiB/460.92 KiB
# crewai     ------------------------------ 78.78 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 299.09 KiB/473.85 KiB
# mpmath     ------------------------------ 273.19 KiB/523.63 KiB
# huggingface-hub ------------------------------ 285.84 KiB/632.58 KiB
# crewai-tools ------------------------------ 41.15 KiB/723.68 KiB
# pyvis      ------------------------------ 270.77 KiB/738.32 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# opentelemetry-semantic-conventions ------------------------------     0 B/226.19 KiB
# tomli      ------------------------------ 48.00 KiB/238.11 KiB
# openpyxl   ------------------------------ 46.80 KiB/245.03 KiB
# python-docx ------------------------------ 76.70 KiB/247.06 KiB
# googleapis-common-protos ------------------------------ 94.41 KiB/293.69 KiB
# rich       ------------------------------ 126.12 KiB/303.20 KiB
# lance-namespace-urllib3-client ------------------------------ 142.82 KiB/307.40 KiB
# protobuf   ------------------------------ 271.85 KiB/315.86 KiB
# pypdf      ------------------------------ 278.81 KiB/328.43 KiB
# jiter      ------------------------------ 322.82 KiB/354.18 KiB
# rpds-py    ------------------------------ 364.85 KiB/381.67 KiB
# prompt-toolkit ------------------------------ 109.41 KiB/382.26 KiB
# watchfiles ------------------------------ 381.85 KiB/445.39 KiB
# httptools  ------------------------------ 381.35 KiB/445.92 KiB
# pydantic   ------------------------------ 234.56 KiB/460.92 KiB
# crewai     ------------------------------ 99.24 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 333.92 KiB/473.85 KiB
# mpmath     ------------------------------ 317.07 KiB/523.63 KiB
# huggingface-hub ------------------------------ 317.84 KiB/632.58 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (2/151)
# opentelemetry-semantic-conventions ------------------------------ 16.00 KiB/226.19 KiB
# tomli      ------------------------------ 96.00 KiB/238.11 KiB
# openpyxl   ------------------------------ 62.80 KiB/245.03 KiB
# python-docx ------------------------------ 108.48 KiB/247.06 KiB
# googleapis-common-protos ------------------------------ 110.30 KiB/293.69 KiB
# rich       ------------------------------ 174.23 KiB/303.20 KiB
# lance-namespace-urllib3-client ------------------------------ 158.82 KiB/307.40 KiB
# protobuf   ------------------------------ 303.85 KiB/315.86 KiB
# pypdf      ------------------------------ 326.81 KiB/328.43 KiB
# jiter      ------------------------------ 354.18 KiB/354.18 KiB
# prompt-toolkit ------------------------------ 125.41 KiB/382.26 KiB
# watchfiles ------------------------------ 417.12 KiB/445.39 KiB
# httptools  ------------------------------ 429.35 KiB/445.92 KiB
# pydantic   ------------------------------ 268.25 KiB/460.92 KiB
# crewai     ------------------------------ 115.24 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 381.92 KiB/473.85 KiB
# mpmath     ------------------------------ 364.97 KiB/523.63 KiB
# huggingface-hub ------------------------------ 350.04 KiB/632.58 KiB
# crewai-tools ------------------------------ 73.15 KiB/723.68 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (2/151)
# opentelemetry-semantic-conventions ------------------------------ 32.00 KiB/226.19 KiB
# tomli      ------------------------------ 112.00 KiB/238.11 KiB
# openpyxl   ------------------------------ 62.80 KiB/245.03 KiB
# python-docx ------------------------------ 108.48 KiB/247.06 KiB
# googleapis-common-protos ------------------------------ 110.30 KiB/293.69 KiB
# rich       ------------------------------ 174.23 KiB/303.20 KiB
# lance-namespace-urllib3-client ------------------------------ 158.82 KiB/307.40 KiB
# protobuf   ------------------------------ 307.02 KiB/315.86 KiB
# pypdf      ------------------------------ 326.81 KiB/328.43 KiB
# prompt-toolkit ------------------------------ 125.41 KiB/382.26 KiB
# watchfiles ------------------------------ 433.12 KiB/445.39 KiB
# httptools  ------------------------------ 445.35 KiB/445.92 KiB
# pydantic   ------------------------------ 284.25 KiB/460.92 KiB
# crewai     ------------------------------ 115.24 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 397.92 KiB/473.85 KiB
# mpmath     ------------------------------ 380.97 KiB/523.63 KiB
# huggingface-hub ------------------------------ 366.04 KiB/632.58 KiB
# crewai-tools ------------------------------ 73.15 KiB/723.68 KiB
# pyvis      ------------------------------ 366.77 KiB/738.32 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (2/151)
# opentelemetry-semantic-conventions ------------------------------ 32.00 KiB/226.19 KiB
# tomli      ------------------------------ 112.00 KiB/238.11 KiB
# openpyxl   ------------------------------ 62.80 KiB/245.03 KiB
# python-docx ------------------------------ 124.48 KiB/247.06 KiB
# googleapis-common-protos ------------------------------ 110.30 KiB/293.69 KiB
# rich       ------------------------------ 174.23 KiB/303.20 KiB
# lance-namespace-urllib3-client ------------------------------ 158.82 KiB/307.40 KiB
# protobuf   ------------------------------ 315.86 KiB/315.86 KiB
# prompt-toolkit ------------------------------ 125.41 KiB/382.26 KiB
# watchfiles ------------------------------ 433.12 KiB/445.39 KiB
# httptools  ------------------------------ 445.35 KiB/445.92 KiB
# pydantic   ------------------------------ 300.25 KiB/460.92 KiB
# crewai     ------------------------------ 115.24 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 397.92 KiB/473.85 KiB
# mpmath     ------------------------------ 380.97 KiB/523.63 KiB
# huggingface-hub ------------------------------ 382.04 KiB/632.58 KiB
# crewai-tools ------------------------------ 73.15 KiB/723.68 KiB
# pyvis      ------------------------------ 366.77 KiB/738.32 KiB
# regex      ------------------------------ 428.61 KiB/781.06 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (2/151)
# opentelemetry-semantic-conventions ------------------------------ 48.00 KiB/226.19 KiB
# tomli      ------------------------------ 112.00 KiB/238.11 KiB
# openpyxl   ------------------------------ 76.68 KiB/245.03 KiB
# python-docx ------------------------------ 140.38 KiB/247.06 KiB
# googleapis-common-protos ------------------------------ 142.30 KiB/293.69 KiB
# rich       ------------------------------ 205.89 KiB/303.20 KiB
# lance-namespace-urllib3-client ------------------------------ 190.72 KiB/307.40 KiB
# protobuf   ------------------------------ 315.86 KiB/315.86 KiB
# prompt-toolkit ------------------------------ 141.19 KiB/382.26 KiB
# watchfiles ------------------------------ 433.12 KiB/445.39 KiB
# httptools  ------------------------------ 445.35 KiB/445.92 KiB
# pydantic   ------------------------------ 316.25 KiB/460.92 KiB
# crewai     ------------------------------ 115.24 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 397.92 KiB/473.85 KiB
# mpmath     ------------------------------ 380.97 KiB/523.63 KiB
# huggingface-hub ------------------------------ 414.04 KiB/632.58 KiB
# crewai-tools ------------------------------ 78.84 KiB/723.68 KiB
# pyvis      ------------------------------ 366.77 KiB/738.32 KiB
# regex      ------------------------------ 428.61 KiB/781.06 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (2/151)
# cffi       ------------------------------     0 B/210.52 KiB
# python-dateutil ------------------------------ 1.90 KiB/224.50 KiB
# opentelemetry-semantic-conventions ------------------------------ 64.00 KiB/226.19 KiB
# tomli      ------------------------------ 128.00 KiB/238.11 KiB
# openpyxl   ------------------------------ 93.67 KiB/245.03 KiB
# python-docx ------------------------------ 156.70 KiB/247.06 KiB
# googleapis-common-protos ------------------------------ 142.30 KiB/293.69 KiB
# rich       ------------------------------ 238.23 KiB/303.20 KiB
# lance-namespace-urllib3-client ------------------------------ 206.72 KiB/307.40 KiB
# protobuf   ------------------------------ 315.86 KiB/315.86 KiB
# prompt-toolkit ------------------------------ 173.51 KiB/382.26 KiB
# watchfiles ------------------------------ 445.39 KiB/445.39 KiB
# pydantic   ------------------------------ 327.45 KiB/460.92 KiB
# crewai     ------------------------------ 131.24 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 415.36 KiB/473.85 KiB
# mpmath     ------------------------------ 397.07 KiB/523.63 KiB
# huggingface-hub ------------------------------ 430.04 KiB/632.58 KiB
# crewai-tools ------------------------------ 94.84 KiB/723.68 KiB
# pyvis      ------------------------------ 382.77 KiB/738.32 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (2/151)
# cffi       ------------------------------ 14.81 KiB/210.52 KiB
# python-dateutil ------------------------------ 1.90 KiB/224.50 KiB
# opentelemetry-semantic-conventions ------------------------------ 64.00 KiB/226.19 KiB
# tomli      ------------------------------ 160.00 KiB/238.11 KiB
# openpyxl   ------------------------------ 93.67 KiB/245.03 KiB
# python-docx ------------------------------ 156.70 KiB/247.06 KiB
# googleapis-common-protos ------------------------------ 142.30 KiB/293.69 KiB
# rich       ------------------------------ 238.23 KiB/303.20 KiB
# lance-namespace-urllib3-client ------------------------------ 206.72 KiB/307.40 KiB
# protobuf   ------------------------------ 315.86 KiB/315.86 KiB
# prompt-toolkit ------------------------------ 173.51 KiB/382.26 KiB
# pydantic   ------------------------------ 343.45 KiB/460.92 KiB
# crewai     ------------------------------ 131.24 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 431.36 KiB/473.85 KiB
# mpmath     ------------------------------ 413.07 KiB/523.63 KiB
# huggingface-hub ------------------------------ 446.04 KiB/632.58 KiB
# crewai-tools ------------------------------ 94.84 KiB/723.68 KiB
# pyvis      ------------------------------ 382.77 KiB/738.32 KiB
# regex      ------------------------------ 490.58 KiB/781.06 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (2/151)
# propcache  ------------------------------ 32.00 KiB/205.11 KiB
# charset-normalizer ------------------------------ 33.84 KiB/209.04 KiB
# cffi       ------------------------------ 123.64 KiB/210.52 KiB
# python-dateutil ------------------------------ 43.87 KiB/224.50 KiB
# frozenlist ------------------------------ 16.00 KiB/225.65 KiB
# opentelemetry-semantic-conventions ------------------------------ 80.00 KiB/226.19 KiB
# tomli      ------------------------------ 224.00 KiB/238.11 KiB
# openpyxl   ------------------------------ 109.57 KiB/245.03 KiB
# python-docx ------------------------------ 188.70 KiB/247.06 KiB
# googleapis-common-protos ------------------------------ 158.41 KiB/293.69 KiB
# rich       ------------------------------ 270.23 KiB/303.20 KiB
# lance-namespace-urllib3-client ------------------------------ 211.24 KiB/307.40 KiB
# protobuf   ------------------------------ 315.86 KiB/315.86 KiB
# prompt-toolkit ------------------------------ 189.51 KiB/382.26 KiB
# pydantic   ------------------------------ 396.25 KiB/460.92 KiB
# crewai     ------------------------------ 131.24 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 473.85 KiB/473.85 KiB
# mpmath     ------------------------------ 413.07 KiB/523.63 KiB
# huggingface-hub ------------------------------ 446.04 KiB/632.58 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (2/151)
# propcache  ------------------------------ 62.08 KiB/205.11 KiB
# charset-normalizer ------------------------------ 63.09 KiB/209.04 KiB
# cffi       ------------------------------ 123.64 KiB/210.52 KiB
# python-dateutil ------------------------------ 75.87 KiB/224.50 KiB
# frozenlist ------------------------------ 48.00 KiB/225.65 KiB
# opentelemetry-semantic-conventions ------------------------------ 80.00 KiB/226.19 KiB
# tomli      ------------------------------ 238.11 KiB/238.11 KiB
# openpyxl   ------------------------------ 109.57 KiB/245.03 KiB
# python-docx ------------------------------ 188.70 KiB/247.06 KiB
# googleapis-common-protos ------------------------------ 158.41 KiB/293.69 KiB
# rich       ------------------------------ 286.23 KiB/303.20 KiB
# lance-namespace-urllib3-client ------------------------------ 236.02 KiB/307.40 KiB
# protobuf   ------------------------------ 315.86 KiB/315.86 KiB
# prompt-toolkit ------------------------------ 205.51 KiB/382.26 KiB
# pydantic   ------------------------------ 412.15 KiB/460.92 KiB
# crewai     ------------------------------ 131.24 KiB/462.12 KiB
# mpmath     ------------------------------ 429.07 KiB/523.63 KiB
# huggingface-hub ------------------------------ 446.04 KiB/632.58 KiB
# crewai-tools ------------------------------ 110.84 KiB/723.68 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (2/151)
# fsspec     ------------------------------     0 B/198.63 KiB
# propcache  ------------------------------ 79.76 KiB/205.11 KiB
# charset-normalizer ------------------------------ 80.19 KiB/209.04 KiB
# cffi       ------------------------------ 155.64 KiB/210.52 KiB
# python-dateutil ------------------------------ 131.09 KiB/224.50 KiB
# frozenlist ------------------------------ 80.00 KiB/225.65 KiB
# opentelemetry-semantic-conventions ------------------------------ 96.00 KiB/226.19 KiB
# tomli      ------------------------------ 238.11 KiB/238.11 KiB
# openpyxl   ------------------------------ 125.57 KiB/245.03 KiB
# python-docx ------------------------------ 220.70 KiB/247.06 KiB
# googleapis-common-protos ------------------------------ 174.30 KiB/293.69 KiB
# lance-namespace-urllib3-client ------------------------------ 236.02 KiB/307.40 KiB
# protobuf   ------------------------------ 315.86 KiB/315.86 KiB
# prompt-toolkit ------------------------------ 221.51 KiB/382.26 KiB
# pydantic   ------------------------------ 428.15 KiB/460.92 KiB
# crewai     ------------------------------ 131.24 KiB/462.12 KiB
# mpmath     ------------------------------ 493.07 KiB/523.63 KiB
# huggingface-hub ------------------------------ 462.04 KiB/632.58 KiB
# crewai-tools ------------------------------ 126.84 KiB/723.68 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (2/151)
# fsspec     ------------------------------ 16.00 KiB/198.63 KiB
# propcache  ------------------------------ 95.76 KiB/205.11 KiB
# charset-normalizer ------------------------------ 81.23 KiB/209.04 KiB
# cffi       ------------------------------ 171.64 KiB/210.52 KiB
# python-dateutil ------------------------------ 142.58 KiB/224.50 KiB
# frozenlist ------------------------------ 96.00 KiB/225.65 KiB
# opentelemetry-semantic-conventions ------------------------------ 96.00 KiB/226.19 KiB
# tomli      ------------------------------ 238.11 KiB/238.11 KiB
# openpyxl   ------------------------------ 125.57 KiB/245.03 KiB
# python-docx ------------------------------ 220.70 KiB/247.06 KiB
# googleapis-common-protos ------------------------------ 174.30 KiB/293.69 KiB
# lance-namespace-urllib3-client ------------------------------ 252.02 KiB/307.40 KiB
# protobuf   ------------------------------ 315.86 KiB/315.86 KiB
# prompt-toolkit ------------------------------ 253.51 KiB/382.26 KiB
# crewai     ------------------------------ 131.24 KiB/462.12 KiB
# mpmath     ------------------------------ 509.07 KiB/523.63 KiB
# huggingface-hub ------------------------------ 462.04 KiB/632.58 KiB
# crewai-tools ------------------------------ 126.84 KiB/723.68 KiB
# pyvis      ------------------------------ 568.56 KiB/738.32 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (2/151)
# websockets ------------------------------     0 B/180.30 KiB
# fsspec     ------------------------------ 16.00 KiB/198.63 KiB
# propcache  ------------------------------ 111.76 KiB/205.11 KiB
# charset-normalizer ------------------------------ 97.23 KiB/209.04 KiB
# cffi       ------------------------------ 171.64 KiB/210.52 KiB
# python-dateutil ------------------------------ 158.58 KiB/224.50 KiB
# frozenlist ------------------------------ 112.00 KiB/225.65 KiB
# opentelemetry-semantic-conventions ------------------------------ 96.00 KiB/226.19 KiB
# openpyxl   ------------------------------ 140.68 KiB/245.03 KiB
# python-docx ------------------------------ 236.70 KiB/247.06 KiB
# googleapis-common-protos ------------------------------ 174.30 KiB/293.69 KiB
# lance-namespace-urllib3-client ------------------------------ 252.02 KiB/307.40 KiB
# protobuf   ------------------------------ 315.86 KiB/315.86 KiB
# prompt-toolkit ------------------------------ 253.51 KiB/382.26 KiB
# crewai     ------------------------------ 131.24 KiB/462.12 KiB
# mpmath     ------------------------------ 509.07 KiB/523.63 KiB
# huggingface-hub ------------------------------ 462.04 KiB/632.58 KiB
# crewai-tools ------------------------------ 126.84 KiB/723.68 KiB
# pyvis      ------------------------------ 568.56 KiB/738.32 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (2/151)
# instructor ------------------------------     0 B/173.98 KiB
# opentelemetry-sdk ------------------------------ 16.00 KiB/175.99 KiB
# websockets ------------------------------ 15.89 KiB/180.30 KiB
# fsspec     ------------------------------ 32.39 KiB/198.63 KiB
# propcache  ------------------------------ 142.08 KiB/205.11 KiB
# charset-normalizer ------------------------------ 127.09 KiB/209.04 KiB
# cffi       ------------------------------ 210.52 KiB/210.52 KiB
# python-dateutil ------------------------------ 190.58 KiB/224.50 KiB
# frozenlist ------------------------------ 144.00 KiB/225.65 KiB
# opentelemetry-semantic-conventions ------------------------------ 112.00 KiB/226.19 KiB
# openpyxl   ------------------------------ 140.68 KiB/245.03 KiB
# python-docx ------------------------------ 236.70 KiB/247.06 KiB
# googleapis-common-protos ------------------------------ 190.30 KiB/293.69 KiB
# lance-namespace-urllib3-client ------------------------------ 268.02 KiB/307.40 KiB
# protobuf   ------------------------------ 315.86 KiB/315.86 KiB
# prompt-toolkit ------------------------------ 285.51 KiB/382.26 KiB
# crewai     ------------------------------ 142.78 KiB/462.12 KiB
# mpmath     ------------------------------ 509.07 KiB/523.63 KiB
# huggingface-hub ------------------------------ 478.04 KiB/632.58 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (2/151)
# instructor ------------------------------     0 B/173.98 KiB
# opentelemetry-sdk ------------------------------ 16.00 KiB/175.99 KiB
# websockets ------------------------------ 15.89 KiB/180.30 KiB
# fsspec     ------------------------------ 48.39 KiB/198.63 KiB
# propcache  ------------------------------ 142.08 KiB/205.11 KiB
# charset-normalizer ------------------------------ 143.09 KiB/209.04 KiB
# cffi       ------------------------------ 210.52 KiB/210.52 KiB
# python-dateutil ------------------------------ 190.58 KiB/224.50 KiB
# frozenlist ------------------------------ 144.00 KiB/225.65 KiB
# opentelemetry-semantic-conventions ------------------------------ 112.00 KiB/226.19 KiB
# openpyxl   ------------------------------ 140.68 KiB/245.03 KiB
# python-docx ------------------------------ 236.70 KiB/247.06 KiB
# googleapis-common-protos ------------------------------ 190.30 KiB/293.69 KiB
# lance-namespace-urllib3-client ------------------------------ 268.02 KiB/307.40 KiB
# prompt-toolkit ------------------------------ 285.51 KiB/382.26 KiB
# crewai     ------------------------------ 142.78 KiB/462.12 KiB
# mpmath     ------------------------------ 509.07 KiB/523.63 KiB
# huggingface-hub ------------------------------ 478.04 KiB/632.58 KiB
# crewai-tools ------------------------------ 142.84 KiB/723.68 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (2/151)
# instructor ------------------------------ 16.00 KiB/173.98 KiB
# opentelemetry-sdk ------------------------------ 16.00 KiB/175.99 KiB
# websockets ------------------------------ 15.89 KiB/180.30 KiB
# fsspec     ------------------------------ 48.39 KiB/198.63 KiB
# propcache  ------------------------------ 158.08 KiB/205.11 KiB
# charset-normalizer ------------------------------ 143.09 KiB/209.04 KiB
# cffi       ------------------------------ 210.52 KiB/210.52 KiB
# python-dateutil ------------------------------ 206.58 KiB/224.50 KiB
# frozenlist ------------------------------ 144.00 KiB/225.65 KiB
# opentelemetry-semantic-conventions ------------------------------ 112.00 KiB/226.19 KiB
# openpyxl   ------------------------------ 140.68 KiB/245.03 KiB
# googleapis-common-protos ------------------------------ 190.30 KiB/293.69 KiB
# lance-namespace-urllib3-client ------------------------------ 268.02 KiB/307.40 KiB
# prompt-toolkit ------------------------------ 285.51 KiB/382.26 KiB
# crewai     ------------------------------ 142.78 KiB/462.12 KiB
# mpmath     ------------------------------ 523.63 KiB/523.63 KiB
# huggingface-hub ------------------------------ 478.04 KiB/632.58 KiB
# crewai-tools ------------------------------ 142.84 KiB/723.68 KiB
# pyvis      ------------------------------ 616.56 KiB/738.32 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (2/151)
# oauthlib   ------------------------------     0 B/156.31 KiB
# instructor ------------------------------ 16.00 KiB/173.98 KiB
# opentelemetry-sdk ------------------------------ 16.00 KiB/175.99 KiB
# websockets ------------------------------ 31.79 KiB/180.30 KiB
# fsspec     ------------------------------ 48.39 KiB/198.63 KiB
# propcache  ------------------------------ 174.08 KiB/205.11 KiB
# charset-normalizer ------------------------------ 159.09 KiB/209.04 KiB
# python-dateutil ------------------------------ 222.58 KiB/224.50 KiB
# frozenlist ------------------------------ 176.00 KiB/225.65 KiB
# opentelemetry-semantic-conventions ------------------------------ 112.00 KiB/226.19 KiB
# openpyxl   ------------------------------ 156.68 KiB/245.03 KiB
# googleapis-common-protos ------------------------------ 206.30 KiB/293.69 KiB
# lance-namespace-urllib3-client ------------------------------ 268.02 KiB/307.40 KiB
# prompt-toolkit ------------------------------ 285.51 KiB/382.26 KiB
# crewai     ------------------------------ 142.78 KiB/462.12 KiB
# mpmath     ------------------------------ 523.63 KiB/523.63 KiB
# huggingface-hub ------------------------------ 478.04 KiB/632.58 KiB
# crewai-tools ------------------------------ 142.84 KiB/723.68 KiB
# pyvis      ------------------------------ 632.56 KiB/738.32 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (2/151)
# oauthlib   ------------------------------     0 B/156.31 KiB
# instructor ------------------------------ 16.00 KiB/173.98 KiB
# opentelemetry-sdk ------------------------------ 16.00 KiB/175.99 KiB
# websockets ------------------------------ 31.79 KiB/180.30 KiB
# fsspec     ------------------------------ 48.39 KiB/198.63 KiB
# propcache  ------------------------------ 174.08 KiB/205.11 KiB
# charset-normalizer ------------------------------ 159.09 KiB/209.04 KiB
# python-dateutil ------------------------------ 222.58 KiB/224.50 KiB
# frozenlist ------------------------------ 176.00 KiB/225.65 KiB
# opentelemetry-semantic-conventions ------------------------------ 112.00 KiB/226.19 KiB
# openpyxl   ------------------------------ 156.68 KiB/245.03 KiB
# googleapis-common-protos ------------------------------ 206.30 KiB/293.69 KiB
# lance-namespace-urllib3-client ------------------------------ 268.02 KiB/307.40 KiB
# prompt-toolkit ------------------------------ 285.51 KiB/382.26 KiB
# crewai     ------------------------------ 142.78 KiB/462.12 KiB
# huggingface-hub ------------------------------ 478.04 KiB/632.58 KiB
# crewai-tools ------------------------------ 142.84 KiB/723.68 KiB
# pyvis      ------------------------------ 632.56 KiB/738.32 KiB
# regex      ------------------------------ 700.50 KiB/781.06 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (2/151)
# jinja2     ------------------------------     0 B/131.74 KiB
# certifi    ------------------------------     0 B/132.53 KiB
# docker     ------------------------------ 16.00 KiB/144.31 KiB
# oauthlib   ------------------------------ 16.00 KiB/156.31 KiB
# instructor ------------------------------ 16.00 KiB/173.98 KiB
# opentelemetry-sdk ------------------------------ 48.00 KiB/175.99 KiB
# websockets ------------------------------ 63.32 KiB/180.30 KiB
# fsspec     ------------------------------ 93.13 KiB/198.63 KiB
# propcache  ------------------------------ 190.08 KiB/205.11 KiB
# charset-normalizer ------------------------------ 191.09 KiB/209.04 KiB
# frozenlist ------------------------------ 192.00 KiB/225.65 KiB
# opentelemetry-semantic-conventions ------------------------------ 128.00 KiB/226.19 KiB
# openpyxl   ------------------------------ 156.68 KiB/245.03 KiB
# googleapis-common-protos ------------------------------ 222.41 KiB/293.69 KiB
# lance-namespace-urllib3-client ------------------------------ 285.41 KiB/307.40 KiB
# prompt-toolkit ------------------------------ 317.51 KiB/382.26 KiB
# crewai     ------------------------------ 158.78 KiB/462.12 KiB
# huggingface-hub ------------------------------ 494.04 KiB/632.58 KiB
# crewai-tools ------------------------------ 142.84 KiB/723.68 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (2/151)
# orjson     ------------------------------     0 B/130.45 KiB
# jinja2     ------------------------------ 16.00 KiB/131.74 KiB
# certifi    ------------------------------ 16.00 KiB/132.53 KiB
# docker     ------------------------------ 16.00 KiB/144.31 KiB
# oauthlib   ------------------------------ 16.00 KiB/156.31 KiB
# instructor ------------------------------ 32.00 KiB/173.98 KiB
# opentelemetry-sdk ------------------------------ 64.00 KiB/175.99 KiB
# websockets ------------------------------ 63.32 KiB/180.30 KiB
# fsspec     ------------------------------ 109.13 KiB/198.63 KiB
# propcache  ------------------------------ 205.11 KiB/205.11 KiB
# charset-normalizer ------------------------------ 207.09 KiB/209.04 KiB
# frozenlist ------------------------------ 208.00 KiB/225.65 KiB
# opentelemetry-semantic-conventions ------------------------------ 144.00 KiB/226.19 KiB
# openpyxl   ------------------------------ 172.68 KiB/245.03 KiB
# googleapis-common-protos ------------------------------ 222.41 KiB/293.69 KiB
# prompt-toolkit ------------------------------ 333.51 KiB/382.26 KiB
# crewai     ------------------------------ 158.78 KiB/462.12 KiB
# huggingface-hub ------------------------------ 510.04 KiB/632.58 KiB
# crewai-tools ------------------------------ 158.84 KiB/723.68 KiB
# pyvis      ------------------------------ 680.56 KiB/738.32 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (2/151)
# urllib3    ------------------------------     0 B/128.50 KiB
# orjson     ------------------------------ 16.00 KiB/130.45 KiB
# jinja2     ------------------------------ 48.00 KiB/131.74 KiB
# certifi    ------------------------------ 48.00 KiB/132.53 KiB
# docker     ------------------------------ 48.00 KiB/144.31 KiB
# oauthlib   ------------------------------ 51.50 KiB/156.31 KiB
# instructor ------------------------------ 32.00 KiB/173.98 KiB
# opentelemetry-sdk ------------------------------ 80.00 KiB/175.99 KiB
# websockets ------------------------------ 95.32 KiB/180.30 KiB
# fsspec     ------------------------------ 141.13 KiB/198.63 KiB
# propcache  ------------------------------ 205.11 KiB/205.11 KiB
# charset-normalizer ------------------------------ 209.04 KiB/209.04 KiB
# frozenlist ------------------------------ 224.00 KiB/225.65 KiB
# opentelemetry-semantic-conventions ------------------------------ 160.00 KiB/226.19 KiB
# openpyxl   ------------------------------ 172.68 KiB/245.03 KiB
# googleapis-common-protos ------------------------------ 238.41 KiB/293.69 KiB
# prompt-toolkit ------------------------------ 349.51 KiB/382.26 KiB
# crewai     ------------------------------ 174.78 KiB/462.12 KiB
# huggingface-hub ------------------------------ 510.04 KiB/632.58 KiB
# crewai-tools ------------------------------ 158.84 KiB/723.68 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (17/151)
# urllib3    ------------------------------     0 B/128.50 KiB
# orjson     ------------------------------ 16.00 KiB/130.45 KiB
# jinja2     ------------------------------ 48.00 KiB/131.74 KiB
# certifi    ------------------------------ 48.00 KiB/132.53 KiB
# docker     ------------------------------ 48.00 KiB/144.31 KiB
# oauthlib   ------------------------------ 51.50 KiB/156.31 KiB
# instructor ------------------------------ 32.00 KiB/173.98 KiB
# opentelemetry-sdk ------------------------------ 80.00 KiB/175.99 KiB
# websockets ------------------------------ 95.32 KiB/180.30 KiB
# fsspec     ------------------------------ 141.13 KiB/198.63 KiB
# charset-normalizer ------------------------------ 209.04 KiB/209.04 KiB
# frozenlist ------------------------------ 224.00 KiB/225.65 KiB
# opentelemetry-semantic-conventions ------------------------------ 160.00 KiB/226.19 KiB
# openpyxl   ------------------------------ 172.68 KiB/245.03 KiB
# googleapis-common-protos ------------------------------ 238.41 KiB/293.69 KiB
# prompt-toolkit ------------------------------ 349.51 KiB/382.26 KiB
# crewai     ------------------------------ 174.78 KiB/462.12 KiB
# huggingface-hub ------------------------------ 510.04 KiB/632.58 KiB
# crewai-tools ------------------------------ 158.84 KiB/723.68 KiB
# pyvis      ------------------------------ 712.46 KiB/738.32 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (17/151)
# urllib3    ------------------------------     0 B/128.50 KiB
# orjson     ------------------------------ 16.00 KiB/130.45 KiB
# jinja2     ------------------------------ 48.00 KiB/131.74 KiB
# certifi    ------------------------------ 48.00 KiB/132.53 KiB
# docker     ------------------------------ 48.00 KiB/144.31 KiB
# oauthlib   ------------------------------ 51.50 KiB/156.31 KiB
# instructor ------------------------------ 48.00 KiB/173.98 KiB
# opentelemetry-sdk ------------------------------ 80.00 KiB/175.99 KiB
# websockets ------------------------------ 111.32 KiB/180.30 KiB
# fsspec     ------------------------------ 157.13 KiB/198.63 KiB
# frozenlist ------------------------------ 224.00 KiB/225.65 KiB
# opentelemetry-semantic-conventions ------------------------------ 160.00 KiB/226.19 KiB
# openpyxl   ------------------------------ 172.68 KiB/245.03 KiB
# googleapis-common-protos ------------------------------ 238.41 KiB/293.69 KiB
# prompt-toolkit ------------------------------ 365.51 KiB/382.26 KiB
# crewai     ------------------------------ 174.78 KiB/462.12 KiB
# huggingface-hub ------------------------------ 510.04 KiB/632.58 KiB
# crewai-tools ------------------------------ 158.84 KiB/723.68 KiB
# pyvis      ------------------------------ 712.46 KiB/738.32 KiB
# regex      ------------------------------ 764.16 KiB/781.06 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (17/151)
# urllib3    ------------------------------ 8.53 KiB/128.50 KiB
# orjson     ------------------------------ 32.00 KiB/130.45 KiB
# jinja2     ------------------------------ 48.00 KiB/131.74 KiB
# certifi    ------------------------------ 48.00 KiB/132.53 KiB
# docker     ------------------------------ 48.00 KiB/144.31 KiB
# oauthlib   ------------------------------ 51.50 KiB/156.31 KiB
# instructor ------------------------------ 48.00 KiB/173.98 KiB
# opentelemetry-sdk ------------------------------ 80.00 KiB/175.99 KiB
# websockets ------------------------------ 111.32 KiB/180.30 KiB
# fsspec     ------------------------------ 157.13 KiB/198.63 KiB
# opentelemetry-semantic-conventions ------------------------------ 160.00 KiB/226.19 KiB
# openpyxl   ------------------------------ 188.68 KiB/245.03 KiB
# googleapis-common-protos ------------------------------ 238.41 KiB/293.69 KiB
# prompt-toolkit ------------------------------ 365.51 KiB/382.26 KiB
# crewai     ------------------------------ 190.78 KiB/462.12 KiB
# huggingface-hub ------------------------------ 510.04 KiB/632.58 KiB
# crewai-tools ------------------------------ 158.84 KiB/723.68 KiB
# pyvis      ------------------------------ 712.46 KiB/738.32 KiB
# regex      ------------------------------ 764.16 KiB/781.06 KiB
# pyyaml     ------------------------------ 787.73 KiB/787.73 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (17/151)
# urllib3    ------------------------------ 8.53 KiB/128.50 KiB
# orjson     ------------------------------ 48.00 KiB/130.45 KiB
# jinja2     ------------------------------ 60.72 KiB/131.74 KiB
# certifi    ------------------------------ 63.39 KiB/132.53 KiB
# ...
# stagehand  ------------------------------ 18.94 MiB/35.55 MiB
# lancedb    ------------------------------ 20.20 MiB/44.50 MiB
# ⠼ Preparing packages... (143/151) 19.34 MiB/46.58 MiB
# sympy      ------------------------------ 5.75 MiB/6.01 MiB
# onnxruntime ------------------------------ 15.64 MiB/16.42 MiB
# chromadb   ------------------------------ 18.95 MiB/18.97 MiB
# uv         ------------------------------ 19.90 MiB/23.67 MiB
# stagehand  ------------------------------ 19.48 MiB/35.55 MiB
# lancedb    ------------------------------ 20.86 MiB/44.50 MiB
# ⠴ Preparing packages... (144/151) 20.17 MiB/46.58 MiB
# sympy      ------------------------------ 5.75 MiB/6.01 MiB
# onnxruntime ------------------------------ 15.64 MiB/16.42 MiB
# chromadb   ------------------------------ 18.95 MiB/18.97 MiB
# uv         ------------------------------ 19.90 MiB/23.67 MiB
# stagehand  ------------------------------ 19.48 MiB/35.55 MiB
# lancedb    ------------------------------ 20.86 MiB/44.50 MiB
# ⠴ Preparing packages... (144/151) 20.17 MiB/46.58 MiB
# sympy      ------------------------------ 5.75 MiB/6.01 MiB
# onnxruntime ------------------------------ 15.64 MiB/16.42 MiB
# chromadb   ------------------------------ 18.97 MiB/18.97 MiB
# uv         ------------------------------ 19.90 MiB/23.67 MiB
# stagehand  ------------------------------ 19.48 MiB/35.55 MiB
# lancedb    ------------------------------ 20.86 MiB/44.50 MiB
# ⠴ Preparing packages... (144/151) 20.17 MiB/46.58 MiB
# sympy      ------------------------------ 5.75 MiB/6.01 MiB
# onnxruntime ------------------------------ 15.64 MiB/16.42 MiB
# chromadb   ------------------------------ 18.97 MiB/18.97 MiB
# uv         ------------------------------ 19.90 MiB/23.67 MiB
# stagehand  ------------------------------ 19.48 MiB/35.55 MiB
# lancedb    ------------------------------ 20.86 MiB/44.50 MiB
# ⠴ Preparing packages... (144/151) 20.17 MiB/46.58 MiB
# sympy      ------------------------------ 5.75 MiB/6.01 MiB
# onnxruntime ------------------------------ 15.64 MiB/16.42 MiB
# chromadb   ------------------------------ 18.97 MiB/18.97 MiB
# uv         ------------------------------ 19.97 MiB/23.67 MiB
# stagehand  ------------------------------ 19.48 MiB/35.55 MiB
# lancedb    ------------------------------ 20.86 MiB/44.50 MiB
# ⠴ Preparing packages... (144/151) 20.17 MiB/46.58 MiB
# sympy      ------------------------------ 5.75 MiB/6.01 MiB
# onnxruntime ------------------------------ 15.64 MiB/16.42 MiB
# uv         ------------------------------ 21.41 MiB/23.67 MiB
# stagehand  ------------------------------ 19.48 MiB/35.55 MiB
# lancedb    ------------------------------ 22.12 MiB/44.50 MiB
# ⠴ Preparing packages... (144/151) 21.04 MiB/46.58 MiB
# sympy      ------------------------------ 5.75 MiB/6.01 MiB
# onnxruntime ------------------------------ 15.66 MiB/16.42 MiB
# uv         ------------------------------ 21.41 MiB/23.67 MiB
# stagehand  ------------------------------ 19.48 MiB/35.55 MiB
# lancedb    ------------------------------ 22.12 MiB/44.50 MiB
# ⠦ Preparing packages... (144/151) 21.04 MiB/46.58 MiB
# sympy      ------------------------------ 5.75 MiB/6.01 MiB
# onnxruntime ------------------------------ 15.66 MiB/16.42 MiB
# uv         ------------------------------ 22.57 MiB/23.67 MiB
# stagehand  ------------------------------ 19.78 MiB/35.55 MiB
# lancedb    ------------------------------ 23.44 MiB/44.50 MiB
# ⠦ Preparing packages... (144/151) 21.59 MiB/46.58 MiB
# sympy      ------------------------------ 5.75 MiB/6.01 MiB
# onnxruntime ------------------------------ 15.66 MiB/16.42 MiB
# uv         ------------------------------ 22.57 MiB/23.67 MiB
# stagehand  ------------------------------ 19.78 MiB/35.55 MiB
# lancedb    ------------------------------ 23.44 MiB/44.50 MiB
# ⠦ Preparing packages... (144/151) 21.59 MiB/46.58 MiB
# sympy      ------------------------------ 5.75 MiB/6.01 MiB
# onnxruntime ------------------------------ 15.66 MiB/16.42 MiB
# uv         ------------------------------ 22.57 MiB/23.67 MiB
# stagehand  ------------------------------ 20.13 MiB/35.55 MiB
# lancedb    ------------------------------ 23.44 MiB/44.50 MiB
# ⠧ Preparing packages... (145/151) 21.59 MiB/46.58 MiB
# sympy      ------------------------------ 5.75 MiB/6.01 MiB
# onnxruntime ------------------------------ 15.66 MiB/16.42 MiB
# uv         ------------------------------ 22.57 MiB/23.67 MiB
# stagehand  ------------------------------ 22.06 MiB/35.55 MiB
# lancedb    ------------------------------ 23.44 MiB/44.50 MiB
# ⠧ Preparing packages... (145/151) 21.59 MiB/46.58 MiB
# sympy      ------------------------------ 5.76 MiB/6.01 MiB
# onnxruntime ------------------------------ 15.69 MiB/16.42 MiB
# uv         ------------------------------ 22.57 MiB/23.67 MiB
# stagehand  ------------------------------ 22.12 MiB/35.55 MiB
# lancedb    ------------------------------ 23.44 MiB/44.50 MiB
# ⠧ Preparing packages... (145/151) 24.95 MiB/46.58 MiB
# onnxruntime ------------------------------ 15.70 MiB/16.42 MiB
# uv         ------------------------------ 22.57 MiB/23.67 MiB
# stagehand  ------------------------------ 22.18 MiB/35.55 MiB
# lancedb    ------------------------------ 23.44 MiB/44.50 MiB
# ⠧ Preparing packages... (145/151) 25.06 MiB/46.58 MiB
# onnxruntime ------------------------------ 15.70 MiB/16.42 MiB
# uv         ------------------------------ 22.57 MiB/23.67 MiB
# stagehand  ------------------------------ 22.24 MiB/35.55 MiB
# lancedb    ------------------------------ 23.44 MiB/44.50 MiB
# ⠧ Preparing packages... (145/151) 27.34 MiB/46.58 MiB
# onnxruntime ------------------------------ 15.70 MiB/16.42 MiB
# uv         ------------------------------ 22.57 MiB/23.67 MiB
# stagehand  ------------------------------ 22.37 MiB/35.55 MiB
# lancedb    ------------------------------ 23.44 MiB/44.50 MiB
# ⠧ Preparing packages... (145/151) 30.97 MiB/46.58 MiB
# onnxruntime ------------------------------ 15.70 MiB/16.42 MiB
# uv         ------------------------------ 22.57 MiB/23.67 MiB
# stagehand  ------------------------------ 22.48 MiB/35.55 MiB
# lancedb    ------------------------------ 23.44 MiB/44.50 MiB
# ⠇ Preparing packages... (146/151) 33.67 MiB/46.58 MiB
# onnxruntime ------------------------------ 15.70 MiB/16.42 MiB
# uv         ------------------------------ 23.36 MiB/23.67 MiB
# stagehand  ------------------------------ 22.79 MiB/35.55 MiB
# lancedb    ------------------------------ 23.83 MiB/44.50 MiB
# ⠇ Preparing packages... (146/151) 33.97 MiB/46.58 MiB
# onnxruntime ------------------------------ 15.70 MiB/16.42 MiB
# uv         ------------------------------ 23.36 MiB/23.67 MiB
# stagehand  ------------------------------ 23.18 MiB/35.55 MiB
# lancedb    ------------------------------ 23.91 MiB/44.50 MiB
# ⠇ Preparing packages... (146/151) 33.97 MiB/46.58 MiB
# onnxruntime ------------------------------ 15.70 MiB/16.42 MiB
# uv         ------------------------------ 23.36 MiB/23.67 MiB
# stagehand  ------------------------------ 23.18 MiB/35.55 MiB
# lancedb    ------------------------------ 23.91 MiB/44.50 MiB
# ⠇ Preparing packages... (146/151) 33.97 MiB/46.58 MiB
# onnxruntime ------------------------------ 15.70 MiB/16.42 MiB
# uv         ------------------------------ 23.36 MiB/23.67 MiB
# stagehand  ------------------------------ 23.18 MiB/35.55 MiB
# lancedb    ------------------------------ 28.24 MiB/44.50 MiB
# ⠋ Preparing packages... (146/151) 34.45 MiB/46.58 MiB
# onnxruntime ------------------------------ 15.70 MiB/16.42 MiB
# uv         ------------------------------ 23.36 MiB/23.67 MiB
# stagehand  ------------------------------ 23.18 MiB/35.55 MiB
# lancedb    ------------------------------ 31.02 MiB/44.50 MiB
# ⠋ Preparing packages... (146/151) 36.74 MiB/46.58 MiB
# onnxruntime ------------------------------ 15.70 MiB/16.42 MiB
# uv         ------------------------------ 23.59 MiB/23.67 MiB
# stagehand  ------------------------------ 24.42 MiB/35.55 MiB
# lancedb    ------------------------------ 33.06 MiB/44.50 MiB
# ⠙ Preparing packages... (146/151) 38.58 MiB/46.58 MiB
# onnxruntime ------------------------------ 15.70 MiB/16.42 MiB
# uv         ------------------------------ 23.59 MiB/23.67 MiB
# stagehand  ------------------------------ 24.42 MiB/35.55 MiB
# lancedb    ------------------------------ 33.48 MiB/44.50 MiB
# ⠙ Preparing packages... (146/151) 38.71 MiB/46.58 MiB
# onnxruntime ------------------------------ 15.70 MiB/16.42 MiB
# uv         ------------------------------ 23.59 MiB/23.67 MiB
# stagehand  ------------------------------ 24.42 MiB/35.55 MiB
# lancedb    ------------------------------ 33.58 MiB/44.50 MiB
# ⠙ Preparing packages... (146/151) 38.71 MiB/46.58 MiB
# onnxruntime ------------------------------ 15.70 MiB/16.42 MiB
# uv         ------------------------------ 23.59 MiB/23.67 MiB
# stagehand  ------------------------------ 24.42 MiB/35.55 MiB
# lancedb    ------------------------------ 36.26 MiB/44.50 MiB
# ⠙ Preparing packages... (146/151) 38.71 MiB/46.58 MiB
# onnxruntime ------------------------------ 15.70 MiB/16.42 MiB
# uv         ------------------------------ 23.59 MiB/23.67 MiB
# stagehand  ------------------------------ 24.91 MiB/35.55 MiB
# lancedb    ------------------------------ 37.26 MiB/44.50 MiB
# ⠙ Preparing packages... (146/151) 38.71 MiB/46.58 MiB
# onnxruntime ------------------------------ 15.73 MiB/16.42 MiB
# stagehand  ------------------------------ 25.80 MiB/35.55 MiB
# lancedb    ------------------------------ 37.26 MiB/44.50 MiB
# ⠙ Preparing packages... (146/151) 38.71 MiB/46.58 MiB
# onnxruntime ------------------------------ 15.73 MiB/16.42 MiB
# stagehand  ------------------------------ 27.69 MiB/35.55 MiB
# lancedb    ------------------------------ 37.26 MiB/44.50 MiB
# ⠙ Preparing packages... (146/151) 40.55 MiB/46.58 MiB
# onnxruntime ------------------------------ 15.73 MiB/16.42 MiB
# stagehand  ------------------------------ 30.20 MiB/35.55 MiB
# lancedb    ------------------------------ 37.26 MiB/44.50 MiB
# ⠹ Preparing packages... (147/151) 43.23 MiB/46.58 MiB
# onnxruntime ------------------------------ 15.73 MiB/16.42 MiB
# stagehand  ------------------------------ 30.20 MiB/35.55 MiB
# lancedb    ------------------------------ 37.32 MiB/44.50 MiB
# ⠹ Preparing packages... (147/151) 43.23 MiB/46.58 MiB
# onnxruntime ------------------------------ 15.73 MiB/16.42 MiB
# stagehand  ------------------------------ 30.20 MiB/35.55 MiB
# lancedb    ------------------------------ 37.34 MiB/44.50 MiB
# ⠹ Preparing packages... (147/151) 43.23 MiB/46.58 MiB
# onnxruntime ------------------------------ 15.73 MiB/16.42 MiB
# stagehand  ------------------------------ 30.20 MiB/35.55 MiB
# lancedb    ------------------------------ 38.86 MiB/44.50 MiB
# ⠸ Preparing packages... (147/151) 43.23 MiB/46.58 MiB
# onnxruntime ------------------------------ 15.73 MiB/16.42 MiB
# stagehand  ------------------------------ 30.20 MiB/35.55 MiB
# lancedb    ------------------------------ 40.91 MiB/44.50 MiB
# ⠸ Preparing packages... (147/151) 43.23 MiB/46.58 MiB
# onnxruntime ------------------------------ 15.91 MiB/16.42 MiB
# stagehand  ------------------------------ 30.20 MiB/35.55 MiB
# lancedb    ------------------------------ 42.23 MiB/44.50 MiB
# ⠸ Preparing packages... (147/151) 44.86 MiB/46.58 MiB
# onnxruntime ------------------------------ 15.91 MiB/16.42 MiB
# stagehand  ------------------------------ 30.20 MiB/35.55 MiB
# ⠸ Preparing packages... (147/151) 44.95 MiB/46.58 MiB
# onnxruntime ------------------------------ 15.91 MiB/16.42 MiB
# stagehand  ------------------------------ 31.83 MiB/35.55 MiB
# ⠸ Preparing packages... (147/151) 44.95 MiB/46.58 MiB
# onnxruntime ------------------------------ 15.91 MiB/16.42 MiB
# ⠸ Preparing packages... (147/151) 45.05 MiB/46.58 MiB
# onnxruntime ------------------------------ 15.91 MiB/16.42 MiB
# ⠸ Preparing packages... (147/151) 45.08 MiB/46.58 MiB
# onnxruntime ------------------------------ 15.91 MiB/16.42 MiB
# ⠼ Preparing packages... (149/151) 45.52 MiB/46.58 MiB
# Prepared 151 packages in 7.83s
# Installed 151 packages in 197ms
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.13.5
#  + aiosignal==1.4.0
#  + annotated-doc==0.0.4
#  + annotated-types==0.7.0
#  + anyio==4.13.0
#  + appdirs==1.4.4
#  + asttokens==3.0.1
#  + attrs==26.1.0
#  + backoff==2.2.1
#  + bcrypt==5.0.0
#  + beautifulsoup4==4.14.3
#  + blinker==1.9.0
#  + build==1.5.0
#  + certifi==2026.4.22
#  + cffi==2.0.0
#  + charset-normalizer==3.4.7
#  + chromadb==1.1.1
#  + click==8.3.3
#  + crewai==0.203.2
#  + crewai-tools==0.76.0
#  + cryptography==47.0.0
#  + decorator==5.2.1
#  + defusedxml==0.7.1
#  + deprecation==2.1.0
#  + distro==1.9.0
#  + docker==7.1.0
#  + docstring-parser==0.18.0
#  + durationpy==0.10
#  + et-xmlfile==2.0.0
#  + executing==2.2.1
#  + filelock==3.29.0
#  + flatbuffers==25.12.19
#  + frozenlist==1.8.0
#  + fsspec==2026.4.0
#  + googleapis-common-protos==1.74.0
#  + grpcio==1.80.0
#  + h11==0.16.0
#  + hf-xet==1.4.3
#  + httpcore==1.0.9
#  + httptools==0.7.1
#  + httpx==0.28.1
#  + huggingface-hub==1.12.2
#  + idna==3.13
#  + importlib-metadata==8.7.1
#  + importlib-resources==7.1.0
#  + instructor==1.15.1
#  + ipython==8.39.0
#  + jedi==0.19.2
#  + jinja2==3.1.6
#  + jiter==0.13.0
#  + json-repair==0.25.2
#  + json5==0.14.0
#  + jsonpickle==4.1.1
#  + jsonref==1.1.0
#  + jsonschema==4.26.0
#  + jsonschema-specifications==2025.9.1
#  + kubernetes==35.0.0
#  + lance-namespace==0.7.2
#  + lance-namespace-urllib3-client==0.7.2
#  + lancedb==0.30.2
#  + litellm==1.74.9
#  + lxml==6.1.0
#  + markdown-it-py==4.0.0
#  + markupsafe==3.0.3
#  + matplotlib-inline==0.2.1
#  + mdurl==0.1.2
#  + mmh3==5.2.1
#  + mpmath==1.3.0
#  + multidict==6.7.1
#  + networkx==3.4.2
#  + new-project==0.1.0 (from file:///home/jovyan/work/L13/new_project)
#  + numpy==2.2.6
#  + oauthlib==3.3.1
#  + onnxruntime==1.24.3
#  + openai==2.33.0
#  + openpyxl==3.1.5
#  + opentelemetry-api==1.41.1
#  + opentelemetry-exporter-otlp-proto-common==1.41.1
#  + opentelemetry-exporter-otlp-proto-grpc==1.41.1
#  + opentelemetry-exporter-otlp-proto-http==1.41.1
#  + opentelemetry-proto==1.41.1
#  + opentelemetry-sdk==1.41.1
#  + opentelemetry-semantic-conventions==0.62b1
#  + orjson==3.11.8
#  + overrides==7.7.0
#  + packaging==26.2
#  + parso==0.8.6
#  + pdfminer-six==20251230
#  + pdfplumber==0.11.9
#  + pexpect==4.9.0
#  + pillow==12.2.0
#  + portalocker==2.7.0
#  + posthog==5.4.0
#  + prompt-toolkit==3.0.52
#  + propcache==0.4.1
#  + protobuf==6.33.6
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pyarrow==24.0.0
#  + pybase64==1.4.3
#  + pycparser==3.0
#  + pydantic==2.13.3
#  + pydantic-core==2.46.3
#  + pydantic-settings==2.14.0
#  + pygments==2.20.0
#  + pyjwt==2.12.1
#  + pypdf==6.10.2
#  + pypdfium2==5.7.1
#  + pypika==0.51.1
#  + pyproject-hooks==1.2.0
#  + python-dateutil==2.9.0.post0
#  + python-docx==1.2.0
#  + python-dotenv==1.2.2
#  + pytube==15.0.0
#  + pyvis==0.3.2
#  + pyyaml==6.0.3
#  + referencing==0.37.0
#  + regex==2026.4.4
#  + requests==2.33.1
#  + requests-oauthlib==2.0.0
#  + rich==14.3.4
#  + rpds-py==0.30.0
#  + shellingham==1.5.4
#  + six==1.17.0
#  + sniffio==1.3.1
#  + soupsieve==2.8.3
#  + stack-data==0.6.3
#  + stagehand==3.19.5
#  + sympy==1.14.0
#  + tenacity==9.1.4
#  + tiktoken==0.12.0
#  + tokenizers==0.23.1
#  + tomli==2.4.1
#  + tomli-w==1.2.0
#  + tqdm==4.67.3
#  + traitlets==5.14.3
#  + typer==0.25.0
#  + typing-extensions==4.15.0
#  + typing-inspection==0.4.2
#  + urllib3==2.6.3
#  + uv==0.11.8
#  + uvicorn==0.46.0
#  + uvloop==0.22.1
#  + watchfiles==1.1.1
#  + wcwidth==0.6.0
#  + websocket-client==1.9.0
#  + websockets==16.0
#  + yarl==1.23.0
#  + youtube-transcript-api==1.2.4
#  + zipp==3.23.1

# %% [markdown]
# ## Setting Environment Variables

# %%
! cat new_project/.env
# Out:
# OPENAI_API_KEY=YOUR_API_KEY_HERE

# %% [markdown]
# ## Running the Crew

# %%
! cd new_project && crewai run
# Out:
# Running the Crew
# ╭─────────────────────────── Crew Execution Started ───────────────────────────╮
# │                                                                              │
# │  Crew Execution Started                                                      │
# │  Name: crew                                                                  │
# │  ID: 51d7862a-d0cb-4ab1-9b79-c8c9eb8ae361                                    │
# │  Tool Args:                                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │  Task: Conduct a thorough research about AI LLMs Make sure you find any      │
# │  interesting and relevant information given the current year is 2024.        │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Status: Executing Task...
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │  Final Answer:                                                               │
# │  1. **Advancements in Zero-Shot and Few-Shot Learning**: AI LLMs have seen   │
# │  significant improvements in zero-shot and few-shot learning capabilities.   │
# │  Models are increasingly able to perform complex tasks without explicit      │
# │  training examples, improving versatility across various applications.       │
# │                                                                              │
# │  2. **Integration of Multimodal Capabilities**: Recent developments have     │
# │  focused on integrating text with other modalities such as images and        │
# │  audio. Models like CLIP and DALL-E have showcased enhanced understanding    │
# │  and generation of content spanning different data types, broadening the     │
# │  scope of LLM applications.                                                  │
# │                                                                              │
# │  3. **Increased Model Sizes and Efficiency**: 2024 has witnessed the         │
# │  release of larger models with enhanced efficiency. Techniques such as       │
# │  model pruning and quantization are employed to maximize performance while   │
# │  reducing the computational cost, enabling developers to deploy LLMs in      │
# │  more resource-constrained environments.                                     │
# │                                                                              │
# │  4. **Fine-Tuning Innovations**: New methodologies for fine-tuning LLMs      │
# │  allow for more customized models tailored to specific industries or tasks,  │
# │  including healthcare, finance, and customer service. This has led to        │
# │  better outcomes in specialized applications.                                │
# │                                                                              │
# │  5. **Ethical AI Initiatives**: As LLMs gain popularity, there is a growing  │
# │  focus on ethical considerations and bias mitigation. Organizations are      │
# │  implementing comprehensive frameworks to ensure LLMs are developed and      │
# │  used responsibly, addressing biases and promoting fairness.                 │
# │                                                                              │
# │  6. **Improved Accessibility through APIs**: Major tech companies are        │
# │  increasing access to LLM capabilities through user-friendly APIs. This      │
# │  democratization allows smaller businesses and individual developers to      │
# │  leverage advanced AI technologies without extensive resources.              │
# │                                                                              │
# │  7. **Real-Time Interaction Enhancements**: Innovations in architecture,     │
# │  particularly in transformer-based models, have improved real-time           │
# │  interaction with LLMs. Users can now experience quicker and more fluent     │
# │  conversations, enhancing the usability of conversational agents.            │
# │                                                                              │
# │  8. **Hybrid Models for Increased Context**: There's a trend towards         │
# │  developing hybrid models that combine traditional rule-based systems with   │
# │  LLMs. This approach aims to improve contextual understanding and            │
# │  decision-making capabilities in applications like customer service and      │
# │  intelligent automation.                                                     │
# │                                                                              │
# │  9. **Deployment of Task-Specific LLMs**: Organizations are increasingly     │
# │  adopting task-specific LLMs that are optimized for particular use cases,    │
# │  allowing for better performance in targeted areas compared to               │
# │  general-purpose models, leading to improvements in productivity and         │
# │  accuracy.                                                                   │
# │                                                                              │
# │  10. **Sustainability Focus**: The AI community is responding to             │
# │  environmental concerns by increasing efforts to promote sustainability in   │
# │  LLM training. Techniques to reduce the carbon footprint of training large   │
# │  models, such as more efficient algorithms and green data centers, are       │
# │  becoming priorities in research and development.                            │
# │                                                                              │
# │  These points reflect the ongoing advancements and trends within the field   │
# │  of AI LLMs as we step into 2024, indicating a vibrant landscape of          │
# │  continuous innovation.                                                      │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
#     Assigned to: AI LLMs Senior Data Researcher
#
#     Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: research_task                                                         │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │  Tool Args:                                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │  Task: Review the context you got and expand each topic into a full section  │
# │  for a report. Make sure the report is detailed and contains any and all     │
# │  relevant information.                                                       │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Status: Executing Task...
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │  Final Answer:                                                               │
# │  # Report on Recent Advancements in AI Language Models (LLMs)                │
# │                                                                              │
# │  This report explores the latest trends and advancements in the field of AI  │
# │  Language Models (LLMs), highlighting key developments as we enter 2024.     │
# │  Each section delves into critical areas of progress, providing a            │
# │  comprehensive overview of the current landscape in AI technologies.         │
# │                                                                              │
# │  ## 1. Advancements in Zero-Shot and Few-Shot Learning                       │
# │                                                                              │
# │  AI LLMs have made remarkable strides in zero-shot and few-shot learning     │
# │  capabilities. These advancements enable models to perform a wide range of   │
# │  complex tasks without requiring extensive, labeled data for training.       │
# │  Zero-shot learning allows models to interpret new tasks based solely on     │
# │  their understanding derived from previously learned concepts. Conversely,   │
# │  few-shot learning enables models to generalize from only a handful of       │
# │  examples, dramatically improving versatility across various applications,   │
# │  from natural language processing to image recognition. The implications of  │
# │  these advancements are vast, as they lower the barrier to entry for         │
# │  deploying AI solutions in a multitude of domains, making it possible to     │
# │  automate tasks even in scenarios where data is scarce.                      │
# │                                                                              │
# │  ## 2. Integration of Multimodal Capabilities                                │
# │                                                                              │
# │  The integration of multimodal capabilities marks a significant step         │
# │  forward in LLM development. Recent models, such as CLIP and DALL-E,         │
# │  demonstrate an enhanced ability to understand and generate content across   │
# │  diverse data types, including text, images, and audio. This multimodal      │
# │  approach allows for richer interactions and applications, as the models     │
# │  can leverage information from various sources to create more nuanced        │
# │  outputs. For instance, users can input a text query and receive an image    │
# │  or audio response that accurately reflects the content requested, thereby   │
# │  expanding the potential use cases of LLMs in areas like digital content     │
# │  creation, multimedia education, and interactive storytelling.               │
# │                                                                              │
# │  ## 3. Increased Model Sizes and Efficiency                                  │
# │                                                                              │
# │  The landscape of AI language models in 2024 has been characterized by the   │
# │  release of larger, more sophisticated models. Alongside size expansion,     │
# │  significant emphasis has been placed on efficiency to optimize performance  │
# │  while managing computational costs. Techniques such as model pruning,       │
# │  which reduces the number of parameters by eliminating redundant ones, and   │
# │  quantization, which simplifies the number representation, are increasingly  │
# │  utilized. These innovations allow developers to deploy LLMs in              │
# │  environments with limited resources, making high-performance AI accessible  │
# │  to a broader range of applications and users.                               │
# │                                                                              │
# │  ## 4. Fine-Tuning Innovations                                               │
# │                                                                              │
# │  Fine-tuning methodologies have undergone significant advancements,          │
# │  allowing for the creation of highly customized models tailored for          │
# │  specific industries and tasks. This is particularly vital in sectors like   │
# │  healthcare, finance, and customer service, where precision and contextual   │
# │  relevance are paramount. New techniques facilitate targeted modifications   │
# │  of LLMs, enabling them to better understand domain-specific jargon and      │
# │  handle industry-specific queries more effectively. As a result,             │
# │  organizations using such fine-tuned models report improved outcomes and     │
# │  increased productivity in their operations.                                 │
# │                                                                              │
# │  ## 5. Ethical AI Initiatives                                                │
# │                                                                              │
# │  With the growing prevalence of LLMs comes a heightened awareness of         │
# │  ethical considerations surrounding AI use—including biases present in       │
# │  training datasets and the implications of AI-generated content. Various     │
# │  organizations are proactively implementing frameworks aimed at ensuring     │
# │  the responsible development and deployment of LLMs. These initiatives       │
# │  focus on bias mitigation, transparency in model decision-making, and the    │
# │  promotion of fairness across applications. By addressing these ethical      │
# │  concerns, researchers and organizations hope to foster user trust and the   │
# │  responsible utilization of AI technologies.                                 │
# │                                                                              │
# │  ## 6. Improved Accessibility through APIs                                   │
# │                                                                              │
# │  Accessibility to advanced LLM capabilities has surged due to the            │
# │  development of user-friendly APIs by major tech companies. This             │
# │  democratization of AI technology enables smaller businesses and individual  │
# │  developers to leverage sophisticated language models without needing        │
# │  extensive computational resources or in-depth knowledge of machine          │
# │  learning. The proliferation of APIs empowers diverse sectors to integrate   │
# │  AI into their workflows, enhancing overall productivity and innovation      │
# │  across industries.                                                          │
# │                                                                              │
# │  ## 7. Real-Time Interaction Enhancements                                    │
# │                                                                              │
# │  Innovations in architecture, particularly the transformer-based models      │
# │  that underlie many LLMs, have led to substantial improvements in real-time  │
# │  interaction. Users can now engage in quicker, more fluid conversations      │
# │  with conversational agents, significantly enhancing usability. This         │
# │  advancement has implications for customer service, virtual assistants, and  │
# │  interactive AI applications, as it allows for more natural interactions     │
# │  and faster resolutions to user inquiries, thereby improving overall user    │
# │  experience.                                                                 │
# │                                                                              │
# │  ## 8. Hybrid Models for Increased Context                                   │
# │                                                                              │
# │  There is an emerging trend towards hybrid models that integrate             │
# │  traditional rule-based systems with LLMs to enhance contextual              │
# │  understanding and decision-making. This approach is particularly            │
# │  beneficial in domains such as customer service and intelligent automation,  │
# │  where contextual relevance is critical. By combining the strengths of       │
# │  rule-based logic (such as consistency and reliability) with the             │
# │  versatility and adaptability of LLMs, these hybrid models are better        │
# │  equipped to handle complex inquiries and provide accurate, context-aware    │
# │  responses.                                                                  │
# │                                                                              │
# │  ## 9. Deployment of Task-Specific LLMs                                      │
# │                                                                              │
# │  Organizations are increasingly opting for task-specific LLMs optimized for  │
# │  particular use cases. These tailored models outperform general-purpose      │
# │  models in targeted tasks, resulting in significant improvements in          │
# │  productivity and accuracy. For instance, a model specifically designed for  │
# │  legal document analysis may achieve higher performance metrics in           │
# │  understanding legal language than a more generalized LLM. This trend        │
# │  underscores the growing recognition of the need for specialized solutions   │
# │  that meet the unique demands of different industries.                       │
# │                                                                              │
# │  ## 10. Sustainability Focus                                                 │
# │                                                                              │
# │  As environmental concerns gain traction, the AI community is intensifying   │
# │  efforts to develop more sustainable practices in LLM training. This         │
# │  includes exploring efficient training algorithms, minimizing data center    │
# │  energy consumption, and utilizing greener technology in AI development.     │
# │  Researchers are prioritizing techniques that reduce the carbon footprint    │
# │  associated with training large models, reflecting a broader commitment to   │
# │  sustainability in AI research and promoting responsible innovation moving   │
# │  forward.                                                                    │
# │                                                                              │
# │  In conclusion, the ongoing advancements and trends in AI LLMs signify a     │
# │  dynamic landscape rife with innovation as we move into 2024. These          │
# │  developments not only enhance the capabilities and efficiency of LLMs but   │
# │  also address crucial ethical considerations, improving their applicability  │
# │  and acceptance across various industries.                                   │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: f1cf2e4b-7488-4337-91af-9660a891c988)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 735fb892-827c-4452-93b0-19e95fb0d55e)
#     Assigned to: AI LLMs Reporting Analyst
#
#     Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: reporting_task                                                        │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │  Tool Args:                                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── Crew Completion ───────────────────────────────╮
# │                                                                              │
# │  Crew Execution Completed                                                    │
# │  Name: crew                                                                  │
# │  ID: 51d7862a-d0cb-4ab1-9b79-c8c9eb8ae361                                    │
# │  Tool Args:                                                                  │
# │  Final Output: # Report on Recent Advancements in AI Language Models (LLMs)  │
# │                                                                              │
# │  This report explores the latest trends and advancements in the field of AI  │
# │  Language Models (LLMs), highlighting key developments as we enter 2024.     │
# │  Each section delves into critical areas of progress, providing a            │
# │  comprehensive overview of the current landscape in AI technologies.         │
# │                                                                              │
# │  ## 1. Advancements in Zero-Shot and Few-Shot Learning                       │
# │                                                                              │
# │  AI LLMs have made remarkable strides in zero-shot and few-shot learning     │
# │  capabilities. These advancements enable models to perform a wide range of   │
# │  complex tasks without requiring extensive, labeled data for training.       │
# │  Zero-shot learning allows models to interpret new tasks based solely on     │
# │  their understanding derived from previously learned concepts. Conversely,   │
# │  few-shot learning enables models to generalize from only a handful of       │
# │  examples, dramatically improving versatility across various applications,   │
# │  from natural language processing to image recognition. The implications of  │
# │  these advancements are vast, as they lower the barrier to entry for         │
# │  deploying AI solutions in a multitude of domains, making it possible to     │
# │  automate tasks even in scenarios where data is scarce.                      │
# │                                                                              │
# │  ## 2. Integration of Multimodal Capabilities                                │
# │                                                                              │
# │  The integration of multimodal capabilities marks a significant step         │
# │  forward in LLM development. Recent models, such as CLIP and DALL-E,         │
# │  demonstrate an enhanced ability to understand and generate content across   │
# │  diverse data types, including text, images, and audio. This multimodal      │
# │  approach allows for richer interactions and applications, as the models     │
# │  can leverage information from various sources to create more nuanced        │
# │  outputs. For instance, users can input a text query and receive an image    │
# │  or audio response that accurately reflects the content requested, thereby   │
# │  expanding the potential use cases of LLMs in areas like digital content     │
# │  creation, multimedia education, and interactive storytelling.               │
# │                                                                              │
# │  ## 3. Increased Model Sizes and Efficiency                                  │
# │                                                                              │
# │  The landscape of AI language models in 2024 has been characterized by the   │
# │  release of larger, more sophisticated models. Alongside size expansion,     │
# │  significant emphasis has been placed on efficiency to optimize performance  │
# │  while managing computational costs. Techniques such as model pruning,       │
# │  which reduces the number of parameters by eliminating redundant ones, and   │
# │  quantization, which simplifies the number representation, are increasingly  │
# │  utilized. These innovations allow developers to deploy LLMs in              │
# │  environments with limited resources, making high-performance AI accessible  │
# │  to a broader range of applications and users.                               │
# │                                                                              │
# │  ## 4. Fine-Tuning Innovations                                               │
# │                                                                              │
# │  Fine-tuning methodologies have undergone significant advancements,          │
# │  allowing for the creation of highly customized models tailored for          │
# │  specific industries and tasks. This is particularly vital in sectors like   │
# │  healthcare, finance, and customer service, where precision and contextual   │
# │  relevance are paramount. New techniques facilitate targeted modifications   │
# │  of LLMs, enabling them to better understand domain-specific jargon and      │
# │  handle industry-specific queries more effectively. As a result,             │
# │  organizations using such fine-tuned models report improved outcomes and     │
# │  increased productivity in their operations.                                 │
# │                                                                              │
# │  ## 5. Ethical AI Initiatives                                                │
# │                                                                              │
# │  With the growing prevalence of LLMs comes a heightened awareness of         │
# │  ethical considerations surrounding AI use—including biases present in       │
# │  training datasets and the implications of AI-generated content. Various     │
# │  organizations are proactively implementing frameworks aimed at ensuring     │
# │  the responsible development and deployment of LLMs. These initiatives       │
# │  focus on bias mitigation, transparency in model decision-making, and the    │
# │  promotion of fairness across applications. By addressing these ethical      │
# │  concerns, researchers and organizations hope to foster user trust and the   │
# │  responsible utilization of AI technologies.                                 │
# │                                                                              │
# │  ## 6. Improved Accessibility through APIs                                   │
# │                                                                              │
# │  Accessibility to advanced LLM capabilities has surged due to the            │
# │  development of user-friendly APIs by major tech companies. This             │
# │  democratization of AI technology enables smaller businesses and individual  │
# │  developers to leverage sophisticated language models without needing        │
# │  extensive computational resources or in-depth knowledge of machine          │
# │  learning. The proliferation of APIs empowers diverse sectors to integrate   │
# │  AI into their workflows, enhancing overall productivity and innovation      │
# │  across industries.                                                          │
# │                                                                              │
# │  ## 7. Real-Time Interaction Enhancements                                    │
# │                                                                              │
# │  Innovations in architecture, particularly the transformer-based models      │
# │  that underlie many LLMs, have led to substantial improvements in real-time  │
# │  interaction. Users can now engage in quicker, more fluid conversations      │
# │  with conversational agents, significantly enhancing usability. This         │
# │  advancement has implications for customer service, virtual assistants, and  │
# │  interactive AI applications, as it allows for more natural interactions     │
# │  and faster resolutions to user inquiries, thereby improving overall user    │
# │  experience.                                                                 │
# │                                                                              │
# │  ## 8. Hybrid Models for Increased Context                                   │
# │                                                                              │
# │  There is an emerging trend towards hybrid models that integrate             │
# │  traditional rule-based systems with LLMs to enhance contextual              │
# │  understanding and decision-making. This approach is particularly            │
# │  beneficial in domains such as customer service and intelligent automation,  │
# │  where contextual relevance is critical. By combining the strengths of       │
# │  rule-based logic (such as consistency and reliability) with the             │
# │  versatility and adaptability of LLMs, these hybrid models are better        │
# │  equipped to handle complex inquiries and provide accurate, context-aware    │
# │  responses.                                                                  │
# │                                                                              │
# │  ## 9. Deployment of Task-Specific LLMs                                      │
# │                                                                              │
# │  Organizations are increasingly opting for task-specific LLMs optimized for  │
# │  particular use cases. These tailored models outperform general-purpose      │
# │  models in targeted tasks, resulting in significant improvements in          │
# │  productivity and accuracy. For instance, a model specifically designed for  │
# │  legal document analysis may achieve higher performance metrics in           │
# │  understanding legal language than a more generalized LLM. This trend        │
# │  underscores the growing recognition of the need for specialized solutions   │
# │  that meet the unique demands of different industries.                       │
# │                                                                              │
# │  ## 10. Sustainability Focus                                                 │
# │                                                                              │
# │  As environmental concerns gain traction, the AI community is intensifying   │
# │  efforts to develop more sustainable practices in LLM training. This         │
# │  includes exploring efficient training algorithms, minimizing data center    │
# │  energy consumption, and utilizing greener technology in AI development.     │
# │  Researchers are prioritizing techniques that reduce the carbon footprint    │
# │  associated with training large models, reflecting a broader commitment to   │
# │  sustainability in AI research and promoting responsible innovation moving   │
# │  forward.                                                                    │
# │                                                                              │
# │  In conclusion, the ongoing advancements and trends in AI LLMs signify a     │
# │  dynamic landscape rife with innovation as we move into 2024. These          │
# │  developments not only enhance the capabilities and efficiency of LLMs but   │
# │  also address crucial ethical considerations, improving their applicability  │
# │  and acceptance across various industries.                                   │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
#
#
# ╭────────────────────────────── Execution Traces ──────────────────────────────╮
# │                                                                              │
# │  🔍 Detailed execution traces are available!                                 │
# │                                                                              │
# │  View insights including:                                                    │
# │    • Agent decision-making process                                           │
# │    • Task execution flow and timing                                          │
# │    • Tool usage details                                                      │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Would you like to view your execution traces? [y/N] (20s timeout):

# %% [markdown]
# ## Flows CLI - Command Line Interface

# %%
! crewai create flow new_flow
# Out:
# Creating flow new_flow...
# Flow new_flow created successfully!

# %%
! ls -1 new_flow
# Out:
# README.md
# pyproject.toml
# src
# tests

# %%
! ls -1 new_flow/src/new_flow/
# Out:
# __init__.py
# crews
# main.py
# tools
