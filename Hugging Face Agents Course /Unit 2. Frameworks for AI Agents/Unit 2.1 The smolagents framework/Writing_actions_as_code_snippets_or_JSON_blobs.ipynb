# %% [markdown]
# <a href="https://colab.research.google.com/github/5atish/TrainingCourse/blob/main/Hugging%20Face%20Agents%20Course%20/Unit%202.%20Frameworks%20for%20AI%20Agents/Unit%202.1%20The%20smolagents%20framework/Writing_actions_as_code_snippets_or_JSON_blobs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install smolagents
# Out:
# Collecting smolagents
#   Downloading smolagents-1.26.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: huggingface-hub>=0.31.2 in /usr/local/lib/python3.13/dist-packages (from smolagents) (1.28.0)
# Requirement already satisfied: requests>=2.32.3 in /usr/local/lib/python3.13/dist-packages (from smolagents) (2.32.4)
# Requirement already satisfied: rich>=13.9.4 in /usr/local/lib/python3.13/dist-packages (from smolagents) (13.9.4)
# Requirement already satisfied: jinja2>=3.1.4 in /usr/local/lib/python3.13/dist-packages (from smolagents) (3.1.6)
# Requirement already satisfied: pillow>=10.0.1 in /usr/local/lib/python3.13/dist-packages (from smolagents) (11.3.0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.13/dist-packages (from smolagents) (1.2.3)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=0.31.2->smolagents) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=0.31.2->smolagents) (3.32.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=0.31.2->smolagents) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=0.31.2->smolagents) (1.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=0.31.2->smolagents) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=0.31.2->smolagents) (26.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=0.31.2->smolagents) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=0.31.2->smolagents) (4.67.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=0.31.2->smolagents) (4.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2>=3.1.4->smolagents) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.32.3->smolagents) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests>=2.32.3->smolagents) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests>=2.32.3->smolagents) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests>=2.32.3->smolagents) (2026.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.9.4->smolagents) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.9.4->smolagents) (2.21.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.31.2->smolagents) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.31.2->smolagents) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.31.2->smolagents) (0.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->smolagents) (0.1.2)
# Downloading smolagents-1.26.0-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.5/161.5 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: smolagents
# Successfully installed smolagents-1.26.0

# %%
# !pip install ddgs
# Out:
# Collecting ddgs
#   Downloading ddgs-9.16.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.13/dist-packages (from ddgs) (8.4.2)
# Collecting primp>=1.3.1 (from ddgs)
#   Downloading primp-2.0.0-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Requirement already satisfied: lxml>=4.9.4 in /usr/local/lib/python3.13/dist-packages (from ddgs) (6.1.2)
# Downloading ddgs-9.16.0-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 kB 2.1 MB/s eta 0:00:00
# Downloading primp-2.0.0-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 57.1 MB/s eta 0:00:00
# Installing collected packages: primp, ddgs
# Successfully installed ddgs-9.16.0 primp-2.0.0

# %%
from smolagents import DuckDuckGoSearchTool

web_search = DuckDuckGoSearchTool()

for query in [
    "Best catering services in Gotham City",
    "Party theme ideas for superheroes"
]:
    print(web_search(f"Search for: {query}"))
# Out:
# ## Search Results
#
# [Catering NYC: Corporate Catering And Wedding - Gotham Catering And Events](https://gothamcateringnyc.com/)
# May 16, 2016 - The Gotham’s Corporate Catering department offers our corporate clients seamless service in all areas of your catering needs. From food preparation to transportation and service, we specialize in professionalism. We proudly practice CCSR: Corporate Catering Social Responsibility.
#
# [Contact the Best Corporate Catering Services in New York City](https://gothamcateringnyc.com/contact/)
# 1 month ago - Contact Gotham Catering & Events for corporate catering, wedding catering, and full-service event planning throughout NYC. As the most sought-after catering and events company in New York City, we deliver unbelievably delicious food, unsurpassed ...
#
# [Your Best Events, Corporate Catering IN NYC](https://gothamcateringnyc.com/corporate-catering/)
# February 2, 2026 - Midtown Breakfast Catering: Conveniently located in midtown NYC, our breakfast catering service ensures you have easy access to a delightful morning meal, no matter where you are in the city.
#
# Dec 6, 2022 · This post is packed full of superheros theme party ideas to get you started! From decorations and easy superhero party food ideas to Superhero games and activities, we’ve got everything you need to make your child’s party a success.
#
# [Superhero Birthday Party Ideas and Free Printables](https://www.craftionary.net/superhero-birthday-party/)
# Jul 21, 2025 · From costumes and party favors to games and DIY decorations, you can create a fun and immersive experience that kids will talk about for weeks. You’ll find everything you need to organize the ultimate superhero party with budget-friendly DIYs, and free printable templates. We will cover these ideas for the superhero birthday party:
#
# [Ideas for a Superhero Party! - Thimble and Twig](https://thimbleandtwig.com/ideas-superhero-party/)
# April 16, 2024 - If you’re looking to hold your very own Superhero Party – check out these lovely ideas from across the world wide web……. First up is the invitations! Try these superhero birthday invitations. I love this Captain America Cake idea from Growing Up Gabel or this inspiring Superhero cake design from Fun with Mama. For lots more game ideas try this Robin themed party from 123Homeschool4me or to find out how to run a Superhero Training Camp at your party, Eastcoast Mommy has some amazing ideas.
#
# [Best Superhero Party Theme Ideas](https://captain-fantastic.co.uk/blog/best-superhero-party-theme-ideas/)
# Picture a Marvel Madness party, immersing your guests in a universe of iconic heroes, or embark on a heroic journey with the Avengers Assemble theme. From crafting DIY superhero capes to indulging in a heroic movie marathon, each idea brings ...
#
# [Superhero-Themed Party Ideas & Decorations | CORKCICLE.](https://corkcicle.com/blogs/lifestyle/marvel-themed-party-ideas)
# For instance, you can center your celebration around Spider-Man with web-themed decorations, Spider-Man-shaped cookies, and even a Spider-Man-themed cake. ... The centerpiece of any superhero party is the superhero cake.
#
# [320 Best Superhero Theme Party ideas in 2026](https://www.pinterest.com/felicia51/superhero-theme-party/)
# I am not a fan of providing more food than needed in a birthday party. Drink, main course, side and dessert. It is more than enough. Also, you don't have to have a cake. In this case brownies were a hit! You can purchase all decorations at www.craftophologie.etsy.com #momof3 #mompreneur #shopsmall #shopsmallbusiness #craftophologie #craftophologiemadethat... ... Superman /Wonderwoman Birthday Bash 1-11-2014 #petitepartyplanning #candybuffet #candystation #superman #wonderwoman ... Avengers Themed Letters for a special little boy.

# %%
from smolagents import ToolCallingAgent, WebSearchTool, InferenceClientModel

# %%
from smolagents import CodeAgent, WebSearchTool, InferenceClientModel

model = InferenceClientModel(model_id='Qwen/Qwen2.5-Coder-32B-Instruct')
agent = CodeAgent(tools=[WebSearchTool()], model=model)
agent.run("Search for the best music recommendations for a party at the Wayne's mansion.")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Search for the best music recommendations for a party at the Wayne's mansion.                                   │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-Coder-32B-Instruct ────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   search_results = web_search(query="best music recommendations for Wayne's mansion party")
#   print(search_results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [WAYNE soundtrack - playlist by Charlie Linskey |
# Spotify](https://open.spotify.com/playlist/5iVbp78KnovfXzpwSOgzDB)
# Playlist · WAYNE soundtrack · 46 items · 10.1K saves
#
# [The 75 Best Party Songs That Will Get Everyone Dancing -
# Gear4music](https://www.gear4music.com/blog/best-party-songs/)
# Creating the perfect soundtrack is crucial to getting the right atmosphere at your event. If you're throwing a
# party , there are countless songs that will get everyone up and dancing; even once you've chosen your mix, you'll
# probably still think of more later! So, to keep things simple, we've compiled the best  party songs of all time,
# from timeless classics to contemporary hits, giving ...
#
# [Song Lists to help you plan the perfect music for your event!](https://pianistforparties.com/songs/)
# Song ideas to help you plan music  for your wedding, corporate event or memorial service, by Event Pianist, Sharon
# Planer.
#
# [Best Songs To Party: DJ's Ultimate Party Songs Playlist](https://top40weekly.com/best-songs-to-party/)
# Planning a celebration? Don't forget the music ! We've compiled the best songs to party that are sure to get
# everyone in the mood to dance and have a good time.
#
# [GUIDE TO Planning Music for a Party -
# partiesuniverse.com](https://partiesuniverse.com/guide-to-planning-music-for-a-party/)
# There are relatively few high-quality guides about how to plan brilliant music  for a party , so we have decided to
# create our own. Our how-to guide for planning the best  music  for a party , is exactly what you need to throw an
# epic celebration where the music completely carries the vibe.
#
# [YouTube Music](https://music.youtube.com/watch?v=oOdHCjj3jn4)
# Playing from late nights in the wayne manor | a bruce wayne rock/blues playlist Mix
#
# [The Ultimate Playlist to Get the Party Started](https://alekasgettogether.com/top-songs-for-any-party/)
# Discover the ultimate party playlist for 2025 with over 50 top songs to keep your guests dancing all night long.
#
# [late nights in the wayne manor part 2 | a bruce wayne rock/blues ...](https://www.youtube.com/watch?v=DBRSHk2XpmU)
# these are songs that bruce wayne listens to while wandering the halls of the great wayne manor. this is part 2.find
# this playlist on my spotify: https://open...
#
# [late nights in the wayne manor | a bruce wayne rock/blues playlist](https://www.youtube.com/watch?v=oOdHCjj3jn4)
# these are songs that bruce wayne listens to while wandering the halls of the great wayne manor.find this playlist
# on my spotify: https://open.spotify.com/use...
#
# [Wayne Playlist - YouTube Music](https://music.youtube.com/playlist?list=PLKw7kB3mFjU7JxH0jGCxUN2VFWWbpQc3j)
# Listen to Wayne Playlist on YouTube Music - a dedicated music app with official songs, music videos, remixes,
# covers, and more.
#
# Out: None
# [Step 1: Duration 2.87 seconds| Input tokens: 2,093 | Output tokens: 65]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Extracting Spotify playlist links from the search results
#   import re
#
#   spotify_links = re.findall(r'https://open\.spotify\.com/playlist/[^\s]+', search_results)
#   print("Spotify Playlist Links:", spotify_links)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Spotify Playlist Links: ['https://open.spotify.com/playlist/5iVbp78KnovfXzpwSOgzDB)']
#
# Out: None
# [Step 2: Duration 3.27 seconds| Input tokens: 5,028 | Output tokens: 197]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Manually cleaned Spotify playlist link
#   wayne_soundtrack_playlist = 'https://open.spotify.com/playlist/5iVbp78KnovfXzpwSOgzDB'
#
#   # Another good party playlist link from Gear4music
#   gear4music_party_songs = 'https://www.gear4music.com/blog/best-party-songs/'
#
#   print("WAYNE Soundtrack Playlist:", wayne_soundtrack_playlist)
#   print("Gear4music Party Songs Article:", gear4music_party_songs)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# WAYNE Soundtrack Playlist: https://open.spotify.com/playlist/5iVbp78KnovfXzpwSOgzDB
# Gear4music Party Songs Article: https://www.gear4music.com/blog/best-party-songs/
#
# Out: None
# [Step 3: Duration 4.11 seconds| Input tokens: 8,234 | Output tokens: 383]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 4 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   recommended_playlist = wayne_soundtrack_playlist
#   final_answer(recommended_playlist)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: https://open.spotify.com/playlist/5iVbp78KnovfXzpwSOgzDB
# [Step 4: Duration 2.19 seconds| Input tokens: 11,846 | Output tokens: 458]
# 'https://open.spotify.com/playlist/5iVbp78KnovfXzpwSOgzDB'
