# %%
# !pip install smolagents
# Out:
# Collecting smolagents
#   Downloading smolagents-1.26.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: huggingface-hub>=0.31.2 in /usr/local/lib/python3.13/dist-packages (from smolagents) (1.28.0)
# Requirement already satisfied: requests>=2.32.3 in /usr/local/lib/python3.13/dist-packages (from smolagents) (2.32.4)
# Requirement already satisfied: rich>=13.9.4 in /usr/local/lib/python3.13/dist-packages (from smolagents) (13.9.4)
# Requirement already satisfied: jinja2>=3.1.4 in /usr/local/lib/python3.13/dist-packages (from smolagents) (3.1.6)
# Requirement already satisfied: pillow>=10.0.1 in /usr/local/lib/python3.13/dist-packages (from smolagents) (11.3.0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.13/dist-packages (from smolagents) (1.2.3)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=0.31.2->smolagents) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=0.31.2->smolagents) (3.32.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=0.31.2->smolagents) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=0.31.2->smolagents) (1.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=0.31.2->smolagents) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=0.31.2->smolagents) (26.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=0.31.2->smolagents) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=0.31.2->smolagents) (4.67.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=0.31.2->smolagents) (4.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2>=3.1.4->smolagents) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.32.3->smolagents) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests>=2.32.3->smolagents) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests>=2.32.3->smolagents) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests>=2.32.3->smolagents) (2026.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.9.4->smolagents) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.9.4->smolagents) (2.21.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.31.2->smolagents) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.31.2->smolagents) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.31.2->smolagents) (0.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->smolagents) (0.1.2)
# Downloading smolagents-1.26.0-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.5/161.5 kB 5.2 MB/s eta 0:00:00
# Installing collected packages: smolagents
# Successfully installed smolagents-1.26.0

# %%
from huggingface_hub import notebook_login, get_token
notebook_login()

import os
os.environ["HF_TOKEN"] = get_token()

# %%
# Initialize the search tool
search_tool = WebSearchTool()

# %%
from smolagents import CodeAgent, WebSearchTool, InferenceClientModel

# %%
# Initialize the model with explicit, working parameters
model = InferenceClientModel(
    model_id="Qwen/Qwen2.5-Coder-32B-Instruct",
    provider="auto",
    token=os.environ["HF_TOKEN"]
)

agent = CodeAgent(
    model=model,
    tools=[search_tool]
)

response = agent.run(
    "Search for luxury superhero-themed party ideas, including decorations, entertainment, and catering."
)
print(response)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Search for luxury superhero-themed party ideas, including decorations, entertainment, and catering.             │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-Coder-32B-Instruct ────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   decorations_results = web_search(query="luxury superhero-themed party decorations")
#   entertainment_results = web_search(query="luxury superhero-themed party entertainment")
#   catering_results = web_search(query="luxury superhero-themed party catering")
#
#   print("Decorations results:")
#   print(decorations_results)
#   print("\nEntertainment results:")
#   print(entertainment_results)
#   print("\nCatering results:")
#   print(catering_results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Decorations results:
# ## Search Results
#
# [Amazon.com: Superhero Party
# Decorations](https://www.amazon.com/superhero-party-decorations/s?k=superhero+party+decorations)
# Find everything you need for a superhero-themed  party . Shop tableware sets, photo booth backdrops, and colorful
# balloon decorations .
#
# [Superhero Themed Party Decor - Etsy](https://www.etsy.com/market/superhero_themed_party_decor)
# Check out our superhero  themed  party decor selection for the very best in unique or custom, handmade pieces from
# our party & gifting shops.
#
# [Superhero Theme Party Decorations - Etsy](https://www.etsy.com/market/superhero_theme_party_decorations)
# Unleash your inner hero with vibrant superhero  party  decorations . Discover dynamic balloons, heroic garlands,
# and cityscape centerpieces, perfect for birthdays and celebrations.
#
# [Super Hero Party Supplies: Transform Your Party Space Into a Heroic
# ...](https://www.bulkpartysupplies.com/collections/super-hero-party-theme)
# Honor your super  hero and transform your party space into a heroic wonderland! Our amazing super  hero  themed
# decorations and party accessories will help you create an unforgettable event. From masks and capes to banners and
# tableware, you'll find everything you need to make your special day heroic. Let your guests feel like super heroes
# as they celebrate the special occasion!
#
# [Superhero Party Supplies: Power Up Your Decor for an Epic
# Celebration](https://www.partydecorations.com/collections/super-hero-party-theme)
# Make your superhero  party epic! Capes, masks, and decorations transform any event into a hero-filled adventure.
#
# [Buy Superhero Theme Party Online | Party City](https://www.partycity.com/collections/superhero-theme-party)
# Host the ultimate superhero birthday bash with superhero-themed plates, cups, and napkins with matching decorations
# , invitations, and party favors.
#
# [Amazon.com: Superhero Theme Party
# Decorations](https://www.amazon.com/superhero-theme-party-decorations/s?k=superhero+theme+party+decorations)
# 1-48 of over 3,000 results for " superhero theme party  decorations " Results Check each product page for other
# buying options. Price and other details may vary based on product size and color.
#
# [Superhero Party Supplies & Decorations - Smart Soirée](https://smartsoiree.com/collections/superhero-party)
# Shop superhero  party supplies including tableware, decorations , and accessories for an action-packed celebration.
#
# [Superhero Party Supplies & Themed
# Decorations](https://factorydirectparty.com/collections/superhero-party-supplies)
# Create an action-packed celebration with our Superhero  Party Supplies & Themed  Decorations collection. Perfect
# for kids' birthdays, costume parties, school events, and superhero-themed celebrations, this collection features
# bold colors, comic-style designs, and heroic details that instantly energize any space. From balloons and banners
# to tableware and décor accents, these supplies make it ...
#
# [Superhero Party Supplies & Favors - Daydream
# Society](https://daydreamsociety.com/collections/superhero-collection)
# Leap into action with our Superhero  party essentials! Equip your event with heroically- themed  party plates,
# superhero cups, and hanging decorations . Be the hero of the event with unique party favors, such as themed pencil
# pouches, superhero tattoos, and rubber stamps.
#
# Entertainment results:
# ## Search Results
#
# [Superhero Party Theme - The Bash](https://www.thebash.com/themes/superhero)
# Search food, drink, decoration and entertainment ideas for putting together a superhero  party theme. Whether
# you're celebrating a birthday or anniversary, find the best party inspiration on The Bash.
#
# [Superhero Party Entertainment Secrets: How to Create Epic Celebrations
# ...](https://magicianforparty.com/2026/05/02/superhero-party-entertainment/)
# Authoritative Sources on superhero  party  entertainment  Party City - The Ultimate Guide to Themed Parties
# partycity.com This site offers a wide range of superhero  party supplies, decorations, and ideas that have inspired
# many of my own celebrations. Parents.com - How to Throw a Superhero  Party parents.com Provides practical tips and
# step-by-step guidance on planning and executing superhero ...
#
# [Creative Event Themes: Superhero Party](https://nationaleventpros.com/creative-event-themes-superhero-party/)
# Not long after we learn to speak, we learn a name: the name of our favorite superhero . Bring those childhood
# dreams to life with a superhero  party .
#
# [Superhero Theme Party - O'Brien Production](https://www.obrienproductions.com/theme-parties/superhero/)
# Choosing a comic book Superhero Theme Party is a fantastic way to celebrate a special occasion, a corporate
# milestone, or have a unique company event. Once you have a wish list for your event and a budget in mind, O'Brien
# Productions will handle all the details and make your party amazing. O'Brien Productions and our professional event
# designers will be happy to meet with you to develop ...
#
# [By a Pro: Superhero Party Ideas by a Professional](https://party-ideas-by-a-pro.com/party-themes/superhero-party/)
# The Superhero  party ideas below were mainly designed with a kid's birthday in mind. However, a lot of the ideas
# could easily be adapted for an adult costume party so I've also included some tips and supplies specifically for
# adults—such as cocktail recipes. The great thing about throwing a generic Superhero  party is that there are lots
# of elements that are common to all comic book heroes ...
#
# [Superhero Party Ideas - Pinterest](https://www.pinterest.com/ideas/superhero-party-ideas/915541619571/)
# Find and save ideas about superhero  party ideas on Pinterest.
#
# [24 Superhero Party Ideas that Will Make You Wish You Were a
# Kid](https://howdoesshe.com/24-incredible-superhero-party-ideas-that-will-make-you-wish-you-were-a-kid-again/)
# 24 incredible superhero  party ideas that kids will love and make adults wish they were kids again. From decor
# ideas, party foods, and costume ideas to superhero-themed activities, we have all of your party needs covered.
#
# [Superhero Party Packages - The Superhero Company](https://thesuperherocompany.com/superhero-parties/)
# Whether you are looking to keep the kids entertained while you manage the main event, or you are looking to provide
# a unique entertainment experience for guests are your conference/congress or corporate event, this is the perfect
# Superhero  party plan!
#
# [Superhero Theme Party Ideas for Adults to Create an Unforgettable
# ...](https://partyideaszone.com/superhero-theme-party-ideas-for-adults/)
# Unleash your inner hero with our ultimate guide to hosting an unforgettable superhero-themed  party for adults!
# Explore creative costume ideas, vibrant decorations, and mouthwatering themed snacks and drinks. Engage your guests
# with fun activities like trivia, costume contests, and movie screenings. Follow our planning tips to create a
# cohesive, memorable experience that your friends will rave ...
#
# [Theme Parties - Above the Top Events](https://www.abovethetopevents.com/super-hero)
# Our event professionals understand that no two theme parties are alike. We tailor every detail—entrances, photo
# moments, lounge areas, tablescapes, and entertainment—to match your style, your guests, and your goals. Whether
# it's an adults-only soirée or a family-friendly celebration, we'll help you create an atmosphere that feels unique,
# immersive, and unforgettable.
#
# Catering results:
# ## Search Results
#
# [Superhero Party Theme - The Bash](https://www.thebash.com/themes/superhero)
# Search food, drink, decoration and entertainment ideas for putting together a superhero  party theme. Whether
# you're celebrating a birthday or anniversary, find the best party inspiration on The Bash.
#
# [HEAVENLY EVENTS - Award Winning Catering in Las Vegas](https://www.heavenlycateredevents.com)
# Heavenly Catered Events provides luxury  catering services for corporate events, private dinners, cocktail parties,
# holiday celebrations, weddings, wine tasting, wine pairing dinners, galas, fundraisers, social gatherings, and
# other special events throughout Las Vegas and the surrounding areas. Do you offer wedding catering in Las Vegas?
# Yes.
#
# [Catering | HOV HQ](https://www.heroorvillaindeli.com/catering)
# Ferndale's superhero-themed sandwich shop offers drop-off catering for Auto Show Catering , your next meeting,
# conference, birthday party , or graduation party . Super sandwiches, salads, soups, and more delivered to you by
# our super team at Hero or Villain Deli.
#
# [Superhero Theme Party - O'Brien Production](https://www.obrienproductions.com/theme-parties/superhero/)
# Choosing a comic book Superhero Theme Party is a fantastic way to celebrate a special occasion, a corporate
# milestone, or have a unique company event. Once you have a wish list for your event and a budget in mind, O'Brien
# Productions will handle all the details and make your party amazing. O'Brien Productions and our professional event
# designers will be happy to meet with you to develop ...
#
# [By a Pro: Superhero Party Ideas by a Professional](https://party-ideas-by-a-pro.com/party-themes/superhero-party/)
#  Superhero  party ideas by an award winning professional party planner including ideas for invitations, party food
# & drinks, decorations, and party supplies
#
# [Superhero - Party Characters For Hire](https://partycharactersforhire.com/themes/superhero.html)
# Our Superhero  themed  party packages bring the excitement of your favorite Superheroes to life! Our top-notch
# birthday experience features Superhero decorations, themed games and activities, and a mouth-watering array of food
# and cake.
#
# [30+ Superhero Party Ideas - Canva](https://www.canva.com/ideas/superhero-party-ideas/)
# Browse a wide range of superhero  party ideas and inspiration, from photos and templates in a stunning selection of
# styles and colours.
#
# [900+ Superhero Party Ideas | spiderman themed birthday ... -
# Pinterest](https://www.pinterest.com/catchmyparty/superhero-party-ideas/)
# Dec 7, 2025 - Superhero  party ideas for birthdays -- Superhero cakes, decorations, party foods and favors. See
# more party ideas at CatchMyParty.com. See more ideas about spiderman themed birthday party , kids superhero
# birthday party inspiration, love themed  superhero .
#
# [Cut and Taste — Catering Las Vegas](https://www.cutandtastelv.com)
# Cut and Taste provides high-end catering Las Vegas events are known for, perfect for any occasion - large or small.
# From corporate catering to small party  catering services, our team can create the most unique and memorable event
# at the venue of your choice.
#
# [Super Hero Parties — Fancyful Parties](https://www.fancyful.com/hero-parties)
#  Super  Hero Parties Party Activities and Pricing Princesses Heroes Mermaids Fairies Miscellaneous Characters Body
# Art Spa Parties
#
# Out: None
# [Step 1: Duration 5.39 seconds| Input tokens: 2,094 | Output tokens: 133]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Extracting luxury decoration ideas
#   dec_patterns = [
#       r"dynamic balloons, heroic garlands, and cityscape centerpieces",
#       r"vibrant superhero party decorations",
#       r"heroically-themed party plates, superhero cups, and hanging decorations"
#   ]
#
#   decoration_ideas = []
#   for pattern in dec_patterns:
#       matches = re.findall(pattern, decorations_results)
#       decoration_ideas.extend(matches)
#
#   decoration_ideas_str = "; ".join(list(set(decoration_ideas)))
#
#   # Extracting luxury entertainment ideas
#   ent_patterns = [
#       r"SuperHero party plans",
#       r"unforgettable superhero-themed party for adults",
#       r"top-notch birthday experience features Superhero decorations, themed games and activities"
#   ]
#
#   entertainment_ideas = []
#   for pattern in ent_patterns:
#       matches = re.findall(pattern, entertainment_results)
#       entertainment_ideas.extend(matches)
#
#   entertainment_ideas_str = "; ".join(list(set(entertainment_ideas)))
#
#   # Extracting luxury catering ideas
#   cat_patterns = [
#       r"high-end catering",
#       r"mouth-watering array of food and cake"
#   ]
#
#   catering_ideas = []
#   for pattern in cat_patterns:
#       matches = re.findall(pattern, catering_results)
#       catering_ideas.extend(matches)
#
#   catering_ideas_str = "; ".join(list(set(catering_ideas)))
#
#   print(f"Decoration ideas: {decoration_ideas_str}")
#   print(f"Entertainment ideas: {entertainment_ideas_str}")
#   print(f"Catering ideas: {catering_ideas_str}")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Code execution failed at line 'for pattern in dec_patterns:
#     matches = re.findall(pattern, decorations_results)
#     decoration_ideas.extend(matches)' due to: InterpreterError: The variable `re` is not defined.
# [Step 2: Duration 7.79 seconds| Input tokens: 6,775 | Output tokens: 508]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import re
#
#   # Extracting luxury decoration ideas
#   dec_patterns = [
#       r"dynamic balloons, heroic garlands, and cityscape centerpieces",
#       r"vibrant superhero party decorations",
#       r"heroically-themed party plates, superhero cups, and hanging decorations"
#   ]
#
#   decoration_ideas = []
#   for pattern in dec_patterns:
#       matches = re.findall(pattern, decorations_results)
#       decoration_ideas.extend(matches)
#
#   decoration_ideas_str = "; ".join(list(set(decoration_ideas)))
#
#   # Extracting luxury entertainment ideas
#   ent_patterns = [
#       r"SuperHero party plans",
#       r"unforgettable superhero-themed party for adults",
#       r"top-notch birthday experience features Superhero decorations, themed games and activities"
#   ]
#
#   entertainment_ideas = []
#   for pattern in ent_patterns:
#       matches = re.findall(pattern, entertainment_results)
#       entertainment_ideas.extend(matches)
#
#   entertainment_ideas_str = "; ".join(list(set(entertainment_ideas)))
#
#   # Extracting luxury catering ideas
#   cat_patterns = [
#       r"high-end catering",
#       r"mouth-watering array of food and cake"
#   ]
#
#   catering_ideas = []
#   for pattern in cat_patterns:
#       matches = re.findall(pattern, catering_results)
#       catering_ideas.extend(matches)
#
#   catering_ideas_str = "; ".join(list(set(catering_ideas)))
#
#   print(f"Decoration ideas: {decoration_ideas_str}")
#   print(f"Entertainment ideas: {entertainment_ideas_str}")
#   print(f"Catering ideas: {catering_ideas_str}")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Decoration ideas: dynamic balloons, heroic garlands, and cityscape centerpieces
# Entertainment ideas:
# Catering ideas: mouth-watering array of food and cake; high-end catering
#
# Out: None
# [Step 3: Duration 7.38 seconds| Input tokens: 12,325 | Output tokens: 866]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 4 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   entertainment_broad_results = web_search(query="luxury superhero-themed party entertainment ideas")
#   print(entertainment_broad_results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [Superhero Party Ideas for Adults: Creative Themes and Fun Activities to
# ...](https://partyideaszone.com/superhero-party-ideas-for-adults/)
# Engaging Themes: Superhero parties for adults can feature themes like classic comic book heroes or movie-inspired
# characters, allowing for creative costume choices and decorations. Interactive Activities: Incorporate fun
# activities such as costume contests and superhero trivia games to engage guests and promote interaction during the
# party .
#
# [Superhero Theme Party Ideas for Adults to Create an Unforgettable
# ...](https://partyideaszone.com/superhero-theme-party-ideas-for-adults/)
# Unleash your inner hero with our ultimate guide to hosting an unforgettable superhero-themed  party for adults!
# Explore creative costume ideas , vibrant decorations, and mouthwatering themed snacks and drinks. Engage your
# guests with fun activities like trivia, costume contests, and movie screenings. Follow our planning tips to create
# a cohesive, memorable experience that your friends will rave ...
#
# [24 Superhero Party Ideas that Will Make You Wish You Were a
# Kid](https://howdoesshe.com/24-incredible-superhero-party-ideas-that-will-make-you-wish-you-were-a-kid-again/)
# 24 incredible superhero  party  ideas that kids will love and make adults wish they were kids again. From decor
# ideas , party foods, and costume ideas to superhero-themed activities, we have all of your party needs covered.
#
# [Creative Event Themes: Superhero Party](https://nationaleventpros.com/creative-event-themes-superhero-party/)
#  Ideas Explore event planning ideas . Discover complete idea guides for creative event themes, venues, catering,
# entertainment , and more! Browse Ideas
#
# [Elegant Superhero Party - Pinterest](https://www.pinterest.com/ideas/elegant-superhero-party/919813378132/)
# Find and save ideas about elegant superhero  party on Pinterest.
#
# [Ideas for Superhero-themed Events -
# Pinterest](https://www.pinterest.com/ideas/ideas-for-superhero-themed-events/933271986369/)
# Find and save ideas about ideas for superhero-themed events on Pinterest.
#
# [By a Pro: Superhero Party Ideas by a Professional](https://party-ideas-by-a-pro.com/party-themes/superhero-party/)
# The Superhero  party  ideas below were mainly designed with a kid's birthday in mind. However, a lot of the ideas
# could easily be adapted for an adult costume party so I've also included some tips and supplies specifically for
# adults—such as cocktail recipes. The great thing about throwing a generic Superhero  party is that there are lots
# of elements that are common to all comic book heroes ...
#
# [Superhero Party Theme - The Bash](https://www.thebash.com/themes/superhero)
# Search food, drink, decoration and entertainment  ideas for putting together a superhero  party theme. Whether
# you're celebrating a birthday or anniversary, find the best party inspiration on The Bash.
#
# [33 Superhero Party Games for Adults - Fun Party Pop](https://funpartypop.com/superhero-party-games-adults/)
# Because of this, I decided my next birthday would be superhero  themed . So today, I have gathered some of the best
# superhero  party games for adults that I could find.
#
# [30 Creative Superhero Party Ideas for a Heroic Birthday](https://www.magicalcalls.com/blog/superhero-party-ideas)
# Plan the ultimate hero- themed bash with these 30 creative superhero  party  ideas , including games, decorations,
# and a magical way to surprise your child.
#
# Out: None
# [Step 4: Duration 3.16 seconds| Input tokens: 18,704 | Output tokens: 948]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 5 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Extracting luxury entertainment ideas
#   ent_broad_patterns = [
#       r"costume contests and superhero trivia games",
#       r"ultimate guide to hosting an unforgettable superhero-themed party for adults",
#       r"fun activities like trivia, costume contests, and movie screenings",
#       r"top-notch birthday experience features Superhero decorations, themed games and activities",
#       r"Elegant Superhero Party - Pinterest",
#       r"Ideas for Superhero-themed Events - Pinterest",
#       r"ideas for costume party",
#       r"33 Superhero Party Games for Adults - Fun Party Pop",
#       r"30 Creative Superhero Party Ideas for a Heroic Birthday - Magical Calls"
#   ]
#
#   entertainment_broad_ideas = []
#   for pattern in ent_broad_patterns:
#       matches = re.findall(pattern, entertainment_broad_results)
#       entertainment_broad_ideas.extend(matches)
#
#   # Combining unique entertainment ideas
#   entertainment_broad_ideas = list(set(entertainment_broad_ideas))
#   entertainment_broad_ideas_str = "; ".join(entertainment_broad_ideas)
#
#   print(f"Broadened Entertainment ideas: {entertainment_broad_ideas_str}")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Broadened Entertainment ideas: Elegant Superhero Party - Pinterest; fun activities like trivia, costume contests,
# and movie screenings; costume contests and superhero trivia games; Ideas for Superhero-themed Events - Pinterest;
# 33 Superhero Party Games for Adults - Fun Party Pop
#
# Out: None
# [Step 5: Duration 5.89 seconds| Input tokens: 25,996 | Output tokens: 1,227]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 6 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   summary = (
#       f"Luxury Superhero-Themed Party Ideas:\n"
#       f"Decorations: {decoration_ideas_str}\n"
#       f"Entertainment: {entertainment_broad_ideas_str}\n"
#       f"Catering: {catering_ideas_str}"
#   )
#
#   final_answer(summary)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: Luxury Superhero-Themed Party Ideas:
# Decorations: dynamic balloons, heroic garlands, and cityscape centerpieces
# Entertainment: Elegant Superhero Party - Pinterest; fun activities like trivia, costume contests, and movie
# screenings; costume contests and superhero trivia games; Ideas for Superhero-themed Events - Pinterest; 33
# Superhero Party Games for Adults - Fun Party Pop
# Catering: mouth-watering array of food and cake; high-end catering
# [Step 6: Duration 3.60 seconds| Input tokens: 33,941 | Output tokens: 1,336]
# Luxury Superhero-Themed Party Ideas:
# Decorations: dynamic balloons, heroic garlands, and cityscape centerpieces
# Entertainment: Elegant Superhero Party - Pinterest; fun activities like trivia, costume contests, and movie screenings; costume contests and superhero trivia games; Ideas for Superhero-themed Events - Pinterest; 33 Superhero Party Games for Adults - Fun Party Pop
# Catering: mouth-watering array of food and cake; high-end catering

# %%
# Initialize the search tool
search_tool = WebSearchTool()

# Initialize the model
model = InferenceClientModel()

agent = CodeAgent(
    model = model,
    tools=[search_tool]
)

# Example usage
response = agent.run(
    "Search for luxury superhero-themed party ideas, including decorations, entertainment, and catering."
)
print(response)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Search for luxury superhero-themed party ideas, including decorations, entertainment, and catering.             │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen3-Next-80B-A3B-Thinking ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Error in generating model output:
# (Request ID: Root=1-6a932d0c-2cc7632a5b1350753242d9ec;8c6fd76f-3b52-4341-a716-55b9206aadf7)
#
# Bad request:
# {'message': "The requested model 'Qwen/Qwen3-Next-80B-A3B-Thinking' is not supported by any provider you have
# enabled.", 'type': 'invalid_request_error', 'param': 'model', 'code': 'model_not_supported'}
# [Step 1: Duration 0.15 seconds]
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# /usr/local/lib/python3.13/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     797     try:
# --> 798         response.raise_for_status()
#     799     except httpx.HTTPStatusError as e:
#
# /usr/local/lib/python3.13/dist-packages/httpx/_models.py in raise_for_status(self)
#     828         message = message.format(self, error_type=error_type)
# --> 829         raise HTTPStatusError(message, request=request, response=self)
#     830
#
# HTTPStatusError: Client error '400 Bad Request' for url 'https://router.huggingface.co/v1/chat/completions'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/400
#
# The above exception was the direct cause of the following exception:
#
# BadRequestError                           Traceback (most recent call last)
# /usr/local/lib/python3.13/dist-packages/smolagents/agents.py in _step_stream(self, memory_step)
#    1676             else:
# -> 1677                 chat_message: ChatMessage = self.model.generate(
#    1678                     input_messages,
#
# /usr/local/lib/python3.13/dist-packages/smolagents/models.py in generate(self, messages, stop_sequences, response_format, tools_to_call_from, **kwargs)
#    1575         self._apply_rate_limit()
# -> 1576         response = self.retryer(self.client.chat_completion, **completion_kwargs)
#    1577         content = response.choices[0].message.content
#
# /usr/local/lib/python3.13/dist-packages/smolagents/utils.py in __call__(self, fn, *args, **kwargs)
#     556             try:
# --> 557                 result = fn(*args, **kwargs)
#     558
#
# /usr/local/lib/python3.13/dist-packages/huggingface_hub/inference/_client.py in chat_completion(self, messages, model, stream, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream_options, temperature, tool_choice, tool_prompt, tools, top_logprobs, top_p, extra_body)
#     929         )
# --> 930         data = self._inner_post(request_parameters, stream=stream)
#     931
#
# /usr/local/lib/python3.13/dist-packages/huggingface_hub/inference/_client.py in _inner_post(self, request_parameters, stream)
#     282             )
# --> 283             hf_raise_for_status(response)
#     284             if stream:
#
# /usr/local/lib/python3.13/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     890             )
# --> 891             raise _format(BadRequestError, message, response) from e
#     892
#
# BadRequestError: (Request ID: Root=1-6a932d0c-2cc7632a5b1350753242d9ec;8c6fd76f-3b52-4341-a716-55b9206aadf7)
#
# Bad request:
# {'message': "The requested model 'Qwen/Qwen3-Next-80B-A3B-Thinking' is not supported by any provider you have enabled.", 'type': 'invalid_request_error', 'param': 'model', 'code': 'model_not_supported'}
#
# The above exception was the direct cause of the following exception:
#
# AgentGenerationError                      Traceback (most recent call last)
# /tmp/ipykernel_975/2389875266.py in <cell line: 0>()
#      11
#      12 # Example usage
# ---> 13 response = agent.run(
#      14     "Search for luxury superhero-themed party ideas, including decorations, entertainment, and catering."
#      15 )
#
# /usr/local/lib/python3.13/dist-packages/smolagents/agents.py in run(self, task, stream, reset, images, additional_args, max_steps, return_full_result)
#     497
#     498         run_start_time = time.time()
# --> 499         steps = list(self._run_stream(task=self.task, max_steps=max_steps, images=images))
#     500
#     501         # Outputs are returned only at the end. We only look at the last step.
#
# /usr/local/lib/python3.13/dist-packages/smolagents/agents.py in _run_stream(self, task, max_steps, images)
#     594             except AgentGenerationError as e:
#     595                 # Agent generation errors are not caused by a Model error but an implementation error: so we should raise them and exit.
# --> 596                 raise e
#     597             except AgentError as e:
#     598                 # Other AgentError types are caused by the Model, so we should log them and iterate.
#
# /usr/local/lib/python3.13/dist-packages/smolagents/agents.py in _run_stream(self, task, max_steps, images)
#     576             self.logger.log_rule(f"Step {self.step_number}", level=LogLevel.INFO)
#     577             try:
# --> 578                 for output in self._step_stream(action_step):
#     579                     # Yield all
#     580                     yield output
#
# /usr/local/lib/python3.13/dist-packages/smolagents/agents.py in _step_stream(self, memory_step)
#    1698             memory_step.model_output = output_text
#    1699         except Exception as e:
# -> 1700             raise AgentGenerationError(f"Error in generating model output:\n{e}", self.logger) from e
#    1701
#    1702         ### Parse output ###
#
# AgentGenerationError: Error in generating model output:
# (Request ID: Root=1-6a932d0c-2cc7632a5b1350753242d9ec;8c6fd76f-3b52-4341-a716-55b9206aadf7)
#
# Bad request:
# {'message': "The requested model 'Qwen/Qwen3-Next-80B-A3B-Thinking' is not supported by any provider you have enabled.", 'type': 'invalid_request_error', 'param': 'model', 'code': 'model_not_supported'}

# %%
# !pip install langchain-community rank_bm25
# Out:
# Collecting langchain-community
#   Downloading langchain_community-0.4.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting rank_bm25
#   Downloading rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (3.14.3)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting langchain-classic<2.0.0,>=1.0.7 (from langchain-community)
#   Downloading langchain_classic-1.0.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (1.6.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (0.11.1)
# Requirement already satisfied: numpy>=2.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (2.1.3)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Downloading pydantic_settings-2.15.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (6.0.3)
# Collecting requests<3.0.0,>=2.32.5 (from langchain-community)
#   Downloading requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (2.0.52)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.5)
# Collecting langchain-text-splitters<2.0.0,>=1.1.2 (from langchain-classic<2.0.0,>=1.0.7->langchain-community)
#   Downloading langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.13/dist-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.13.4)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.0.18)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (26.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.17.0)
# Requirement already satisfied: anyio>=3.5.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.9.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.13/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.3)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.13/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.7.22)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.13/dist-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (3.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.46.4)
# Downloading langchain_community-0.4.2-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 42.1 MB/s eta 0:00:00
# Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.8-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 57.8 MB/s eta 0:00:00
# Downloading pydantic_settings-2.15.0-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 6.5 MB/s eta 0:00:00
# Downloading requests-2.34.2-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 7.0 MB/s eta 0:00:00
# Downloading langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Installing collected packages: requests, rank_bm25, httpx-sse, pydantic-settings, langchain-text-splitters, langchain-classic, langchain-community
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# Successfully installed httpx-sse-0.4.3 langchain-classic-1.0.8 langchain-community-0.4.2 langchain-text-splitters-1.1.2 pydantic-settings-2.15.0 rank_bm25-0.2.2 requests-2.34.2

# %%
from langchain_core.documents import Document

# %%
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
from smolagents import Tool
from langchain_community.retrievers import BM25Retriever
from smolagents import CodeAgent, InferenceClientModel

# %%
# from google.colab import userdata
# userdata.get('HF_TOKEN')

# %%
import os
model = InferenceClientModel(
    model_id="Qwen/Qwen2.5-Coder-32B-Instruct",
    provider="auto",
    token=userdata.get('HF_TOKEN')
)

# %%
# Initialize the agent
agent = CodeAgent(tools=[party_planning_retriever], model=model)

# Example usage
response = agent.run(
    "Find ideas for a luxury superhero-themed party, including entertainment, catering, and decoration options."
)
print(response)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Find ideas for a luxury superhero-themed party, including entertainment, catering, and decoration options.      │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-Coder-32B-Instruct ────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   party_ideas = party_planning_retriever(query="luxury superhero-themed party ideas")
#   print(party_ideas)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
#
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.
#
# ===== Idea 2 =====
# Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.
#
# ===== Idea 3 =====
# For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.
#
# Out: None
# [Step 1: Duration 2.31 seconds| Input tokens: 2,103 | Output tokens: 67]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Categorizing the ideas
#   decorations = [
#       "A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.",
#       "Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the
#   venue."
#   ]
#
#   entertainment = [
#       "Interactive experiences with VR where guests can engage in superhero simulations or compete in themed
#   games.",
#       "Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman."
#   ]
#
#   catering = [
#       "For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power
#   Steak.'"
#   ]
#
#   # Summarizing the ideas
#   decoration_summary = "Luxury decor including masquerade elements (gold accents, velvet curtains) and
#   projections of iconic superhero cities with logos."
#   entertainment_summary = "Interactive VR experiences and themed music by a professional DJ featuring
#   superheroes."
#   catering_summary = "Superhero-themed cuisine such as 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'"
#
#   final_answer({
#       "decorations": decoration_summary,
#       "entertainment": entertainment_summary,
#       "catering": catering_summary
#   })
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: {'decorations': 'Luxury decor including masquerade elements (gold accents, velvet curtains) and
# projections of iconic superhero cities with logos.', 'entertainment': 'Interactive VR experiences and themed music
# by a professional DJ featuring superheroes.', 'catering': "Superhero-themed cuisine such as 'The Hulk's Green
# Smoothie' and 'Iron Man's Power Steak.'"}
# [Step 2: Duration 5.71 seconds| Input tokens: 4,489 | Output tokens: 358]
# {'decorations': 'Luxury decor including masquerade elements (gold accents, velvet curtains) and projections of iconic superhero cities with logos.', 'entertainment': 'Interactive VR experiences and themed music by a professional DJ featuring superheroes.', 'catering': "Superhero-themed cuisine such as 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'"}

# %%
from google.colab import userdata
import os
os.environ["HF_TOKEN"] = userdata.get('HF_TOKEN')

from smolagents import InferenceClientModel

model = InferenceClientModel(
    model_id="Qwen/Qwen2.5-Coder-32B-Instruct",
    provider="auto",
    token=os.environ["HF_TOKEN"]
)

# %%
class PartyPlanningRetrieverTool(Tool):
    name = "party_planning_retriever"
    description = "Uses semantic search to retrieve relevant party planning ideas for Alfred’s superhero-themed party at Wayne Manor."
    inputs = {
        "query": {
            "type": "string",
            "description": "The query to perform. This should be a query related to party planning or superhero themes.",
        }
    }
    output_type = "string"

    def __init__(self, docs, **kwargs):
        super().__init__(**kwargs)
        self.retriever = BM25Retriever.from_documents(
            docs, k=5  # Retrieve the top 5 documents
        )

    def forward(self, query: str) -> str:
        assert isinstance(query, str), "Your search query must be a string"

        docs = self.retriever.invoke(
            query,
        )
        return "\nRetrieved ideas:\n" + "".join(
            [
                f"\n\n===== Idea {str(i)} =====\n" + doc.page_content
                for i, doc in enumerate(docs)
            ]
        )

# %%
agent = CodeAgent(tools=[party_planning_retriever], model=InferenceClientModel())

# %%
import os
from smolagents import Tool, CodeAgent, InferenceClientModel
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.retrievers import BM25Retriever

class PartyPlanningRetrieverTool(Tool):
    name = "party_planning_retriever"
    description = "Uses semantic search to retrieve relevant party planning ideas for Alfred's superhero-themed party at Wayne Manor."
    inputs = {
        "query": {
            "type": "string",
            "description": "The query to perform. This should be a query related to party planning or superhero themes.",
        }
    }
    output_type = "string"

    def __init__(self, docs, **kwargs):
        super().__init__(**kwargs)
        self.retriever = BM25Retriever.from_documents(
            docs, k=5
        )

    def forward(self, query: str) -> str:
        assert isinstance(query, str), "Your search query must be a string"
        docs = self.retriever.invoke(query)
        return "\nRetrieved ideas:\n" + "".join(
            [
                f"\n\n===== Idea {str(i)} =====\n" + doc.page_content
                for i, doc in enumerate(docs)
            ]
        )

# Simulate a knowledge base about party planning
party_ideas = [
    {"text": "A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.", "source": "Party Ideas 1"},
    {"text": "Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.", "source": "Entertainment Ideas"},
    {"text": "For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'", "source": "Catering Ideas"},
    {"text": "Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.", "source": "Decoration Ideas"},
    {"text": "Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.", "source": "Entertainment Ideas"}
]

source_docs = [
    Document(page_content=doc["text"], metadata={"source": doc["source"]})
    for doc in party_ideas
]

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50,
    add_start_index=True,
    strip_whitespace=True,
    separators=["\n\n", "\n", ".", " ", ""],
)
docs_processed = text_splitter.split_documents(source_docs)

party_planning_retriever = PartyPlanningRetrieverTool(docs_processed)

# THIS is the line that needed to change:
model = InferenceClientModel(
    model_id="Qwen/Qwen2.5-Coder-32B-Instruct",
    provider="auto",
    token=os.environ["HF_TOKEN"]
)

agent = CodeAgent(tools=[party_planning_retriever], model=model)

response = agent.run(
    "Find ideas for a luxury superhero-themed party, including entertainment, catering, and decoration options."
)
print(response)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Find ideas for a luxury superhero-themed party, including entertainment, catering, and decoration options.      │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-Coder-32B-Instruct ────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   entertainment_ideas = party_planning_retriever(query="luxury superhero-themed party entertainment ideas")
#   catering_ideas = party_planning_retriever(query="luxury superhero-themed party catering ideas")
#   decoration_ideas = party_planning_retriever(query="luxury superhero-themed party decoration ideas")
#
#   print("Entertainment Ideas:", entertainment_ideas)
#   print("\nCatering Ideas:", catering_ideas)
#   print("\nDecoration Ideas:", decoration_ideas)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Entertainment Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.
#
# ===== Idea 2 =====
# Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.
#
# ===== Idea 3 =====
# For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.
#
# Catering Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.
#
# ===== Idea 2 =====
# Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.
#
# ===== Idea 3 =====
# For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.
#
# Decoration Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.
#
# ===== Idea 2 =====
# Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.
#
# ===== Idea 3 =====
# For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.
#
# Out: None
# [Step 1: Duration 3.58 seconds| Input tokens: 2,103 | Output tokens: 156]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   entertainment_ideas_refined = party_planning_retriever(query="luxury superhero-themed party entertainment
#   options")
#   catering_ideas_refined = party_planning_retriever(query="luxury superhero-themed party catering options")
#   decoration_ideas_refined = party_planning_retriever(query="luxury superhero-themed party decoration options")
#
#   print("Refined Entertainment Ideas:", entertainment_ideas_refined)
#   print("\nRefined Catering Ideas:", catering_ideas_refined)
#   print("\nRefined Decoration Ideas:", decoration_ideas_refined)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Refined Entertainment Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.
#
# ===== Idea 2 =====
# Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.
#
# ===== Idea 3 =====
# For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.
#
# Refined Catering Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.
#
# ===== Idea 2 =====
# Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.
#
# ===== Idea 3 =====
# For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.
#
# Refined Decoration Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.
#
# ===== Idea 2 =====
# Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.
#
# ===== Idea 3 =====
# For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.
#
# Out: None
# [Step 2: Duration 3.54 seconds| Input tokens: 4,932 | Output tokens: 316]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   entertainment_ideas_specific = party_planning_retriever(query="luxury superhero-themed party entertainment
#   options such as live performances")
#   catering_ideas_specific = party_planning_retriever(query="luxury superhero-themed party catering options such
#   as gourmet food")
#   decoration_ideas_specific = party_planning_retriever(query="luxury superhero-themed party decoration options
#   such as high-quality materials and lighting effects")
#
#   print("Specific Entertainment Ideas:", entertainment_ideas_specific)
#   print("\nSpecific Catering Ideas:", catering_ideas_specific)
#   print("\nSpecific Decoration Ideas:", decoration_ideas_specific)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Specific Entertainment Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.
#
# ===== Idea 2 =====
# Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.
#
# ===== Idea 3 =====
# For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.
#
# Specific Catering Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.
#
# ===== Idea 2 =====
# Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.
#
# ===== Idea 3 =====
# For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.
#
# Specific Decoration Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.
#
# ===== Idea 1 =====
# Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.
#
# ===== Idea 2 =====
# Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.
#
# ===== Idea 3 =====
# For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'
#
# ===== Idea 4 =====
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.
#
# Out: None
# [Step 3: Duration 3.83 seconds| Input tokens: 8,511 | Output tokens: 481]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 4 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   entertainment_ideas_precise = party_planning_retriever(query="luxury superhero-themed party live entertainment
#   options")
#   catering_ideas_precise = party_planning_retriever(query="luxury superhero-themed party gourmet catering
#   options")
#   decoration_ideas_precise = party_planning_retriever(query="luxury superhero-themed party high-quality
#   decoration options")
#
#   print("Precise Entertainment Ideas:", entertainment_ideas_precise)
#   print("\nPrecise Catering Ideas:", catering_ideas_precise)
#   print("\nPrecise Decoration Ideas:", decoration_ideas_precise)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Precise Entertainment Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.
#
# ===== Idea 2 =====
# Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.
#
# ===== Idea 3 =====
# For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.
#
# Precise Catering Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.
#
# ===== Idea 2 =====
# Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.
#
# ===== Idea 3 =====
# For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.
#
# Precise Decoration Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.
#
# ===== Idea 2 =====
# Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.
#
# ===== Idea 3 =====
# For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.
#
# Out: None
# [Step 4: Duration 3.61 seconds| Input tokens: 12,849 | Output tokens: 639]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 5 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   entertainment_ideas_precise = party_planning_retriever(query="luxury superhero-themed party live performances,
#   acrobatics, and film screenings")
#   catering_ideas_precise = party_planning_retriever(query="luxury superhero-themed party gourmet
#   superhero-inspired dishes with superhero motifs")
#   decoration_ideas_precise = party_planning_retriever(query="luxury superhero-themed party high-quality scene
#   recreations from superhero movies or comic books")
#
#   print("Final Entertainment Ideas:", entertainment_ideas_precise)
#   print("\nFinal Catering Ideas:", catering_ideas_precise)
#   print("\nFinal Decoration Ideas:", decoration_ideas_precise)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Final Entertainment Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.
#
# ===== Idea 1 =====
# Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.
#
# ===== Idea 2 =====
# Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.
#
# ===== Idea 3 =====
# For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'
#
# ===== Idea 4 =====
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.
#
# Final Catering Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.
#
# ===== Idea 1 =====
# For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'
#
# ===== Idea 2 =====
# Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.
#
# ===== Idea 3 =====
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.
#
# Final Decoration Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.
#
# ===== Idea 2 =====
# Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.
#
# ===== Idea 3 =====
# For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.
#
# Out: None
# [Step 5: Duration 6.01 seconds| Input tokens: 17,939 | Output tokens: 899]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 6 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   entertainment_ideas_final = [
#       "Live superhero costumes and performances",
#       "Superhero trivia quiz with prizes",
#       "Red carpet event with paparazzi and a photo booth"
#   ]
#
#   catering_ideas_final = [
#       "Gourmet versions of classic superhero snacks (e.g., Superman's Kryptonite cake, Spider-Man's green pea
#   hummus)",
#       "Champagne toast with a superhero theme"
#   ]
#
#   decoration_ideas_final = [
#       "Detailed recreations of iconic scenes from popular superhero movies",
#       "Themed lighting effects (e.g., neon signs, laser lights)",
#       "Exclusive VIP lounges decorated in the style of different hero headquarters"
#   ]
#
#   final_answer({
#       "entertainment": entertainment_ideas_final,
#       "catering": catering_ideas_final,
#       "decoration": decoration_ideas_final
#   })
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: {'entertainment': ['Live superhero costumes and performances', 'Superhero trivia quiz with prizes',
# 'Red carpet event with paparazzi and a photo booth'], 'catering': ["Gourmet versions of classic superhero snacks
# (e.g., Superman's Kryptonite cake, Spider-Man's green pea hummus)", 'Champagne toast with a superhero theme'],
# 'decoration': ['Detailed recreations of iconic scenes from popular superhero movies', 'Themed lighting effects
# (e.g., neon signs, laser lights)', 'Exclusive VIP lounges decorated in the style of different hero headquarters']}
# [Step 6: Duration 7.95 seconds| Input tokens: 23,895 | Output tokens: 1,254]
# {'entertainment': ['Live superhero costumes and performances', 'Superhero trivia quiz with prizes', 'Red carpet event with paparazzi and a photo booth'], 'catering': ["Gourmet versions of classic superhero snacks (e.g., Superman's Kryptonite cake, Spider-Man's green pea hummus)", 'Champagne toast with a superhero theme'], 'decoration': ['Detailed recreations of iconic scenes from popular superhero movies', 'Themed lighting effects (e.g., neon signs, laser lights)', 'Exclusive VIP lounges decorated in the style of different hero headquarters']}
