# %% [markdown]
# <a href="https://colab.research.google.com/github/5atish/TrainingCourse/blob/main/Hugging%20Face%20Agents%20Course%20/Unit%201.%20Introduction%20to%20Agents/Understanding_AI_Agents_through_the_Thought_Action_Observation_Cycle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
   {
     "action": "get_weather",
     "action_input": {
       "location": "New York"
     }
   }
# Out:
# {'action': 'get_weather', 'action_input': {'location': 'New York'}}
