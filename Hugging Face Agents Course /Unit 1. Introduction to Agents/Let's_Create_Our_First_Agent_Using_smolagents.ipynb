# %% [markdown]
# <a href="https://colab.research.google.com/github/5atish/TrainingCourse/blob/main/Hugging%20Face%20Agents%20Course%20/Unit%201.%20Introduction%20to%20Agents/Let's_Create_Our_First_Agent_Using_smolagents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install smolagents
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.5/161.5 kB 1.4 MB/s eta 0:00:00
# ...

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, FinalAnswerTool, InferenceClientModel, load_tool, tool
import datetime
import requests
import pytz
import yaml

# %%
@tool
def my_custom_tool(arg1:str, arg2:int)-> str: # it's important to specify the return type
    # Keep this format for the tool description / args description but feel free to modify the tool
    """A tool that does nothing yet
    Args:
        arg1: the first argument
        arg2: the second argument
    """
    return "What magic will you build ?"

@tool
def get_current_time_in_timezone(timezone: str) -> str:
    """A tool that fetches the current local time in a specified timezone.
    Args:
        timezone: A string representing a valid timezone (e.g., 'America/New_York').
    """
    try:
        # Create timezone object
        tz = pytz.timezone(timezone)
        # Get current time in that timezone
        local_time = datetime.datetime.now(tz).strftime("%Y-%m-%d %H:%M:%S")
        return f"The current local time in {timezone} is: {local_time}"
    except Exception as e:
        return f"Error fetching time for timezone '{timezone}': {str(e)}"

# %%
from Gradio_UI import GradioUI

# %%
# !pip install -U gradio huggingface_hub smolagents
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 31.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 795.8/795.8 kB 45.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.25.2
#     Uninstalling huggingface-hub-0.25.2:
#       Successfully uninstalled huggingface-hub-0.25.2
#   Attempting uninstall: gradio-client
#     Found existing installation: gradio_client 1.3.0
#     Uninstalling gradio_client-1.3.0:
#       Successfully uninstalled gradio_client-1.3.0
#   Attempting uninstall: gradio
#     Found existing installation: gradio 4.44.0
#     Uninstalling gradio-4.44.0:
#       Successfully uninstalled gradio-4.44.0
# ...

# %%
# !pip install --upgrade gradio

# %%
# !pip show gradio
# Out:
# Name: gradio
# Version: 4.44.0
# Summary: Python library for easily interacting with trained machine learning models
# Home-page: https://github.com/gradio-app/gradio
# Author:
# Author-email: Abubakar Abid <gradio-team@huggingface.co>, Ali Abid <gradio-team@huggingface.co>, Ali Abdalla <gradio-team@huggingface.co>, Dawood Khan <gradio-team@huggingface.co>, Ahsen Khaliq <gradio-team@huggingface.co>, Pete Allen <gradio-team@huggingface.co>, Ömer Faruk Özdemir <gradio-team@huggingface.co>, Freddy A Boulton <gradio-team@huggingface.co>, Hannah Blair <gradio-team@huggingface.co>
# License:
# Location: /usr/local/lib/python3.13/dist-packages
# Requires: aiofiles, anyio, fastapi, ffmpy, gradio-client, httpx, huggingface-hub, importlib-resources, jinja2, markupsafe, matplotlib, numpy, orjson, packaging, pandas, pillow, pydantic, pydub, python-multipart, pyyaml, ruff, semantic-version, tomlkit, typer, typing-extensions, urllib3, uvicorn
# Required-by:

# %%
# !grep -n "type=" Gradio_UI.py
# Out:
# 269:                type="messages",

# %%
# !pip install "huggingface_hub==0.25.2"

# %%
final_answer = FinalAnswerTool()
model = InferenceClientModel(
    max_tokens=2096,
    temperature=0.5,
    model_id='Qwen/Qwen2.5-Coder-32B-Instruct',
    custom_role_conversions=None,
)

agent = CodeAgent(
    model=model,
    tools=[final_answer],
    max_steps=6,
    verbosity_level=1,
    planning_interval=None,
    name=None,
    description=None,
)
GradioUI(agent).launch()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_19992/4199819400.py in <cell line: 0>()
#      16     description=None,
#      17 )
# ---> 18 GradioUI(agent).launch()
#
# /content/Gradio_UI.py in launch(self, **kwargs)
#     265             stored_messages = gr.State([])
#     266             file_uploads_log = gr.State([])
# --> 267             chatbot = gr.Chatbot(
#     268                 label="Agent",
#     269                 type="messages",
#
# /usr/local/lib/python3.13/dist-packages/gradio/component_meta.py in wrapper(*args, **kwargs)
#     192             return None
#     193         else:
# --> 194             return fn(self, **kwargs)
#     195
#     196     return wrapper
#
# TypeError: Chatbot.__init__() got an unexpected keyword argument 'type'

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install gradio==4.44.0

# %%
# !pip install gradio

# %%
# !pip install tools

# %%
# !git clone https://huggingface.co/spaces/agents-course/First_agent_template
# %cd First_agent_template
# Out:
# Cloning into 'First_agent_template'...
# remote: Enumerating objects: 302, done.
# remote: Total 302 (delta 0), reused 0 (delta 0), pack-reused 302 (from 1)
# Receiving objects: 100% (302/302), 93.65 KiB | 2.60 MiB/s, done.
# Resolving deltas: 100% (155/155), done.
# /content/First_agent_template

# %%
# !git clone https://huggingface.co/spaces/agents-course/First_agent_template
# !cp -r First_agent_template/tools /content/
# !cp First_agent_template/Gradio_UI.py /content/
# !cp First_agent_template/prompts.yaml /content/
# Out:
# Cloning into 'First_agent_template'...
# remote: Enumerating objects: 302, done.
# remote: Total 302 (delta 0), reused 0 (delta 0), pack-reused 302 (from 1)
# Receiving objects: 100% (302/302), 93.65 KiB | 394.00 KiB/s, done.
# Resolving deltas: 100% (155/155), done.

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, InferenceClientModel, load_tool, tool
import datetime
import requests
import pytz
import yaml
from tools.final_answer import FinalAnswerTool

from Gradio_UI import GradioUI

# Below is an example of a tool that does nothing. Amaze us with your creativity!
@tool
def my_custom_tool(arg1:str, arg2:int)-> str: # it's important to specify the return type
    # Keep this format for the tool description / args description but feel free to modify the tool
    """A tool that does nothing yet
    Args:
        arg1: the first argument
        arg2: the second argument
    """
    return "What magic will you build ?"

@tool
def get_current_time_in_timezone(timezone: str) -> str:
    """A tool that fetches the current local time in a specified timezone.
    Args:
        timezone: A string representing a valid timezone (e.g., 'America/New_York').
    """
    try:
        # Create timezone object
        tz = pytz.timezone(timezone)
        # Get current time in that timezone
        local_time = datetime.datetime.now(tz).strftime("%Y-%m-%d %H:%M:%S")
        return f"The current local time in {timezone} is: {local_time}"
    except Exception as e:
        return f"Error fetching time for timezone '{timezone}': {str(e)}"


final_answer = FinalAnswerTool()
model = InferenceClientModel(
    max_tokens=2096,
    temperature=0.5,
    model_id='Qwen/Qwen2.5-Coder-32B-Instruct',
    custom_role_conversions=None,
)


# Import tool from Hub
image_generation_tool = load_tool("agents-course/text-to-image", trust_remote_code=True)

# Load system prompt from prompt.yaml file
with open("/content/prompts.yaml", 'r') as stream:
    prompt_templates = yaml.safe_load(stream)

agent = CodeAgent(
    model=model,
    tools=[final_answer], # add your tools here (don't remove final_answer)
    max_steps=6,
    verbosity_level=1,
    grammar=None,
    planning_interval=None,
    name=None,
    description=None,
    prompt_templates=prompt_templates # Pass system prompt to CodeAgent
)


GradioUI(agent).launch()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_988/1972180798.py in <cell line: 0>()
#       4 import pytz
#       5 import yaml
# ----> 6 from tools.final_answer import FinalAnswerTool
#       7
#       8 from Gradio_UI import GradioUI
#
# ModuleNotFoundError: No module named 'tools.final_answer'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
